# %% [markdown]
# # ABOUT

# %% [markdown]
# Datascientest's Datascientist continuous bootcamp - cohorte Mars2022 -  AeroBOT project
#
# **Tutor**
#
# * Alban THUET
#
# **Authors:**
#
# * Hélène ASSIR
#
# </br>
#
# ---
# </br>
#
# **Version History**
#
# Version | Date       | Author(s)  | Modification
# --------|----------- | ---------  | --------------------------
# 3.0     | 02/11/2022 | H.A.       | Code cleaning
# 2.1     | 30/09/2022 | H.A.       | Use df_for_Anomaly_prediction.pkl as data source
# 2.0     | 22/09/2022 | H.A.       | Add GridSearch for model optimisation
# 1.0     | 24/08/2022 | H.A.       | Document creation

# %% [markdown]
# This notebook can be executed entirely.
#
# It
#
# * mounts the GDrive of our AeroBot project @gmail account.
#
# * loads the data from the `df_for_Anomaly_prediction.pkl` file (cf. `04_1_1 Anomaly feature Definition TRAIN set.ipynb`) under a pandas DataFrame named `df`, which contains `96986` entries and 20 columns.
# These data do not contain any more UAS-related entries.
#
# * Performs Anomaly target feature prediction : Bag Of Words approach with feature selection based on feature importance
# - for classifiers : Decision Tree, Random Forest and Gradient Boosting with GridsearchCV
# - for classifier : SVM with SVC(C = 1,  kernel = 'rbf')

# %% [markdown]
# # IMPORT PACKAGES

# %%
#######################
# Import packages
#######################
import numpy as np
import seaborn as sns
import math # for math.pi etc.
import time # time code execution

#######################
# Pandas
#######################
import pandas as pd
# Set pandas settings to show all data when using .head(), .columns etc.
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.set_option("display.colheader_justify","left") # left-justify the print output of pandas

### Display full columnwidth
# Set pandas settings to display full text columns
#pd.options.display.max_colwidth = None
# Restore pandas settings to display standard colwidth
pd.reset_option('display.max_colwidth')

import itertools # Pour créer des iterateurs

# Package to show the progression of pandas operations
from tqdm import tqdm
# from tqdm.auto import tqdm  # for notebooks

# Create new `pandas` methods which use `tqdm` progress
# (can use tqdm_gui, optional kwargs, etc.)
tqdm.pandas()
# simply use .progress_apply() instead of .apply() on your pd.DataFram

######################
# PLOTTING
######################
import matplotlib.pyplot as plt
# %matplotlib inline

#####################
# NLP 
#####################
import re # for Regular Expression handling
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet') # WordNet lemmatizer
nltk.download('omw-1.4') # necessary for WordNet lemmatizer
from nltk.tokenize import word_tokenize # Usual tokenizer
from nltk.tokenize import TweetTokenizer # Special tokenizer;  "we'll", "didn't", etc. are considered as one word
from sklearn.feature_extraction.text import CountVectorizer # Vectorization
from nltk.corpus import stopwords # Import stopwords from nltk.corpus
from nltk.stem.snowball import EnglishStemmer
##############################
# Undersampeling
##############################
from imblearn.under_sampling import RandomUnderSampler 
###############################
# ML preprocessing and models
###############################
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import ensemble # random forest
from sklearn.svm import SVC
from sklearn import model_selection #,preprocessing

from sklearn.metrics import classification_report, confusion_matrix


###############################
# Other
###############################
import pickle as pkl # Saving data externally
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %% [markdown]
# # LOAD DATA

# %% [markdown]
# ## Mount GDrive

# %%
#@title
# Mount your Google Drive
from google.colab import drive
drive.mount('/content/drive/')

#check your present working directory 
# %pwd
# Out:
# Mounted at /content/drive/
# '/content'

# %%
#@title
# move to the transformed data location (you can create a deeper structure, if needed, e.g. to save a trained model):
# %cd /content/drive/MyDrive/data/transformed/
# Out:
# /content/drive/MyDrive/data/transformed

# %%
#@title
# !ls # list the content of the pwd

#!ls "/content/drive/MyDrive/Data_Science/Formations/DataScienceTest/projet/AeroBot/" # list contect of a speficic folder
# Out:
#  complaints-2022-08-05_13_55.csv
# 'Copy of Qualified abbreviations_20220718.xlsx.gsheet'
# 'Data Dictionnary.xlsx'
#  data_for_BERT_multilabel_20220805.pkl
#  df_for_Anomaly_prediction.pkl
#  df_test_for_Anomaly_prediction.pkl
#  model.png
#  model_results
#  Narrative_PP_stemmed_24072022_TRAIN.pkl
#  Narrative_Raw_Stemmed_24072022_TRAIN.pkl
#  Narrative_RegEx_subst_21072022_TRAIN.pkl
# 'Qualified abbreviations_20220707_test.csv'
# 'Qualified abbreviations_20220708.csv'
# 'Qualified abbreviations_20220718.csv'
# 'Qualified abbreviations_20220718_Google_sheet.gsheet'
#  test_data_final.pkl
#  train_data_final.pkl

# %% [markdown]
# ## Load data from .pkl file

# %%
# Load the TRAIN data (96986 entries)

# %cd /content/drive/MyDrive/data/transformed/
with open("df_for_Anomaly_prediction.pkl", "rb") as f:
    loaded_data = pkl.load(f)

df = loaded_data
print("\nA Dataframe with", len(df), "entries has been loaded")
# Out:
# /content/drive/MyDrive/data/transformed
#
# A Dataframe with 96986 entries has been loaded

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96986 entries, 1163382 to 874642
# Data columns (total 20 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Narrative                                     96986 non-null  object
#  1   Anomaly                                       96986 non-null  object
#  2   Narrative_PP_stemmed                          96986 non-null  object
#  3   Narrative_Raw_Stemmed                         96986 non-null  object
#  4   Narrative_Raw_Stemmed_str                     96986 non-null  object
#  5   Narrative_PP_stemmed_str                      96986 non-null  object
#  6   Anomaly_Deviation / Discrepancy - Procedural  96986 non-null  int64
#  7   Anomaly_Aircraft Equipment                    96986 non-null  int64
#  8   Anomaly_Conflict                              96986 non-null  int64
#  9   Anomaly_Inflight Event / Encounter            96986 non-null  int64
#  10  Anomaly_ATC Issue                             96986 non-null  int64
#  11  Anomaly_Deviation - Altitude                  96986 non-null  int64
#  12  Anomaly_Deviation - Track / Heading           96986 non-null  int64
#  13  Anomaly_Ground Event / Encounter              96986 non-null  int64
#  14  Anomaly_Flight Deck / Cabin / Aircraft Event  96986 non-null  int64
#  15  Anomaly_Ground Incursion                      96986 non-null  int64
#  16  Anomaly_Airspace Violation                    96986 non-null  int64
#  17  Anomaly_Deviation - Speed                     96986 non-null  int64
#  18  Anomaly_Ground Excursion                      96986 non-null  int64
#  19  Anomaly_No Specific Anomaly Occurred          96986 non-null  int64
# dtypes: int64(14), object(6)
# memory usage: 15.5+ MB

# %% [markdown]
# ## Define Anomaly_RootLabels_columns list from data set

# %%
# Retriece the list of Anomaly label columns
Anomaly_RootLabels_columns = []

for col in df.columns:
  if 'Anomaly_' in str(col):
      Anomaly_RootLabels_columns.append(col)

# %%
Anomaly_RootLabels_columns
# Out:
# ['Anomaly_Deviation / Discrepancy - Procedural',
#  'Anomaly_Aircraft Equipment',
#  'Anomaly_Conflict',
#  'Anomaly_Inflight Event / Encounter',
#  'Anomaly_ATC Issue',
#  'Anomaly_Deviation - Altitude',
#  'Anomaly_Deviation - Track / Heading',
#  'Anomaly_Ground Event / Encounter',
#  'Anomaly_Flight Deck / Cabin / Aircraft Event',
#  'Anomaly_Ground Incursion',
#  'Anomaly_Airspace Violation',
#  'Anomaly_Deviation - Speed',
#  'Anomaly_Ground Excursion',
#  'Anomaly_No Specific Anomaly Occurred']

# %% [markdown]
# # SUPERVISED NARRATIVE PREPROCESSING WITH IMPORTANCE

# %% [markdown]
# ## FIRST DECISION TREE PREDICTION

# %% [markdown]
# ## STANDARD SAMPLING - Function metrics_table_DT_grid  (DT classifiers only)
# -Performs a decision tree model with standard sampling on the different targets and stock the results as well as the importance of features (tokens)
# -Grid_search dictionnary is optional

# %%
def metrics_table_DT_grid(data, target, vectorizer, classifier,grid_parameters_dict=None):
    """
    Return Prediction metrics and feature importance for Decision Trees
    /!\ works only for DT, since the other models don't return Feature importance

    Inputs: 
    - data: pd.Series containing the narratives as single string
    - target: a list of target labels
    - vectorizer instance. Lets you instantiate it with the desired settings
    - classifier (must be a decision tree as we calculate importance)
    - grid_parameters_dict (must be a dictionnary of parameters compatible with the classifier)   
    Return:
    - a DataFrame containing the classification reports for each target label
    - a DataFrame containing the feature importance for each token

    """

    # Time the function execution
    start_time = time.time()
    print(7*'-', "Execution started...", 7*'-', '\n')
    
    # Train-test split  
    X_train, X_test, y_train, y_test = train_test_split(data, target, 
                                                        test_size= 0.2, 
                                                        random_state = 12)


    # apply the vectorizer 
    X_train = vectorizer.fit_transform(X_train) 
    X_test = vectorizer.transform(X_test) 
    vocab = vectorizer.get_feature_names_out()
    print("Vocabulary length:" , len(vocab))

    # Instantiate variables
    df_importances = pd.DataFrame(vocab).rename(columns={0: 'token'})
    metrics_df_list = []

    # Loop through Anomaly labels
    for Anomaly in target.columns:

      print('Prediction of anomaly :', Anomaly)

      # Select the correct target data
      y_train_Anomaly = y_train[Anomaly]
      y_test_Anomaly = y_test[Anomaly]

      # Grid_Search option
      if grid_parameters_dict != None :
        grid_clf=model_selection.GridSearchCV(estimator=classifier,param_grid=grid_parameters_dict,scoring='f1')
        grid=grid_clf.fit(X_train, y_train)  
        print(pd.DataFrame.from_dict(grid.cv_results_).loc[:,['params', 'mean_test_score']]) 
        print(grid_clf.best_params_)
        classifier.set_params(**grid_clf.best_params_)
        print('Done Grid Optimisation')

      # Train & predict best classifier
      classifier.fit(X_train, y_train_Anomaly)
      y_pred = classifier.predict(X_test)
      print('Done Prediction')

      #########  FEATURE IMPORTANCE ################
      # write feature and its importance into a dict
      feats={}
      for feature,importance in zip(vocab, classifier.feature_importances_):
        feats[feature] = importance

      # Create a DataFrame from the dict. Each anomaly label gets a new column
      col_importance = 'Importance_' + Anomaly
      importance = pd.DataFrame.from_dict(feats, orient = 'index').reset_index().rename(columns = {'index': 'token', 0: col_importance})
      df_importances = df_importances.merge(importance, on = 'token', how = 'left')

      #########  CLASSIFICATION REPORT #############
      # Classif. report; dict format
      clf_rep = classification_report(y_test_Anomaly, y_pred, output_dict = True)
      
      # write classification report dictionnary into pd.DataFrame
      metrics = pd.DataFrame(clf_rep).reset_index().rename(columns = {'index': 'metric'})
      # Fill in with anomaly name
      metrics['anomaly'] = Anomaly
      if grid_parameters_dict == None :
        metrics['classifier'] = 'Decision Tree'  # [dt, rf, Word_Embedding, ...]
      else :
        metrics['classifier'] = 'Decision Tree (Grid)'  # [dt, rf, Word_Embedding, ...]
      metrics['undersampling'] = 0              # 1 if undersampling was applied
      metrics_df_list.append(metrics)

    
    metrics_exp = pd.concat(metrics_df_list)
    # Reset index, otherwise you get a repetition of 0,1,2,3
    metrics_exp = metrics_exp.reset_index().drop(columns =['index'])

    
    # Calculate and print time to execute
    end_time = time.time()
    print(f"--- DONE! It took {np.round((end_time - start_time)/60,1)} minutes ---")

    return metrics_exp, df_importances

# %% [markdown]
# ### DT (Gini , Max_Depth=20), PP NARRATIVES,DEFAULT SAMPLING  (df_metrics_DT_PP.pkl)

# %%
# Initializes the objects necesseray function inputs
data = df['Narrative_PP_stemmed_str']
target = df[Anomaly_RootLabels_columns]
clf = DecisionTreeClassifier(max_depth = 20)
vectorizer = CountVectorizer()

# %%
# Calls the function 
df_metrics, df_importances = metrics_table_DT_grid(data, target, vectorizer, clf)

# Fill in additionnal columns with metadata
df_metrics['preprocessing'] = 1          # 0 if raw, 1 if preprocessed
df_metrics['Count_Vectorizer_opts'] = np.nan # ['exclude_numerics'; 'min_df = 12'; ...]
# Reorder columns
df_metrics = df_metrics[['classifier', 'preprocessing', 'undersampling', 'Count_Vectorizer_opts',
                'anomaly', 'metric', '0', '1', 'accuracy', 'macro avg', 'weighted avg']]
# Out:
# ------- Execution started... -------
#
# Vocabulary length: 50030
# Prediction of anomaly : Anomaly_Deviation / Discrepancy - Procedural
# Done Prediction
# Prediction of anomaly : Anomaly_Aircraft Equipment
# Done Prediction
# Prediction of anomaly : Anomaly_Conflict
# Done Prediction
# Prediction of anomaly : Anomaly_Inflight Event / Encounter
# Done Prediction
# Prediction of anomaly : Anomaly_ATC Issue
# Done Prediction
# Prediction of anomaly : Anomaly_Deviation - Altitude
# Done Prediction
# Prediction of anomaly : Anomaly_Deviation - Track / Heading
# Done Prediction
# Prediction of anomaly : Anomaly_Ground Event / Encounter
# Done Prediction
# Prediction of anomaly : Anomaly_Flight Deck / Cabin / Aircraft Event
# Done Prediction
# Prediction of anomaly : Anomaly_Ground Incursion
# Done Prediction
# Prediction of anomaly : Anomaly_Airspace Violation
# Done Prediction
# Prediction of anomaly : Anomaly_Deviation - Speed
# Done Prediction
# Prediction of anomaly : Anomaly_Ground Excursion
# Done Prediction
# Prediction of anomaly : Anomaly_No Specific Anomaly Occurred
# Done Prediction
# --- DONE! It took 5.1 minutes ---

# %%
print(df_metrics.shape, " should be (56 , 11)")
# Out:
# (56, 11)  should be (56 , 11)

# %%
# # Saves the metrics into a pkl file
# %cd /content/drive/MyDrive/data/transformed/model_results/Importance_Feature_Selection_Grid_Search/
# filename = 'df_metrics_DT_PP.pkl'
# #enregistre le modèle
# pickle.dump([df_metrics], open(filename, 'wb'))

# %% [markdown]
# ####Token Importance analysis

# %%
len(df_importances)
# Out:
# 50030

# %%
df_metrics[df_metrics['metric'] == 'f1-score']
# Out:
#    classifier      preprocessing  undersampling  Count_Vectorizer_opts  \
# 2   Decision Tree  1              0             NaN
# 6   Decision Tree  1              0             NaN
# 10  Decision Tree  1              0             NaN
# 14  Decision Tree  1              0             NaN
# 18  Decision Tree  1              0             NaN
# 22  Decision Tree  1              0             NaN
# 26  Decision Tree  1              0             NaN
# 30  Decision Tree  1              0             NaN
# 34  Decision Tree  1              0             NaN
# 38  Decision Tree  1              0             NaN
# 42  Decision Tree  1              0             NaN
# 46  Decision Tree  1              0             NaN
# 50  Decision Tree  1              0             NaN
# 54  Decision Tree  1              0             NaN
#
#    anomaly                                       metric     0         \
# 2   Anomaly_Deviation / Discrepancy - Procedural  f1-score  0.545427
# 6                     Anomaly_Aircraft Equipment  f1-score  0.867484
# 10                              Anomaly_Conflict  f1-score  0.927110
# 14            Anomaly_Inflight Event / Encounter  f1-score  0.920785
# 18                             Anomaly_ATC Issue  f1-score  0.921614
# 22                  Anomaly_Deviation - Altitude  f1-score  0.954654
# 26           Anomaly_Deviation - Track / Heading  f1-score  0.957211
# 30              Anomaly_Ground Event / Encounter  f1-score  0.962207
# 34  Anomaly_Flight Deck / Cabin / Aircraft Event  f1-score  0.974153
# 38                      Anomaly_Ground Incursion  f1-score  0.975818
# 42                    Anomaly_Airspace Violation  f1-score  0.981920
# 46                     Anomaly_Deviation - Speed  f1-score  0.985084
# 50                      Anomaly_Ground Excursion  f1-score  0.989584
# 54          Anomaly_No Specific Anomaly Occurred  f1-score  0.996741
#
#     1         accuracy  macro avg  weighted avg
# 2   0.759984  0.685844  0.652706   0.674296
# 6   0.783518  0.835602  0.825501   0.834301
# 10  0.636966  0.878596  0.782038   0.875298
# 14  0.575410  0.866481  0.748098   0.859626
# 18  0.509540  0.864831  0.715577   0.854380
# 22  0.492298  0.916744  0.723476   0.913371
# 26  0.455992  0.920662  0.706601   0.915610
# 30  0.461901  0.929374  0.712054   0.923932
# 34  0.654316  0.951902  0.814235   0.949173
# 38  0.571842  0.954222  0.773830   0.953410
# 42  0.498890  0.965099  0.740405   0.961900
# 46  0.383860  0.970873  0.684472   0.968812
# 50  0.489691  0.979586  0.739638   0.978323
# 54  0.059701  0.993504  0.528221   0.990703

# %%
# Prints the top 10 most important features for each Anomaly label
for Anomaly in target.columns:
  col_importance = 'Importance_' + Anomaly
  topfeatures = df_importances.sort_values(by = col_importance, ascending = False).head(5)
  print(Anomaly,'\n',topfeatures[['token', col_importance]], '\n')
# Out:
# Anomaly_Deviation / Discrepancy - Procedural
#        token    Importance_Anomaly_Deviation / Discrepancy - Procedural
# 20119   emerg  0.136952
# 28691    land  0.035485
# 37717  realiz  0.029528
# 17851  declar  0.020886
# 44219    told  0.018209
#
# Anomaly_Aircraft Equipment
#        token     Importance_Anomaly_Aircraft Equipment
# 30197  mainten  0.316246
# 20119    emerg  0.114112
# 20252    engin  0.076373
# 36970      qrh  0.043183
# 39308   runway  0.021250
#
# Anomaly_Conflict
#        token      Importance_Anomaly_Conflict
# 44461   traffic  0.276288
# 37350        ra  0.073354
# 15936    collis  0.053742
# 20642      evas  0.026577
# 10156  aircraft  0.026359
#
# Anomaly_Inflight Event / Encounter
#        token      Importance_Anomaly_Inflight Event / Encounter
# 44896    turbul  0.181587
# 47551   weather  0.090057
# 43567   terrain  0.056497
# 11038  approach  0.033935
# 15699     cloud  0.025430
#
# Anomaly_ATC Issue
#        token      Importance_Anomaly_ATC Issue
# 40143    sector  0.162830
# 44461   traffic  0.089887
# 40275     separ  0.048234
# 10156  aircraft  0.034274
# 15577  clearanc  0.023822
#
# Anomaly_Deviation - Altitude
#        token     Importance_Anomaly_Deviation - Altitude
# 10493  altitud  0.229569
# 21391     feet  0.087886
# 28691     land  0.025808
# 43416      teb  0.021269
# 14249    cabin  0.017486
#
# Anomaly_Deviation - Track / Heading
#        token   Importance_Anomaly_Deviation - Track / Heading
# 24402   head  0.157569
# 16636  cours  0.062512
# 22003    fms  0.056908
# 21391   feet  0.034450
# 44912   turn  0.031567
#
# Anomaly_Ground Event / Encounter
#        token    Importance_Anomaly_Ground Event / Encounter
# 17511   damag  0.141467
# 13487   brake  0.069726
# 36504  propel  0.047034
# 23567   grass  0.028705
# 22967    gear  0.017511
#
# Anomaly_Flight Deck / Cabin / Aircraft Event
#        token     Importance_Anomaly_Flight Deck / Cabin / Aircraft Event
# 41220    smell  0.343939
# 41247    smoke  0.110852
# 34847  passeng  0.079736
# 30777    medic  0.037997
# 33564     odor  0.026252
#
# Anomaly_Ground Incursion
#        token     Importance_Anomaly_Ground Incursion
# 43315  taxiway  0.267463
# 24895     hold  0.103756
# 40628    short  0.039641
# 39308   runway  0.025478
# 13487    brake  0.019771
#
# Anomaly_Airspace Violation
#        token     Importance_Anomaly_Airspace Violation
# 10222  airspac  0.288925
# 43642      tfr  0.092764
# 9813      adiz  0.072147
# 46791   violat  0.021411
# 44461  traffic  0.015299
#
# Anomaly_Deviation - Speed
#        token     Importance_Anomaly_Deviation - Speed
# 41674    speed  0.170445
# 10228   airspe  0.046907
# 40459   shaker  0.037356
# 28210     knot  0.034509
# 34336  overspe  0.029191
#
# Anomaly_Ground Excursion
#        token    Importance_Anomaly_Ground Excursion
# 23567   grass  0.253189
# 46565    veer  0.053599
# 13487   brake  0.044418
# 17511   damag  0.043868
# 39308  runway  0.032312
#
# Anomaly_No Specific Anomaly Occurred
#        token    Importance_Anomaly_No Specific Anomaly Occurred
# 32858   night  0.052591
# 22244    four  0.038599
# 121      0200  0.037013
# 46423  vaccin  0.035065
# 24560    hepa  0.035063

# %%
# Plots the top 10 most important features for each Anomaly label
for Anomaly in target.columns:
  col_importance = 'Importance_' + Anomaly
  topfeatures = df_importances.sort_values(by = col_importance, ascending = True).tail(20)
  topfeatures.set_index('token').plot.barh(  y=[col_importance],legend=None) 
  plt.xlabel('Importance')
  plt.ylabel('Tokens')
  plt.title(Anomaly)

# %% [markdown]
# ### Dictionnary : Token Importance

# %%
vocab_length_list=[20,30,50,100,250,500,750,1000,3000]

# %%
# Defines a dictionnary (keys = anomalies) of dictionnaries (keys=vocab_length) of top N important tokens for the anomaly
dict_top_N_features={}
for Anomaly in Anomaly_RootLabels_columns:
  col_importance = 'Importance_' + Anomaly
  dict_top_features={}
  for vocab_length in vocab_length_list :
    topfeatures = list(df_importances.sort_values(by = col_importance, ascending = False).head(vocab_length)['token'])
    dict_top_features[vocab_length]=topfeatures
  dict_top_N_features[Anomaly]=dict_top_features

# %% [markdown]
# #### Analysis of top most important tokens / anomaly

# %%
# Defines a dictionnary (keys = vocab_length) of top N important  tokens for all the anomalies (deduplicated)
# i.e :  For 20 : we take the 20 most important tokens for each anomalies (potentially 280 tokens) and deduplicate the list : we get 189 tokens
dict_top_N_features_global={}
for vocab_length in vocab_length_list :
  vocab_total_list=[]
  for Anomaly in Anomaly_RootLabels_columns:
    col_importance = 'Importance_' + Anomaly
    liste=dict_top_N_features[Anomaly][vocab_length]  
    vocab_total_list=vocab_total_list+liste
  vocab_distinct_list=list(set(vocab_total_list))  
  dict_top_N_features_global[vocab_length]=vocab_distinct_list

# %%
for vocab_length in vocab_length_list :
  print('Top ',vocab_length,' most important tokens (per anomaly) =>', len(dict_top_N_features_global[vocab_length]), 'tokens in total')
# Out:
# Top  20  most important tokens (per anomaly) => 187 tokens in total
# Top  30  most important tokens (per anomaly) => 266 tokens in total
# Top  50  most important tokens (per anomaly) => 394 tokens in total
# Top  100  most important tokens (per anomaly) => 697 tokens in total
# Top  250  most important tokens (per anomaly) => 1553 tokens in total
# Top  500  most important tokens (per anomaly) => 2901 tokens in total
# Top  750  most important tokens (per anomaly) => 3922 tokens in total
# Top  1000  most important tokens (per anomaly) => 4723 tokens in total
# Top  3000  most important tokens (per anomaly) => 6967 tokens in total

# %% [markdown]
# ## SECOND DECISION TREE

# %% [markdown]
# ### SECOND DT (Grid search), PP NARRATIVES,DEFAULT SAMPLING  , Vocab = N most important tokens (df_metrics_DT_PP_Impce_N.pkl)

# %%
#vocab_length_list_to_run= [20,30,50,100,250,500] 
# For DT, due to extended computation time, only 20,30,50,100,250,500 could be tested
vocab_length_list_to_run=[20] # to test & run quickly cleaned collab

# %%
clf = DecisionTreeClassifier()
criterion = ['gini', 'entropy']
max_depth = [5,10,15,20]
grid_parameters_dict_DT=dict(criterion=criterion,
                      max_depth=max_depth)

# %%
for vocab_length in vocab_length_list_to_run :
  df_second_metrics_compiled=[]
  #for Anomaly in ['Anomaly_Ground Event / Encounter','Anomaly_Conflict']:
  for Anomaly in Anomaly_RootLabels_columns:
    col_importance = 'Importance_' + Anomaly
    liste=dict_top_N_features[Anomaly][vocab_length]
    # Initializes the objects necesseray function inputs
    data = df['Narrative_PP_stemmed_str']
    target = df[[Anomaly]]
    vectorizer = CountVectorizer(vocabulary=liste) 

    # Calls the function 
    df_second_metrics, df_second_importances = metrics_table_DT_grid(data, target, vectorizer, clf,grid_parameters_dict=grid_parameters_dict_DT)

    # Fill in additionnal columns with metadata
    df_second_metrics['preprocessing'] = 1          # 0 if raw, 1 if preprocessed
    Count_Vectorizer_opts_label='impce= '+str(vocab_length) 
    df_second_metrics['Count_Vectorizer_opts'] = Count_Vectorizer_opts_label # ['exclude_numerics'; 'min_df = 12'; 'impce= 100'...]
    # Reorder columns
    df_second_metrics = df_second_metrics[['classifier', 'preprocessing', 'undersampling', 'Count_Vectorizer_opts',
                    'anomaly', 'metric', '0', '1', 'accuracy', 'macro avg', 'weighted avg']]
    df_second_metrics_compiled.append(df_second_metrics)
  
  metrics_exp_vocab_length = pd.concat(df_second_metrics_compiled)
  print(metrics_exp_vocab_length.shape, " should be (56 , 11)")

  # %cd /content/drive/MyDrive/data/transformed/model_results/Importance_Feature_Selection_Grid_Search/
  # filename = 'df_metrics_DT_PP_Impce_Grid_'+str(vocab_length)+'.pkl'
  # #enregistre le modèle
  # pickle.dump([metrics_exp_vocab_length], open(filename, 'wb'))
# Out:
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation / Discrepancy - Procedural
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.738021
# 1     {'criterion': 'gini', 'max_depth': 10}  0.764470
# 2     {'criterion': 'gini', 'max_depth': 15}  0.762986
# 3     {'criterion': 'gini', 'max_depth': 20}  0.754832
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.737977
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.762581
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.763447
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.757614
# {'criterion': 'gini', 'max_depth': 10}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.4 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Aircraft Equipment
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.741176
# 1     {'criterion': 'gini', 'max_depth': 10}  0.777687
# 2     {'criterion': 'gini', 'max_depth': 15}  0.778390
# 3     {'criterion': 'gini', 'max_depth': 20}  0.768155
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.733772
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.772987
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.779362
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.771365
# {'criterion': 'entropy', 'max_depth': 15}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.3 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Conflict
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.534666
# 1     {'criterion': 'gini', 'max_depth': 10}  0.603639
# 2     {'criterion': 'gini', 'max_depth': 15}  0.609811
# 3     {'criterion': 'gini', 'max_depth': 20}  0.594810
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.527340
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.605943
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.611567
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.596769
# {'criterion': 'entropy', 'max_depth': 15}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.3 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Inflight Event / Encounter
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.500620
# 1     {'criterion': 'gini', 'max_depth': 10}  0.538519
# 2     {'criterion': 'gini', 'max_depth': 15}  0.539163
# 3     {'criterion': 'gini', 'max_depth': 20}  0.529475
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.475147
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.534413
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.544181
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.536749
# {'criterion': 'entropy', 'max_depth': 15}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.3 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_ATC Issue
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.393043
# 1     {'criterion': 'gini', 'max_depth': 10}  0.470851
# 2     {'criterion': 'gini', 'max_depth': 15}  0.473104
# 3     {'criterion': 'gini', 'max_depth': 20}  0.468651
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.372655
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.459158
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.475341
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.471047
# {'criterion': 'entropy', 'max_depth': 15}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.4 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Altitude
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.448851
# 1     {'criterion': 'gini', 'max_depth': 10}  0.504410
# 2     {'criterion': 'gini', 'max_depth': 15}  0.505796
# 3     {'criterion': 'gini', 'max_depth': 20}  0.491137
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.357745
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.461864
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.490541
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.484746
# {'criterion': 'gini', 'max_depth': 15}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.5 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Track / Heading
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.329533
# 1     {'criterion': 'gini', 'max_depth': 10}  0.438363
# 2     {'criterion': 'gini', 'max_depth': 15}  0.448186
# 3     {'criterion': 'gini', 'max_depth': 20}  0.443073
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.319384
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.437976
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.449004
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.444345
# {'criterion': 'entropy', 'max_depth': 15}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.4 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Event / Encounter
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.336816
# 1     {'criterion': 'gini', 'max_depth': 10}  0.433091
# 2     {'criterion': 'gini', 'max_depth': 15}  0.428962
# 3     {'criterion': 'gini', 'max_depth': 20}  0.421215
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.300252
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.436491
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.428505
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.421619
# {'criterion': 'entropy', 'max_depth': 10}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.2 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Flight Deck / Cabin / Aircraft Event
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.627127
# 1     {'criterion': 'gini', 'max_depth': 10}  0.659123
# 2     {'criterion': 'gini', 'max_depth': 15}  0.645534
# 3     {'criterion': 'gini', 'max_depth': 20}  0.623774
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.614984
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.664628
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.655855
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.633082
# {'criterion': 'entropy', 'max_depth': 10}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.3 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Incursion
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.540523
# 1     {'criterion': 'gini', 'max_depth': 10}  0.571456
# 2     {'criterion': 'gini', 'max_depth': 15}  0.523998
# 3     {'criterion': 'gini', 'max_depth': 20}  0.503768
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.534967
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.559293
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.522270
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.506826
# {'criterion': 'gini', 'max_depth': 10}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.4 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Airspace Violation
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.470396
# 1     {'criterion': 'gini', 'max_depth': 10}  0.469535
# 2     {'criterion': 'gini', 'max_depth': 15}  0.458048
# 3     {'criterion': 'gini', 'max_depth': 20}  0.447399
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.489464
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.475282
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.462242
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.451772
# {'criterion': 'entropy', 'max_depth': 5}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.3 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Speed
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.258354
# 1     {'criterion': 'gini', 'max_depth': 10}  0.346239
# 2     {'criterion': 'gini', 'max_depth': 15}  0.373290
# 3     {'criterion': 'gini', 'max_depth': 20}  0.358852
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.237900
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.351955
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.359836
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.356199
# {'criterion': 'gini', 'max_depth': 15}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.2 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Excursion
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.498685
# 1     {'criterion': 'gini', 'max_depth': 10}  0.504301
# 2     {'criterion': 'gini', 'max_depth': 15}  0.484613
# 3     {'criterion': 'gini', 'max_depth': 20}  0.472878
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.473587
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.505573
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.498563
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.468450
# {'criterion': 'entropy', 'max_depth': 10}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.2 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_No Specific Anomaly Occurred
#   params                                      mean_test_score
# 0      {'criterion': 'gini', 'max_depth': 5}  0.005634
# 1     {'criterion': 'gini', 'max_depth': 10}  0.058674
# 2     {'criterion': 'gini', 'max_depth': 15}  0.065268
# 3     {'criterion': 'gini', 'max_depth': 20}  0.074164
# 4   {'criterion': 'entropy', 'max_depth': 5}  0.017062
# 5  {'criterion': 'entropy', 'max_depth': 10}  0.061959
# 6  {'criterion': 'entropy', 'max_depth': 15}  0.060472
# 7  {'criterion': 'entropy', 'max_depth': 20}  0.055059
# {'criterion': 'gini', 'max_depth': 20}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.1 minutes ---
# (56, 11)  should be (56 , 11)

# %% [markdown]
# ## OTHER CLASSIFIERS

# %% [markdown]
# ## FUNCTIONS

# %% [markdown]
# ### STANDARD SAMPLING - Function metrics_table_grid (all classifiers)
# -Performs a model with standard sampling on the different targets and stock the results
# -Grid search dictionnary is optional

# %%
def metrics_table_grid(data, target, vectorizer, classifier,grid_parameters_dict=None):
    """
    Return Prediction metrics and feature importance for Decision Trees
    /!\ works only for DT, since the other models don't return Feature importance

    Inputs: 
    - data: pd.Series containing the narratives as single string
    - target: a list of target labels
    - vectorizer instance. Lets you instantiate it with the desired settings
    - classifier (must be a decision tree as we calculate importance)
    - grid_parameters_dict (must be a dictionnary of parameters compatible with the classifier)   
    
    Return:
    - a DataFrame containing the classification reports for each target label
    - a DataFrame containing the feature importance for each token

    """

    # Time the function execution
    start_time = time.time()
    print(7*'-', "Execution started...", 7*'-', '\n')
    
    # Train-test split  
    X_train, X_test, y_train, y_test = train_test_split(data, target, 
                                                        test_size= 0.2, 
                                                        random_state = 12)


    # apply the vectorizer 
    X_train = vectorizer.fit_transform(X_train) 
    X_test = vectorizer.transform(X_test) 
    vocab = vectorizer.get_feature_names_out()
    print("Vocabulary length:" , len(vocab))

    # Instantiate variables
    metrics_df_list = []

    # Loop through Anomaly labels
    for Anomaly in target.columns:

      print('Prediction of anomaly :', Anomaly)

      # Select the correct target data
      y_train_Anomaly = y_train[Anomaly]
      y_test_Anomaly = y_test[Anomaly]
      
      # Grid_Search option
      if grid_parameters_dict != None :
        grid_clf=model_selection.GridSearchCV(estimator=classifier,param_grid=grid_parameters_dict,scoring='f1')
        grid=grid_clf.fit(X_train, y_train_Anomaly)  
        print(pd.DataFrame.from_dict(grid.cv_results_).loc[:,['params', 'mean_test_score']]) 
        print(grid_clf.best_params_)
        classifier.set_params(**grid_clf.best_params_)
        print('Done Grid Optimisation')    
      # Train & predict
      classifier.fit(X_train, y_train_Anomaly)
      y_pred = classifier.predict(X_test)
      print('Done Prediction')   
      #########  CLASSIFICATION REPORT #############
      # Classif. report; dict format
      clf_rep = classification_report(y_test_Anomaly, y_pred, output_dict = True)
      # write classification report dictionnary into pd.DataFrame
      metrics = pd.DataFrame(clf_rep).reset_index().rename(columns = {'index': 'metric'})
      # Fill in with anomaly name
      metrics['anomaly'] = Anomaly
      metrics['undersampling'] = 0              # 1 if undersampling was applied
      metrics_df_list.append(metrics)

    
    metrics_exp = pd.concat(metrics_df_list)
    # Reset index, otherwise you get a repetition of 0,1,2,3
    metrics_exp = metrics_exp.reset_index().drop(columns =['index'])

    
    # Calculate and print time to execute
    end_time = time.time()
    print(f"--- DONE! It took {np.round((end_time - start_time)/60,1)} minutes ---")

    return metrics_exp

# %% [markdown]
# ### UNDERSAMPLING - Function metrics_table_US_grid (for all classifiers)
# -Performs a model with under sampling on the different targets and stock the results
# -Grid search is optional

# %%
def metrics_table_US_grid(data, target, vectorizer, classifier,grid_parameters_dict=None):
    """
    Return Prediction metrics and feature importance for Decision Trees
    /!\ works only for DT, since the other models don't return Feature importance

    Inputs: 
    - data: pd.Series containing the narratives as single string
    - target: a list of target labels
    - vectorizer instance. Lets you instantiate it with the desired settings
    - classifier  
    - grid_parameters_dict (must be a dictionnary of parameters compatible with the classifier)   
   
    Return:
    - a DataFrame containing the classification reports for each target label
    - a DataFrame containing the feature importance for each token

    """

    # Time the function execution
    start_time = time.time()
    print(7*'-', "Execution started...", 7*'-', '\n')
    
    # add an extra column ones in the data DataFrame for convenience later during undersampeling
    data = pd.DataFrame(data)
    data['ones'] = 1

    # Train-test split  
    X_train, X_test, y_train, y_test = train_test_split(data, target, 
                                                        test_size= 0.2, 
                                                        random_state = 12)


    # Remove from X_test
    X_test = X_test.drop('ones', axis=1)
    X_test = X_test.squeeze()
    
    # Instantiate variables
    metrics_df_list = []

    # Loop through Anomaly labels
    for Anomaly in target.columns:

      print('Prediction of anomaly :', Anomaly)

      # Select the correct target data
      y_train_Anomaly = y_train[Anomaly]
      y_test_Anomaly = y_test[Anomaly]

      # Perform an undersampeling step
      rus = RandomUnderSampler()
      X_ru, y_ru = rus.fit_resample(X_train, y_train_Anomaly)

      # Remove the extra added column of ones from the X_ru and X_test 
      # Remove from X_ru
      X_ru = X_ru.drop('ones', axis=1)
      X_ru = X_ru.squeeze()

      # apply the vectorizer 
      X_ru = vectorizer.fit_transform(X_ru) 
      X_test_Anomaly = vectorizer.transform(X_test) 
      vocab = vectorizer.get_feature_names_out()
      print("Vocabulary length:" , len(vocab))

      # Grid_Search option
      if grid_parameters_dict != None :
        grid_clf=model_selection.GridSearchCV(estimator=classifier,param_grid=grid_parameters_dict,scoring='f1')
        grid=grid_clf.fit(X_ru, y_ru)  
        print(pd.DataFrame.from_dict(grid.cv_results_).loc[:,['params', 'mean_test_score']]) 
        print(grid_clf.best_params_)
        classifier.set_params(**grid_clf.best_params_)
        print('Done Grid Optimisation')    
      # Train & predict
      classifier.fit(X_ru, y_ru)
      y_pred = classifier.predict(X_test_Anomaly)
      print('Done Prediction')   



      #########  CLASSIFICATION REPORT #############
      # Classif. report; dict format
      clf_rep = classification_report(y_test_Anomaly, y_pred, output_dict = True)
      # write classification report dictionnary into pd.DataFrame
      metrics = pd.DataFrame(clf_rep).reset_index().rename(columns = {'index': 'metric'})
      # Fill in with anomaly name
      metrics['anomaly'] = Anomaly
      metrics['undersampling'] = 1  # 1 if undersampling was applied
      metrics_df_list.append(metrics)

    
    metrics_exp = pd.concat(metrics_df_list)
    # Reset index, otherwise you get a repetition of 0,1,2,3
    metrics_exp = metrics_exp.reset_index().drop(columns =['index'])
    # Calculate and print time to execute
    end_time = time.time()
    print(f"--- DONE! It took {np.round((end_time - start_time)/60,1)} minutes ---")

    return metrics_exp

# %% [markdown]
# ## RANDOM FOREST

# %% [markdown]
# ### RF (Grid search) DEFAULT SAMPLING (df_metrics_RF_PP_Impce_N.pkl)
# PP NARRATIVES, Vocab = N most important tokens

# %%
#vocab_length_list_to_run= [20,30,50]  
# For RF, due to extended computation time, only 20,30,50 could be tested
vocab_length_list_to_run=[20] # to test & run quickly cleaned collab

# %%
clf = ensemble.RandomForestClassifier()
grid_parameters_dict_RF = { 
    'n_estimators': [50,100],
    'max_features': ['sqrt'],
    'max_depth' : [5,10,None],
    'criterion' :['gini', 'entropy']
}

# %%
for vocab_length in vocab_length_list_to_run :
  df_second_metrics_compiled=[]
  #for Anomaly in ['Anomaly_Ground Event / Encounter','Anomaly_Conflict']:
  for Anomaly in Anomaly_RootLabels_columns:
    col_importance = 'Importance_' + Anomaly
    liste=dict_top_N_features[Anomaly][vocab_length]
    
    # initialize the objects necesseray function inputs
    data = df['Narrative_PP_stemmed_str']
    target = df[[Anomaly]]
    vectorizer = CountVectorizer(vocabulary=liste)
    
    # Calls the function 
    df_second_metrics= metrics_table_grid(data, target, vectorizer, clf,grid_parameters_dict_RF)

    # Fill in additionnal columns with metadata
    df_second_metrics['classifier'] = 'Random Forest (Grid)'  # [dt, rf, Word_Embedding, ...]
    df_second_metrics['preprocessing'] = 1          # 0 if raw, 1 if preprocessed
    Count_Vectorizer_opts_label='impce= '+str(vocab_length) 
    df_second_metrics['Count_Vectorizer_opts'] = Count_Vectorizer_opts_label # ['exclude_numerics'; 'min_df = 12'; 'impce= 100'...]
    # Reorder columns
    df_second_metrics = df_second_metrics[['classifier', 'preprocessing', 'undersampling', 'Count_Vectorizer_opts',
                    'anomaly', 'metric', '0', '1', 'accuracy', 'macro avg', 'weighted avg']]



    df_second_metrics_compiled.append(df_second_metrics)
  
  metrics_exp_vocab_length = pd.concat(df_second_metrics_compiled)
  print(metrics_exp_vocab_length.shape, " should be (56 , 11)")

  # %cd /content/drive/MyDrive/data/transformed/model_results/Importance_Feature_Selection_Grid_Search/
  # filename = 'df_metrics_RF_PP_Impce_Grid_'+str(vocab_length)+'.pkl'
  # #enregistre le modèle
  # pickle.dump([metrics_exp_vocab_length], open(filename, 'wb'))
# Out:
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation / Discrepancy - Procedural
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.777694
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.777184
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.781485
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.781406
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.755525
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.756258
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.777206
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.777059
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.782746
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.781527
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.755906
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.757369
# {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 50}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 11.8 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Aircraft Equipment
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.737074
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.740124
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.780003
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.781334
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.784868
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.785463
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.740619
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.743288
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.777638
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.779118
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.785284
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.785732
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 8.9 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Conflict
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.488919
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.487490
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.601815
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.606202
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.639617
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.642154
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.468464
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.469974
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.597585
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.596010
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.642302
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.642837
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 10.0 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Inflight Event / Encounter
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.361142
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.365346
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.511256
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.511481
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.568655
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.569003
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.371578
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.367188
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.508977
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.508370
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.566383
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.567071
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 8.2 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_ATC Issue
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.333833
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.334654
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.451922
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.455036
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.511326
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.514642
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.327553
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.321684
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.443509
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.444980
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.508483
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.510808
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 11.4 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Altitude
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.253741
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.247597
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.502104
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.499464
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.555997
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.563616
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.220786
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.221341
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.476746
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.474947
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.557667
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.559949
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 10.3 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Track / Heading
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.200530
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.188773
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.404181
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.404274
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.489582
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.492353
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.176328
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.182579
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.391114
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.394264
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.485969
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.491327
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 10.8 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Event / Encounter
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.208508
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.201114
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.396795
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.398966
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.463622
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.468112
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.183672
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.187880
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.390653
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.389065
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.463569
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.467780
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 5.0 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Flight Deck / Cabin / Aircraft Event
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.574341
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.572365
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.673699
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.678426
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.691368
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.696378
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.572911
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.566112
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.670754
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.671783
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.691643
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.692729
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 7.8 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Incursion
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.459141
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.454485
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.568735
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.572101
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.587788
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.602384
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.441730
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.440755
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.567961
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.566439
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.592059
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.600249
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 7.7 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Airspace Violation
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.269905
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.256427
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.484785
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.485293
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.517572
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.520699
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.238114
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.244182
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.474741
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.471390
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.513600
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.520139
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 6.8 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Speed
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.075925
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.073869
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.319615
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.314099
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.401390
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.401365
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.039643
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.034171
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.291999
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.298215
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.397945
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.400987
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 50}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 3.9 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Excursion
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.357883
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.336761
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.504315
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.509139
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.534732
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.538917
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.321338
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.350124
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.500063
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.499928
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.534556
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.537339
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 3.9 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_No Specific Anomaly Occurred
#    params                                              mean_test_score
# 0   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.000000
# 1   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.000000
# 2   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.005634
# 3   {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.016673
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.032462
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.037242
# 6   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.000000
# 7   {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.000000
# 8   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.000000
# 9   {'criterion': 'entropy', 'max_depth': 10, 'max...  0.000000
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  0.027340
# 11  {'criterion': 'entropy', 'max_depth': None, 'm...  0.021706
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 1.5 minutes ---
# (56, 11)  should be (56 , 11)

# %% [markdown]
# ### RF (Grid Search) UNDER SAMPLING (df_metrics_RF_PP_US_Impce_N.pkl)
# PP NARRATIVES, Vocab = N most important tokens

# %%
#vocab_length_list_to_run= [20,30,50] 
# For RF, due to extended computation time, only 20,30,50 could be tested
vocab_length_list_to_run=[20] # to test & run quickly cleaned collab

# %%
clf = ensemble.RandomForestClassifier()
# grid_parameters_dict_RF = { 
#     'n_estimators': [50,100],
#     'max_features': ['auto', 'sqrt'],
#     'max_depth' : [5,10,None],
#     'criterion' :['gini', 'entropy']
# }
grid_parameters_dict_RF = { 
    'n_estimators': [50,100],
    'max_features': ['sqrt'],
    'max_depth' : [5,10,None],
    'criterion' :['gini', 'entropy']
}

# %%
for vocab_length in vocab_length_list_to_run :
  df_second_metrics_compiled=[]
  #for Anomaly in ['Anomaly_Ground Event / Encounter','Anomaly_Conflict']:
  for Anomaly in Anomaly_RootLabels_columns:
    col_importance = 'Importance_' + Anomaly
    liste=dict_top_N_features[Anomaly][vocab_length]
    
    # initialize the objects necesseray function inputs
    data = df['Narrative_PP_stemmed_str']
    target = df[[Anomaly]]
    vectorizer = CountVectorizer(vocabulary=liste)
    
    # Calls the function 
    df_second_metrics = metrics_table_US_grid(data, target, vectorizer, clf)

    # Fill in additionnal columns with metadata
    df_second_metrics['classifier'] = 'Random Forest (Grid)'  # [dt, rf, Word_Embedding, ...]
    df_second_metrics['preprocessing'] = 1          # 0 if raw, 1 if preprocessed
    Count_Vectorizer_opts_label='impce= '+str(vocab_length) 
    df_second_metrics['Count_Vectorizer_opts'] = Count_Vectorizer_opts_label # ['exclude_numerics'; 'min_df = 12'; 'impce= 100'...]
    # Reorder columns
    df_second_metrics = df_second_metrics[['classifier', 'preprocessing', 'undersampling', 'Count_Vectorizer_opts',
                    'anomaly', 'metric', '0', '1', 'accuracy', 'macro avg', 'weighted avg']]

    df_second_metrics_compiled.append(df_second_metrics)
  
  metrics_exp_vocab_length = pd.concat(df_second_metrics_compiled)
  print(metrics_exp_vocab_length.shape, " should be (56 , 11)")

  # %cd /content/drive/MyDrive/data/transformed/model_results/Importance_Feature_Selection_Grid_Search/
  # filename = 'df_metrics_RF_PP_US_Impce_Grid_'+str(vocab_length)+'.pkl'
  # #enregistre le modèle
  # pickle.dump([metrics_exp_vocab_length], open(filename, 'wb'))
# Out:
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Deviation / Discrepancy - Procedural
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.7 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Aircraft Equipment
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.5 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Conflict
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.3 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Inflight Event / Encounter
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.2 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_ATC Issue
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.3 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Deviation - Altitude
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.1 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Deviation - Track / Heading
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.2 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Ground Event / Encounter
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.1 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Flight Deck / Cabin / Aircraft Event
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.1 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Ground Incursion
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.1 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Airspace Violation
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.1 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Deviation - Speed
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.0 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Ground Excursion
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.0 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_No Specific Anomaly Occurred
# Vocabulary length: 20
# Done Prediction
# --- DONE! It took 0.0 minutes ---
# (56, 11)  should be (56 , 11)

# %% [markdown]
# ## GRADIENT BOOSTING

# %% [markdown]
# ### GRADIENT BOOSTING (Grid search) DEFAULT SAMPLING (df_metrics_GB_PP_Impce_N.pkl)
# PP NARRATIVES Vocab = N most important tokens

# %%
#vocab_length_list_to_run= [20,30,50] # 
# For GB, due to extended computation time, only 20,30,50 could be tested
vocab_length_list_to_run=[20] # to test & run quickly cleaned collab

# %%
clf = GradientBoostingClassifier()
    
grid_parameters_dict_GP = {'learning_rate': [0.1,0.5,1], #so called `eta` value
              'max_depth': [3,5],
              'min_samples_leaf': [1,5],
              'n_estimators': [100],#number of trees, change it to 1000 for better results
              }

# %%
for vocab_length in vocab_length_list_to_run :
  df_second_metrics_compiled=[]
  #for Anomaly in ['Anomaly_Ground Event / Encounter','Anomaly_Conflict']:
  for Anomaly in Anomaly_RootLabels_columns:
    col_importance = 'Importance_' + Anomaly
    liste=dict_top_N_features[Anomaly][vocab_length]
    
    # initialize the objects necesseray function inputs
    data = df['Narrative_PP_stemmed_str']
    target = df[[Anomaly]]
    vectorizer = CountVectorizer(vocabulary=liste)
    
    # Calls the function 
    df_second_metrics= metrics_table_grid(data, target, vectorizer, clf,grid_parameters_dict_GP)

    # Fill in additionnal columns with metadata
    df_second_metrics['classifier'] = 'Gradient Boosting (Grid)'  # [dt, rf, Word_Embedding, ...]
    df_second_metrics['preprocessing'] = 1          # 0 if raw, 1 if preprocessed
    Count_Vectorizer_opts_label='impce= '+str(vocab_length) 
    df_second_metrics['Count_Vectorizer_opts'] = Count_Vectorizer_opts_label # ['exclude_numerics'; 'min_df = 12'; 'impce= 100'...]
    # Reorder columns
    df_second_metrics = df_second_metrics[['classifier', 'preprocessing', 'undersampling', 'Count_Vectorizer_opts',
                    'anomaly', 'metric', '0', '1', 'accuracy', 'macro avg', 'weighted avg']]



    df_second_metrics_compiled.append(df_second_metrics)
  
  metrics_exp_vocab_length = pd.concat(df_second_metrics_compiled)
  print(metrics_exp_vocab_length.shape, " should be (56 , 11)")

  # %cd /content/drive/MyDrive/data/transformed/model_results/Importance_Feature_Selection_Grid_Search/
  # filename = 'df_metrics_GB_PP_Impce_Grid_'+str(vocab_length)+'.pkl'
  # #enregistre le modèle
  # pickle.dump([metrics_exp_vocab_length], open(filename, 'wb'))
# Out:
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation / Discrepancy - Procedural
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.778673
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.778576
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.778815
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.778859
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.777497
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.778093
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.775103
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.775009
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.775613
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.775261
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.770608
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.771019
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 4.0 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Aircraft Equipment
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.782378
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.781921
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.797674
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.795703
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.793823
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.794627
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.795101
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.795274
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.793075
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.794151
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.788829
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.792488
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 3.6 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Conflict
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.634576
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.633435
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.657545
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.658567
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.653206
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.654626
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.651606
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.652436
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.646850
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.647614
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.637906
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.634175
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 4.0 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Inflight Event / Encounter
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.541179
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.542137
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.571449
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.570827
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.570515
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.568952
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.573899
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.571953
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.568213
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.568156
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.562438
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.561235
# {'learning_rate': 0.5, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 3.3 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_ATC Issue
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.497735
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.497869
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.527259
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.524303
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.516303
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.517352
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.518410
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.516320
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.512777
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.508598
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.507349
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.503213
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 4.4 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Altitude
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.558471
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.559230
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.578878
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.576990
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.574628
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.574492
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.561007
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.565143
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.552801
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.553883
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.539502
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.538505
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 5.4 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Track / Heading
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.493523
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.492712
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.524875
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.521868
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.517612
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.521174
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.515522
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.513634
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.492436
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.492325
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.487678
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.491879
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 5.3 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Event / Encounter
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.434552
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.437162
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.470151
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.474231
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.462368
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.462490
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.469840
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.466072
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.415879
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.421067
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.422243
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.427608
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 2.9 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Flight Deck / Cabin / Aircraft Event
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.689760
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.690662
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.704359
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.702664
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.690500
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.691660
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.680285
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.685765
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.609442
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.609442
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.573398
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.586501
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 4.5 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Incursion
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.610036
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.611307
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.621161
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.623773
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.595998
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.603329
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.580326
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.583486
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.484295
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.485548
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.466521
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.466354
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 5.6 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Airspace Violation
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.526008
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.519957
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.529445
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.533914
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.508346
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.506770
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.478774
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.490781
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.384837
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.384837
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.432759
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.458481
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 4.2 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Speed
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.405868
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.407577
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.423523
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.416393
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.418009
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.418155
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.402818
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.396787
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.343324
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.342432
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.333229
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.346067
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 3.4 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Excursion
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.555236
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.550427
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.569702
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.563767
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.438532
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.436452
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.505004
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.506244
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.145016
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.144879
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.404868
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.342505
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 3.5 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_No Specific Anomaly Occurred
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.073155
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.038134
# 2   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.061143
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.047672
# 4   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.075407
# 5   {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.036172
# 6   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.079363
# 7   {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.036385
# 8   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.042209
# 9   {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.061536
# 10  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.101834
# 11  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.067288
# {'learning_rate': 1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 1.8 minutes ---
# (56, 11)  should be (56 , 11)

# %% [markdown]
# ### GRADIENT BOOSTING (Grid search)  UNDER SAMPLING (df_metrics_GB_PP_US_Impce_N.pkl)
# PP NARRATIVES Vocab = N most important tokens

# %%
#vocab_length_list_to_run= [20,30,50] # 
# For GB, due to extended computation time, only 20,30,50 could be tested
vocab_length_list_to_run=[20] # to test & run quickly cleaned collab

# %%
clf = GradientBoostingClassifier()
# # To check the parameters of a given classifier
clf.get_params().keys()
# Out:
# dict_keys(['ccp_alpha', 'criterion', 'init', 'learning_rate', 'loss', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_iter_no_change', 'random_state', 'subsample', 'tol', 'validation_fraction', 'verbose', 'warm_start'])

# %%
clf = GradientBoostingClassifier()
    

grid_parameters_dict_GP = {'learning_rate': [0.1,0.5,1], #so called `eta` value
              'max_depth': [3,5],
              'min_samples_leaf': [1,5],
              'n_estimators': [10,50,100], 
              }

# %%
for vocab_length in vocab_length_list_to_run :
  df_second_metrics_compiled=[]
  #for Anomaly in ['Anomaly_Ground Event / Encounter','Anomaly_Conflict']:
  for Anomaly in Anomaly_RootLabels_columns:
    col_importance = 'Importance_' + Anomaly
    liste=dict_top_N_features[Anomaly][vocab_length]
    
    # initialize the objects necesseray function inputs
    data = df['Narrative_PP_stemmed_str']
    target = df[[Anomaly]]
    vectorizer = CountVectorizer(vocabulary=liste)
    
    # Calls the function 
    df_second_metrics= metrics_table_US_grid(data, target, vectorizer, clf,grid_parameters_dict_GP)

    # Fill in additionnal columns with metadata
    df_second_metrics['classifier'] = 'Gradient Boosting (Grid)'  # [dt, rf, Word_Embedding, ...]
    df_second_metrics['preprocessing'] = 1          # 0 if raw, 1 if preprocessed
    Count_Vectorizer_opts_label='impce= '+str(vocab_length) 
    df_second_metrics['Count_Vectorizer_opts'] = Count_Vectorizer_opts_label # ['exclude_numerics'; 'min_df = 12'; 'impce= 100'...]
    # Reorder columns
    df_second_metrics = df_second_metrics[['classifier', 'preprocessing', 'undersampling', 'Count_Vectorizer_opts',
                    'anomaly', 'metric', '0', '1', 'accuracy', 'macro avg', 'weighted avg']]



    df_second_metrics_compiled.append(df_second_metrics)
  
  metrics_exp_vocab_length = pd.concat(df_second_metrics_compiled)
  print(metrics_exp_vocab_length.shape, " should be (56 , 11)")

  # %cd /content/drive/MyDrive/data/transformed/model_results/Importance_Feature_Selection_Grid_Search/
  # filename = 'df_metrics_GB_PP_US_Impce_Grid_'+str(vocab_length)+'.pkl'
  # #enregistre le modèle
  # pickle.dump([metrics_exp_vocab_length], open(filename, 'wb'))
# Out:
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Deviation / Discrepancy - Procedural
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.691535
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.702248
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.698636
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.691535
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.701634
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.699311
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.701560
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.703830
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.701743
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.701948
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.703148
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.701685
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.698085
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.697425
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.698843
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.698340
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.698344
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.699082
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.700539
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.699347
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.698649
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.702715
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.699217
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.698347
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.694375
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.696925
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.696546
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.696399
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.698684
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.697555
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.696683
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.693196
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.689518
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.696858
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.694356
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.691862
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 50}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 5.0 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Aircraft Equipment
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.776358
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.809103
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.828183
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.776358
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.807870
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.828708
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.789177
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.829687
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.830926
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.789185
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.829792
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.831127
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.814137
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.829306
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.828604
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.813540
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.829437
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.829863
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.827401
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.828256
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.826489
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.828084
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.829563
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.828301
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.824540
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.828121
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.827452
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.824414
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.827550
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.827181
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.827677
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.825036
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.824168
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.827358
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.825219
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.823909
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 4.5 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Conflict
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.764889
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.821663
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.830922
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.764889
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.821165
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.829983
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.801242
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.830426
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.833459
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.801892
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.829805
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.832649
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.821296
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.831067
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.830807
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.821500
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.832654
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.832200
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.827273
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.828448
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.825831
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.828300
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.829860
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.828814
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.823552
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.827324
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.827766
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.823436
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.828141
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.828988
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.825702
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.821105
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.820851
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.826072
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.822159
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.822486
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 2.6 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Inflight Event / Encounter
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.709748
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.773142
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.785331
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.709748
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.774108
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.786073
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.750331
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.788640
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.790240
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.751393
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.788416
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.791464
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.775249
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.786013
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.784948
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.775862
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.786334
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.786703
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.784351
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.784447
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.783708
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.785451
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.784797
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.783154
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.781177
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.782106
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.780295
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.779734
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.783714
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.782951
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.782322
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.773809
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.771868
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.784971
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.780819
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.780090
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 2.2 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_ATC Issue
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.753924
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.783176
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.787730
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.753983
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.782133
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.788708
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.773606
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.789466
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.792537
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.772789
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.790093
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.793643
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.776825
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.786453
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.785441
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.776977
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.787204
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.786255
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.787296
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.786182
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.782142
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.788125
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.788069
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.783178
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.784285
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.784204
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.785433
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.783978
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.784351
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.782556
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.782091
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.772746
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.768224
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.781644
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.774323
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.770495
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 2.6 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Deviation - Altitude
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.849925
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.864982
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.866472
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.849925
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.864580
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.866670
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.861188
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.867961
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.868005
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.860640
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.868865
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.867939
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.862670
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.866821
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.865336
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.862148
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.866462
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.864873
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.861520
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.856635
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.853934
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.864256
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.860355
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.853936
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.856165
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.860140
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.855414
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.857215
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.858407
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.856919
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.857442
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.845657
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.837337
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.858227
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.852924
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.845972
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 50}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 1.9 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Deviation - Track / Heading
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.787090
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.830732
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.835949
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.787090
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.830296
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.835596
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.812612
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.836737
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.836547
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.811449
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.837323
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.837482
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.823378
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.832120
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.833165
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.824131
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.833289
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.832492
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.831799
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.828834
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.824277
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.831595
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.830137
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.825188
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.825697
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.826437
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.821020
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.826269
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.825338
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.821602
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.826403
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.811904
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.808670
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.820781
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.816704
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.812711
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 1.9 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Ground Event / Encounter
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.747882
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.798494
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.805597
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.750181
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.798635
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.805942
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.779205
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.805484
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.808624
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.779280
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.805624
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.808275
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.798487
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.803610
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.803320
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.797367
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.805111
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.804294
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.800085
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.800172
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.796635
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.806772
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.804498
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.800839
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.802124
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.801113
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.798461
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.800453
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.800815
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.800678
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.799332
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.793427
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.788791
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.799999
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.795958
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.792008
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 1.0 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Flight Deck / Cabin / Aircraft Event
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.818306
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.859579
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.870227
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.818306
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.859136
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.870391
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.842446
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.874001
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.873206
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.844517
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.872144
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.873414
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.861301
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.871878
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.870203
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.861430
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.869871
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.870234
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.869343
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.868006
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.866292
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.871772
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.869156
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.865606
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.863164
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.868088
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.862291
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.864165
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.864789
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.866173
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.865317
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.860266
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.860147
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.866715
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.864023
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.861263
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 50}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 1.4 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Ground Incursion
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.875090
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.895946
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.897943
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.875090
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.895785
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.897558
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.887914
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.899861
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.897843
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.887559
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.899327
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.899044
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.894743
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.894827
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.892505
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.893750
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.897317
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.894529
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.894053
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.887454
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.886348
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.896987
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.890354
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.888249
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.887809
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.885233
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.882099
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.888018
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.888235
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.885565
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.890311
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.876396
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.876584
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.884864
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.875376
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.876534
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 50}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 1.3 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Airspace Violation
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.820673
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.853680
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.854963
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.820871
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.853444
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.856462
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.837515
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.856331
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.856577
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.839455
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.858425
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.857263
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.852353
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.850372
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.848971
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.851852
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.853719
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.853040
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.850322
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.844299
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.840999
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.857707
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.842504
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.838833
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.849458
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.845787
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.838739
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.851036
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.844722
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.843342
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.843472
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.822709
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.817824
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.847463
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.830565
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.825168
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 50}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.9 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Deviation - Speed
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.883942
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.894388
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.898220
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.883848
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.895505
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.899098
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.891038
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.895211
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.898361
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.890411
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.897879
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.893404
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.893803
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.890904
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.886792
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.894926
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.893719
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.887960
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.892020
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.887371
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.886412
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.898272
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.887608
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.884967
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.893149
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.885991
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.877525
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.892988
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.888490
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.885156
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.884941
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.879082
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.878951
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.883424
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.878263
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.874577
# {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.6 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_Ground Excursion
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.853411
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.889835
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.893403
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.853946
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.888523
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.893838
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.864021
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.892377
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.894193
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.859896
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.893831
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.896436
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.888370
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.895503
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.890223
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.887570
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.893821
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.892179
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.887328
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.887009
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.881535
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.890211
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.887556
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.881497
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.889618
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.884101
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.878467
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.889175
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.880828
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.884002
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.882690
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.869667
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.873884
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.879130
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.878110
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.875794
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.5 minutes ---
# ------- Execution started... -------
#
# Prediction of anomaly : Anomaly_No Specific Anomaly Occurred
# Vocabulary length: 20
#    params                                              mean_test_score
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.409128
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.432779
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.446150
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.407429
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.452389
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'min_sa...  0.450507
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.397604
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.433857
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.450598
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.407727
# 10  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.447237
# 11  {'learning_rate': 0.1, 'max_depth': 5, 'min_sa...  0.451352
# 12  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.445207
# 13  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.457674
# 14  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.458046
# 15  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.447400
# 16  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.449457
# 17  {'learning_rate': 0.5, 'max_depth': 3, 'min_sa...  0.453855
# 18  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.437617
# 19  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.448263
# 20  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.445278
# 21  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.442207
# 22  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.450074
# 23  {'learning_rate': 0.5, 'max_depth': 5, 'min_sa...  0.455804
# 24  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.447874
# 25  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.449314
# 26  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.444137
# 27  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.449342
# 28  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.445148
# 29  {'learning_rate': 1, 'max_depth': 3, 'min_samp...  0.435665
# 30  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.445309
# 31  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.457058
# 32  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.452906
# 33  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.423395
# 34  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.449826
# 35  {'learning_rate': 1, 'max_depth': 5, 'min_samp...  0.436727
# {'learning_rate': 0.5, 'max_depth': 3, 'min_samples_leaf': 1, 'n_estimators': 100}
# Done Grid Optimisation
# Done Prediction
# --- DONE! It took 0.2 minutes ---
# (56, 11)  should be (56 , 11)

# %% [markdown]
# ## SVM

# %% [markdown]
# ### SVM DEFAULT SAMPLING (df_metrics_SVM_PP_Impce_N.pkl)
# PP NARRATIVES Vocab = N most important tokens

# %%
#vocab_length_list_to_run= [20,30,50] #  
# For SVM, due to extended computation time, only 20 , 30, and 50 could be tested
vocab_length_list_to_run=[20] # to test & run quickly cleaned collab

# %%
clf = SVC(C = 1,  kernel = 'rbf')

# %%
for vocab_length in vocab_length_list_to_run :
  df_second_metrics_compiled=[]
  #for Anomaly in ['Anomaly_Ground Event / Encounter','Anomaly_Conflict']:
  for Anomaly in Anomaly_RootLabels_columns:
    col_importance = 'Importance_' + Anomaly
    liste=dict_top_N_features[Anomaly][vocab_length]
    
    # initialize the objects necesseray function inputs
    data = df['Narrative_PP_stemmed_str']
    target = df[[Anomaly]]
    vectorizer = CountVectorizer(vocabulary=liste)
    
    # Calls the function 
    df_second_metrics= metrics_table_grid(data, target, vectorizer, clf)

    # Fill in additionnal columns with metadata
    df_second_metrics['classifier'] = 'SVM'  # [dt, rf, Word_Embedding, ...]
    df_second_metrics['preprocessing'] = 1          # 0 if raw, 1 if preprocessed
    Count_Vectorizer_opts_label='impce= '+str(vocab_length) 
    df_second_metrics['Count_Vectorizer_opts'] = Count_Vectorizer_opts_label # ['exclude_numerics'; 'min_df = 12'; 'impce= 100'...]
    # Reorder columns
    df_second_metrics = df_second_metrics[['classifier', 'preprocessing', 'undersampling', 'Count_Vectorizer_opts',
                    'anomaly', 'metric', '0', '1', 'accuracy', 'macro avg', 'weighted avg']]



    df_second_metrics_compiled.append(df_second_metrics)
  
  metrics_exp_vocab_length = pd.concat(df_second_metrics_compiled)
  print(metrics_exp_vocab_length.shape, " should be (56 , 11)")

  # %cd /content/drive/MyDrive/data/transformed/model_results/Importance_Feature_Selection_Grid_Search/
  # filename = 'df_metrics_SVM_PP_Impce_'+str(vocab_length)+'.pkl'
  # #enregistre le modèle
  # pickle.dump([metrics_exp_vocab_length], open(filename, 'wb'))
# Out:
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation / Discrepancy - Procedural
# Done Prediction
# --- DONE! It took 7.6 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Aircraft Equipment
# Done Prediction
# --- DONE! It took 5.4 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Conflict
# Done Prediction
# --- DONE! It took 3.3 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Inflight Event / Encounter
# Done Prediction
# --- DONE! It took 5.5 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_ATC Issue
# Done Prediction
# --- DONE! It took 4.8 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Altitude
# Done Prediction
# --- DONE! It took 2.6 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Track / Heading
# Done Prediction
# --- DONE! It took 2.6 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Event / Encounter
# Done Prediction
# --- DONE! It took 4.3 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Flight Deck / Cabin / Aircraft Event
# Done Prediction
# --- DONE! It took 2.7 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Incursion
# Done Prediction
# --- DONE! It took 2.5 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Airspace Violation
# Done Prediction
# --- DONE! It took 2.8 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Deviation - Speed
# Done Prediction
# --- DONE! It took 2.5 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_Ground Excursion
# Done Prediction
# --- DONE! It took 0.5 minutes ---
# ------- Execution started... -------
#
# Vocabulary length: 20
# Prediction of anomaly : Anomaly_No Specific Anomaly Occurred
# Done Prediction
# --- DONE! It took 0.2 minutes ---
# (56, 11)  should be (56 , 11)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
