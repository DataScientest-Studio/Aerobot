# %% [markdown]
# # 2022_05_09_TLP_data_exploration
#
# #### by Ioannis STASINOPOULOS
# https://www.linkedin.com/in/ioannis-stasinopoulos/
#
# last update: 2022.05.10

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Set pandas settings to show all data when using .head(), .columns etc.
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df = pd.read_csv('ASRS_10y_data.csv')
# Out:
# /Users/gs/Desktop/sample_project/env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (15,19,40,41,48,67,71,72,78,79,81,89,99) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Import several .csv files and concatenate them in one
# (was necessary only the first time, when several .csv were downloaded from the server)

# files = [] # instantiate empty list

# for i in np.arange(1,9): # we have filenames from 1-8
    
#     # append pandas DataFrames to 'files' --> files becomes list of df's.
#     files.append(pd.read_csv("data/ASRS_DBOnline"+str(i)+".csv", header= 1)) # the 2nd line contains the headers

# # concatenate into 1 df:
# df = pd.concat(files)

# %%
print("We have", len(df), "events to work with.\n\n",
     "/!\ These include unmanned-aircraft-related entries; yet the latter are insignificantly low in number (see below)")
# Out:
# We have 24063 events to work with.
#
#  /!\ These include unmanned-aircraft-related entries; yet the latter are insignificantly low in number (see below)

# %%
df.head()
# Out:
#       ACN    Date Local Time Of Day Locale Reference State Reference  \
# 0  986560  201201         1801-2400       A11.TRACON              AK
# 1  988077  201201         0001-0600      ENA.Airport              AK
# 2  988094  201201         0601-1200      PHX.Airport              AZ
# 3  988431  201201         1801-2400      SDL.Airport              AZ
# 4  989412  201201         0601-1200      LIT.Airport              AR
#
#    Relative Position.Angle.Radial  Relative Position.Distance.Nautical Miles  \
# 0                             NaN                                        NaN
# 1                             NaN                                        NaN
# 2                             NaN                                        NaN
# 3                             NaN                                        NaN
# 4                           240.0                                       35.0
#
#    Altitude.AGL.Single Value  Altitude.MSL.Single Value  \
# 0                        NaN                     8000.0
# 1                        NaN                     2000.0
# 2                        NaN                    15000.0
# 3                        0.0                        NaN
# 4                      600.0                        NaN
#
#    Latitude / Longitude (UAS) Flight Conditions Weather Elements / Visibility  \
# 0                         NaN               NaN                           NaN
# 1                         NaN               IMC                           NaN
# 2                         NaN               VMC                           NaN
# 3                         NaN               NaN                           NaN
# 4                         NaN             Mixed                  Fog; Rain; 1
#
#   Work Environment Factor     Light Ceiling RVR.Single Value  \
# 0                     NaN       NaN     NaN              NaN
# 1                     NaN       NaN     NaN              NaN
# 2                     NaN  Daylight     NaN              NaN
# 3                     NaN       NaN     NaN              NaN
# 4                     NaN  Daylight     700              NaN
#
#           ATC / Advisory Aircraft Operator  \
# 0             TRACON A11          Air Taxi
# 1  Center ZAN; Tower ENA          Air Taxi
# 2             Center ZAB       Air Carrier
# 3              Tower SDL          Personal
# 4             TRACON LIT               FBO
#
#                                Make Model Name Aircraft Zone  Crew Size  \
# 0                           Super King Air 200           NaN        1.0
# 1                     Caravan Undifferentiated           NaN        1.0
# 2        B737 Next Generation Undifferentiated           NaN        2.0
# 3                                       Viking           NaN        1.0
# 4  PA-28 Cherokee/Archer/Dakota/Pillan/Warrior           NaN        1.0
#
#   Operating Under FAR Part Flight Plan    Mission  Nav In Use    Flight Phase  \
# 0                 Part 135         IFR  Passenger         NaN         Descent
# 1                 Part 135         IFR        NaN         NaN  Final Approach
# 2                 Part 121         IFR  Passenger  FMS Or FMC         Descent
# 3                  Part 91         NaN        NaN         NaN            Taxi
# 4                  Part 91        None   Personal         NaN          Cruise
#
#       Route In Use     Airspace Maintenance Status.Maintenance Deferred  \
# 0          Vectors  Class E ANC                                     NaN
# 1  Visual Approach  Class E ZAN                                     NaN
# 2       STAR GEELA  Class E ZAB                                     NaN
# 3             None          NaN                                     NaN
# 4             None  Class G LIT                                     NaN
#
#   Maintenance Status.Records Complete Maintenance Status.Released For Service  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   Maintenance Status.Required / Correct Doc On Board  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Maintenance Status.Maintenance Type  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Maintenance Status.Maintenance Items Involved Cabin Lighting  \
# 0                                           NaN            NaN
# 1                                           NaN            NaN
# 2                                           NaN            NaN
# 3                                           NaN            NaN
# 4                                           NaN            NaN
#
#    Number Of Seats.Number  Passengers On Board.Number  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
#
#    Crew Size Flight Attendant.Number Of Crew  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Airspace Authorization Provider (UAS)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Operating Under Waivers / Exemptions / Authorizations (UAS)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Waivers / Exemptions / Authorizations (UAS)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Airworthiness Certification (UAS) Weight Category (UAS) Configuration (UAS)  \
# 0                               NaN                   NaN                 NaN
# 1                               NaN                   NaN                 NaN
# 2                               NaN                   NaN                 NaN
# 3                               NaN                   NaN                 NaN
# 4                               NaN                   NaN                 NaN
#
#   Flight Operated As (UAS) Flight Operated with Visual Observer (UAS)  \
# 0                      NaN                                        NaN
# 1                      NaN                                        NaN
# 2                      NaN                                        NaN
# 3                      NaN                                        NaN
# 4                      NaN                                        NaN
#
#   Control Mode (UAS) Flying In / Near / Over (UAS) Passenger Capable (UAS)  \
# 0                NaN                           NaN                     NaN
# 1                NaN                           NaN                     NaN
# 2                NaN                           NaN                     NaN
# 3                NaN                           NaN                     NaN
# 4                NaN                           NaN                     NaN
#
#   Type (UAS) Number of UAS Being Controlled (UAS) Aircraft Component  \
# 0        NaN                                  NaN                NaN
# 1        NaN                                  NaN                NaN
# 2        NaN                                  NaN                MCP
# 3        NaN                                  NaN                NaN
# 4        NaN                                  NaN                NaN
#
#   Manufacturer Aircraft Reference              Problem ATC / Advisory.1  \
# 0          NaN                NaN                  NaN              NaN
# 1          NaN                NaN                  NaN              NaN
# 2          NaN                  X  Improperly Operated              NaN
# 3          NaN                NaN                  NaN              NaN
# 4          NaN                NaN                  NaN              NaN
#
#   Aircraft Operator.1 Make Model Name.1  Aircraft Zone.1  Crew Size.1  \
# 0                 NaN               NaN              NaN          NaN
# 1                 NaN               NaN              NaN          NaN
# 2                 NaN               NaN              NaN          NaN
# 3                 NaN               NaN              NaN          NaN
# 4                 NaN               NaN              NaN          NaN
#
#   Operating Under FAR Part.1 Flight Plan.1 Mission.1 Nav In Use.1  \
# 0                        NaN           NaN       NaN          NaN
# 1                        NaN           NaN       NaN          NaN
# 2                        NaN           NaN       NaN          NaN
# 3                        NaN           NaN       NaN          NaN
# 4                        NaN           NaN       NaN          NaN
#
#   Flight Phase.1 Route In Use.1 Airspace.1  \
# 0            NaN            NaN        NaN
# 1            NaN            NaN        NaN
# 2            NaN            NaN        NaN
# 3            NaN            NaN        NaN
# 4            NaN            NaN        NaN
#
#   Maintenance Status.Maintenance Deferred.1  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Maintenance Status.Records Complete.1  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Maintenance Status.Released For Service.1  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Maintenance Status.Required / Correct Doc On Board.1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Maintenance Status.Maintenance Type.1  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Maintenance Status.Maintenance Items Involved.1  Cabin Lighting.1  \
# 0                                             NaN               NaN
# 1                                             NaN               NaN
# 2                                             NaN               NaN
# 3                                             NaN               NaN
# 4                                             NaN               NaN
#
#    Number Of Seats.Number.1  Passengers On Board.Number.1  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#    Crew Size Flight Attendant.Number Of Crew.1  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Airspace Authorization Provider (UAS).1  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Operating Under Waivers / Exemptions / Authorizations (UAS).1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Waivers / Exemptions / Authorizations (UAS).1  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    Airworthiness Certification (UAS).1 Weight Category (UAS).1  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                                  NaN                     NaN
# 4                                  NaN                     NaN
#
#   Configuration (UAS).1  Flight Operated As (UAS).1  \
# 0                   NaN                         NaN
# 1                   NaN                         NaN
# 2                   NaN                         NaN
# 3                   NaN                         NaN
# 4                   NaN                         NaN
#
#    Flight Operated with Visual Observer (UAS).1  Control Mode (UAS).1  \
# 0                                           NaN                   NaN
# 1                                           NaN                   NaN
# 2                                           NaN                   NaN
# 3                                           NaN                   NaN
# 4                                           NaN                   NaN
#
#   Flying In / Near / Over (UAS).1  Passenger Capable (UAS).1  Type (UAS).1  \
# 0                             NaN                        NaN           NaN
# 1                             NaN                        NaN           NaN
# 2                             NaN                        NaN           NaN
# 3                             NaN                        NaN           NaN
# 4                             NaN                        NaN           NaN
#
#   Number of UAS Being Controlled (UAS).1   Location Of Person  \
# 0                                    NaN  Facility A11.TRACON
# 1                                    NaN   Facility ZAN.ARTCC
# 2                                    NaN           Aircraft X
# 3                                    NaN   Facility SDL.Tower
# 4                                    NaN           Aircraft X
#
#   Location In Aircraft Reporter Organization                     Function  \
# 0                  NaN            Government          Departure; Approach
# 1                  NaN            Government                      Enroute
# 2          Flight Deck           Air Carrier  Pilot Flying; First Officer
# 3                  NaN            Government                       Ground
# 4          Flight Deck              Personal                 Single Pilot
#
#                          Qualification  \
# 0    Air Traffic Control Developmental
# 1  Air Traffic Control Fully Certified
# 2                                  NaN
# 3  Air Traffic Control Fully Certified
# 4                  Flight Crew Private
#
#                                           Experience Cabin Activity  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2  Flight Crew Last 90 Days 156; Flight Crew Type...            NaN
# 3                                                NaN            NaN
# 4  Flight Crew Last 90 Days 7; Flight Crew Total ...            NaN
#
#                                        Human Factors  \
# 0                              Situational Awareness
# 1                              Situational Awareness
# 2  Situational Awareness; Workload; Human-Machine...
# 3                   Confusion; Situational Awareness
# 4    Situational Awareness; Training / Qualification
#
#                              Communication Breakdown  \
# 0                                                NaN
# 1                                                NaN
# 2  Party1 Flight Crew; Party2 Flight Crew; Party2...
# 3                                                NaN
# 4                                                NaN
#
#   UAS Communication Breakdown  ASRS Report Number.Accession Number  \
# 0                         NaN                               986560
# 1                         NaN                               988077
# 2                         NaN                               988094
# 3                         NaN                               988431
# 4                         NaN                               989412
#
#   Location Of Person.1 Location In Aircraft.1 Reporter Organization.1  \
# 0                  NaN            Flight Deck                Air Taxi
# 1                  NaN                    NaN                     NaN
# 2           Aircraft X            Flight Deck             Air Carrier
# 3                  NaN                    NaN                     NaN
# 4                  NaN                    NaN                     NaN
#
#                   Function.1                        Qualification.1  \
# 0      Captain; Pilot Flying                                    NaN
# 1                        NaN                                    NaN
# 2  Captain; Pilot Not Flying  Flight Crew Air Transport Pilot (ATP)
# 3                        NaN                                    NaN
# 4                        NaN                                    NaN
#
#                                         Experience.1 Cabin Activity.1  \
# 0  Flight Crew Last 90 Days 46; Flight Crew Total...              NaN
# 1                                                NaN              NaN
# 2  Flight Crew Last 90 Days 141; Flight Crew Type...              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#                                      Human Factors.1  \
# 0                                                NaN
# 1                                                NaN
# 2  Situational Awareness; Human-Machine Interface...
# 3                                                NaN
# 4                                                NaN
#
#   Communication Breakdown.1  UAS Communication Breakdown.1  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
#
#    ASRS Report Number.Accession Number.1  \
# 0                               986993.0
# 1                                    NaN
# 2                               988102.0
# 3                                    NaN
# 4                                    NaN
#
#                                              Anomaly Miss Distance  \
# 0  Deviation - Altitude Excursion From Assigned A...           NaN
# 1  ATC Issue All Types; Deviation / Discrepancy -...           NaN
# 2  Deviation - Altitude Crossing Restriction Not ...           NaN
# 3  Conflict Ground Conflict; Critical; Deviation ...           NaN
# 4  Inflight Event / Encounter CFTT / CFIT; Inflig...           NaN
#
#   Were Passengers Involved In Event  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#                                             Detector When Detected  \
# 0                         Person Air Traffic Control           NaN
# 1                         Person Air Traffic Control           NaN
# 2                                 Person Flight Crew     In-flight
# 3                         Person Air Traffic Control          Taxi
# 4  Automation Aircraft Terrain Warning; Person Fl...     In-flight
#
#                                               Result  \
# 0           Air Traffic Control Issued New Clearance
# 1                      General None Reported / Taken
# 2  Flight Crew Returned To Clearance; Flight Crew...
# 3                      General None Reported / Taken
# 4  Air Traffic Control Provided Assistance; Fligh...
#
#     Contributing Factors / Situations Primary Problem  \
# 0                       Human Factors   Human Factors
# 1   Weather; Human Factors; Procedure   Human Factors
# 2  Procedure; Aircraft; Human Factors        Aircraft
# 3              Airport; Human Factors         Airport
# 4              Human Factors; Weather   Human Factors
#
#                                            Narrative Callback  \
# 0  A BE20 was inbound to ANC via YESKA. He was to...      NaN
# 1  A C208 departed for Kenai. Kenai Tower called ...      NaN
# 2  We were on the GEELA Arrival into PHX and were...      NaN
# 3  While working Ground Control Aircraft X exited...      NaN
# 4  My brother; who is not a pilot; was my only pa...      NaN
#
#                                          Narrative.1 Callback.1  \
# 0  I was descending to 8;000 FT proceeding direct...        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN
#
#                                             Synopsis  Unnamed: 125
# 0  A11 Controller described a descent below MVA; ...           NaN
# 1  ZAN Controller issued a Visual Approach cleara...           NaN
# 2  A B737-NG on the PHX GEELA arrival was vectore...           NaN
# 3  SDL Controller described a near collision with...           NaN
# 4  PA28 pilot reports departing on a local pleasu...           NaN

# %%
list(df.columns)
# Out:
# ['ACN',
#  'Date',
#  'Local Time Of Day',
#  'Locale Reference',
#  'State Reference',
#  'Relative Position.Angle.Radial',
#  'Relative Position.Distance.Nautical Miles',
#  'Altitude.AGL.Single Value',
#  'Altitude.MSL.Single Value',
#  'Latitude / Longitude (UAS)',
#  'Flight Conditions',
#  'Weather Elements / Visibility',
#  'Work Environment Factor',
#  'Light',
#  'Ceiling',
#  'RVR.Single Value',
#  'ATC / Advisory',
#  'Aircraft Operator',
#  'Make Model Name',
#  'Aircraft Zone',
#  'Crew Size',
#  'Operating Under FAR Part',
#  'Flight Plan',
#  'Mission',
#  'Nav In Use',
#  'Flight Phase',
#  'Route In Use',
#  'Airspace',
#  'Maintenance Status.Maintenance Deferred',
#  'Maintenance Status.Records Complete',
#  'Maintenance Status.Released For Service',
#  'Maintenance Status.Required / Correct Doc On Board',
#  'Maintenance Status.Maintenance Type',
#  'Maintenance Status.Maintenance Items Involved',
#  'Cabin Lighting',
#  'Number Of Seats.Number',
#  'Passengers On Board.Number',
#  'Crew Size Flight Attendant.Number Of Crew',
#  'Airspace Authorization Provider (UAS)',
#  'Operating Under Waivers / Exemptions / Authorizations (UAS)',
#  'Waivers / Exemptions / Authorizations (UAS)',
#  'Airworthiness Certification (UAS)',
#  'Weight Category (UAS)',
#  'Configuration (UAS)',
#  'Flight Operated As (UAS)',
#  'Flight Operated with Visual Observer (UAS)',
#  'Control Mode (UAS)',
#  'Flying In / Near / Over (UAS)',
#  'Passenger Capable (UAS)',
#  'Type (UAS)',
#  'Number of UAS Being Controlled (UAS)',
#  'Aircraft Component',
#  'Manufacturer',
#  'Aircraft Reference',
#  'Problem',
#  'ATC / Advisory.1',
#  'Aircraft Operator.1',
#  'Make Model Name.1',
#  'Aircraft Zone.1',
#  'Crew Size.1',
#  'Operating Under FAR Part.1',
#  'Flight Plan.1',
#  'Mission.1',
#  'Nav In Use.1',
#  'Flight Phase.1',
#  'Route In Use.1',
#  'Airspace.1',
#  'Maintenance Status.Maintenance Deferred.1',
#  'Maintenance Status.Records Complete.1',
#  'Maintenance Status.Released For Service.1',
#  'Maintenance Status.Required / Correct Doc On Board.1',
#  'Maintenance Status.Maintenance Type.1',
#  'Maintenance Status.Maintenance Items Involved.1',
#  'Cabin Lighting.1',
#  'Number Of Seats.Number.1',
#  'Passengers On Board.Number.1',
#  'Crew Size Flight Attendant.Number Of Crew.1',
#  'Airspace Authorization Provider (UAS).1',
#  'Operating Under Waivers / Exemptions / Authorizations (UAS).1',
#  'Waivers / Exemptions / Authorizations (UAS).1',
#  'Airworthiness Certification (UAS).1',
#  'Weight Category (UAS).1',
#  'Configuration (UAS).1',
#  'Flight Operated As (UAS).1',
#  'Flight Operated with Visual Observer (UAS).1',
#  'Control Mode (UAS).1',
#  'Flying In / Near / Over (UAS).1',
#  'Passenger Capable (UAS).1',
#  'Type (UAS).1',
#  'Number of UAS Being Controlled (UAS).1',
#  'Location Of Person',
#  'Location In Aircraft',
#  'Reporter Organization',
#  'Function',
#  'Qualification',
#  'Experience',
#  'Cabin Activity',
#  'Human Factors',
#  'Communication Breakdown',
#  'UAS Communication Breakdown',
#  'ASRS Report Number.Accession Number',
#  'Location Of Person.1',
#  'Location In Aircraft.1',
#  'Reporter Organization.1',
#  'Function.1',
#  'Qualification.1',
#  'Experience.1',
#  'Cabin Activity.1',
#  'Human Factors.1',
#  'Communication Breakdown.1',
#  'UAS Communication Breakdown.1',
#  'ASRS Report Number.Accession Number.1',
#  'Anomaly',
#  'Miss Distance',
#  'Were Passengers Involved In Event',
#  'Detector',
#  'When Detected',
#  'Result',
#  'Contributing Factors / Situations',
#  'Primary Problem',
#  'Narrative',
#  'Callback',
#  'Narrative.1',
#  'Callback.1',
#  'Synopsis',
#  'Unnamed: 125']

# %% [markdown]
# #### How many data include a 2nd narrative?

# %%
nar1_all = df[df['Narrative.1'].isna() == False]

# %%
print("Out of a total of", len(df), "entries of events,", "there are", len(nar1_all), "entries that include a 2nd narrative.")
# Out:
# Out of a total of 24063 entries of events, there are 5818 entries that include a 2nd narrative.

# %% [markdown]
# #### Example of an event with 2 narratives

# %%
#nar1_all.head()

# %%
print(nar1_all['Narrative'][9])
# Out:
# During approach to TUS; leg 5 of a 6-leg day; talking to Approach Control; we were cleared direct CALLS for the ILS 11L and cleared to descend to 5;000 FT. We called the airport in sight and were cleared for the visual approach and told to contact Tower. First Officer selected direct POCIB in the FMC; and selected 4;600 FT on the MCP. When we contacted Tower; the Controller said to check altitude and stated the MVA in the area was 5;900 FT. Simultaneously we received a 'Caution Terrain; Caution Obstacle' alert from the GPWS. First Officer executed go-around maneuver. We climbed to clear the alert. Once we were clear of the hazard; we continued our descent to the runway. An s-turn to the south was needed to lose altitude. The terrain feature was in use on both navigation displays; but did not show an immediate threat in front of the airplane. The turn to POCIB was not verbalized; but I was aware of it. This turn only changed our lateral course by a couple of degrees to the right; so I did not initially think it would make a big difference; but it apparently brought us close enough laterally to terrain to trigger the alert.[We needed] verbalization of changes to FMC programming; staying on previously cleared path and altitude at night; even when cleared for a visual approach; especially in mountainous areas. Better monitoring and situational awareness on the part of the Captain/pilot not flying; not trying to salvage the approach under such conditions.

# %%
nar1_all['Narrative.1'][9]
# Out:
# "While on a descent into TUS; we had been given direct CALLS and descend to 5;000 FT. We were high on our profile due to a delayed descent. I had the speedbrakes extended and at some point in the process as we approached 5;000 FT; I extended the landing gear to slow and configure for the approach. Approach asked if we had the airport in sight and we confirmed airport in sight. Approach cleared us for the visual approach and told us to contact Tower. Once cleared for the visual; I selected POCIB in the FMC and went direct and reset the MCP altitude to 4;600 FT. The difference in heading change was less than ten degrees. We were still descending at 250 KTS with speed brake extended and gear down. When we switched to Tower; Tower said 'Check altitude; minimum vectoring in that area is 5;900 FT.' We were descending through 5;300 FT and within a few miles of POCIB. As Tower tells us this; we receive a GPWS Caution; 'Caution Obstacle Caution Terrain.' Even though it was a visual approach; it was at night so we executed the required maneuver per the FOM. We asked Tower if we could take a turn to the south to reconfigure for landing after we were clear of all terrain. The Tower approved and we landed flaps 40; exited the runway; and parked the aircraft. Captain debriefed after parking at the gate. During the event; the terrain mapping feature on the ND display never indicated terrain in front of us. It was black with terrain showing to the north. It is my opinion that had I stayed on the original clearance to CALLS at 5;000 FT or had I been on profile with a normal descent rate; we would not have received the GPWS Caution."

# %%
nar1_all['Synopsis'][9]
# Out:
# 'B737 flight crew experiences an EGPWS terrain caution just after a low altitude alert from the Tower during a night visual approach to Runway 11L at TUS. An immediate climb is initiated.'

# %%
nar1_all['Anomaly'][9]
# Out:
# 'Inflight Event / Encounter CFTT / CFIT; Inflight Event / Encounter Unstabilized Approach'

# %%
nar1_all['Result'][9]
# Out:
# 'Air Traffic Control Issued Advisory / Alert; Flight Crew Took Evasive Action'

# %%
nar1_all['Primary Problem'][9]
# Out:
# 'Human Factors'

# %%
nar1_all['Contributing Factors / Situations'][9]
# Out:
# 'Aircraft; Human Factors; Airport'

# %% [markdown]
# ## Explore features

# %% [markdown]
# ### Features related to manned aircraft

# %%
# List of features to plot using a for-loop (see below)

# Here only *manned* aircraft features
features_manned = [ 
  'Primary Problem',
  'State Reference',
  'Flight Conditions', # IMC: 'Instrument Meteorological IMC Conditions' 
                       # VMC: 'Visual Meteorological Conditions'
  'Work Environment Factor',
  'Light',
  'Aircraft Operator',
  'Crew Size',
  'Crew Size Flight Attendant.Number Of Crew',
  'Mission',
  'Maintenance Status.Maintenance Deferred',
  'Maintenance Status.Records Complete',
  'Maintenance Status.Released For Service',
  'Maintenance Status.Required / Correct Doc On Board',
  'Maintenance Status.Maintenance Type',
  'Maintenance Status.Maintenance Items Involved',
  'Cabin Lighting',
  'Number Of Seats.Number',
  'Passengers On Board.Number',   
  'Manufacturer',
  'Aircraft Reference',
  'Location In Aircraft',
  'Reporter Organization',
  'Were Passengers Involved In Event',
  'When Detected',

###################################################
### To treat separately
###################################################
#  'Cabin Activity', # to treat separately
#  'Communication Breakdown', # to treat separately 
#  'Aircraft Zone', # many NaN's
#  'Operating Under FAR Part', # Federal Aviation Regulation
#  'ATC / Advisory', # The 'advisor' during the event

    
### Features with many instances:
    
# 'Locale Reference', # too many different instances
# 'Relative Position.Angle.Radial'#, # too many different instances
#  'Relative Position.Distance.Nautical Miles',  # too many different instances
#  'Altitude.AGL.Single Value', # too many different instances
#  'Altitude.MSL.Single Value', # too many different instances
#  'Weather Elements / Visibility', # too many different instances
#  'Ceiling', # too many different instances
#  'RVR.Single Value', # Runway Visual Range, too many different instances
#  'Make Model Name', # too many different instances
#  'Aircraft Component', # too many different instances
#  'Location Of Person',  # too many different instances
#  'Miss Distance', # too many different instances
#  'Flight Plan',
#  'Nav In Use', # too many different instances
#  'Flight Phase', # too many different instances
#  'Route In Use', # too many different instances
#  'Airspace', # too many different instances
    

###################################################    
### with some str splitting and RegEx's we can 
### extract interesting numerical information from 
### the features below
###################################################
#  'Problem', # VERY INTERESTING TEXTUAL FEATURE, TO TREAT SEPARATELY
#  'Function',
#  'Qualification',
#  'Experience', 
#  'Human Factors',
#  'Anomaly',
#  'Detector',
#  'Result', # can be used as a recommendation, if we assume that what happened was the best possible solution?
#  'Contributing Factors / Situations',
#  'Callback', # 570 extensive textual entries (+ 27 under 'Callback.1')

    
##################################################
### Additional entries for the above variables ###
##################################################
#  'ATC / Advisory.1',
#  'Aircraft Operator.1',
#  'Make Model Name.1',
#  'Aircraft Zone.1',
#  'Crew Size.1',
#  'Operating Under FAR Part.1',
#  'Flight Plan.1',
#  'Mission.1',
#  'Nav In Use.1',
#  'Flight Phase.1',
#  'Route In Use.1',
#  'Airspace.1',
#  'Maintenance Status.Maintenance Deferred.1',
#  'Maintenance Status.Records Complete.1',
#  'Maintenance Status.Released For Service.1',
#  'Maintenance Status.Required / Correct Doc On Board.1',
#  'Maintenance Status.Maintenance Type.1',
#  'Maintenance Status.Maintenance Items Involved.1',
#  'Cabin Lighting.1',
#  'Number Of Seats.Number.1',
#  'Passengers On Board.Number.1',
#  'Crew Size Flight Attendant.Number Of Crew.1',
#  'Location Of Person.1',
#  'Location In Aircraft.1',
#  'Reporter Organization.1',
#  'Function.1',
#  'Qualification.1',
#  'Experience.1',
#  'Cabin Activity.1',
#  'Human Factors.1',
#  'Communication Breakdown.1',
#  'UAS Communication Breakdown.1',
#  'ASRS Report Number.Accession Number.1',    
#  'Callback.1'
###################################################

###################################################
### Not particularly interesting features
###################################################
#  'ASRS Report Number.Accession Number', # just an entry reference number / unique ID
    
]

# %%
def plot_feats_countplt(features_to_plot):

#    for feat in features_to_plot[:-5:-1]: # plot from the end of the list, to avoid scroll down
     for feat in features_to_plot:

        # Instantiate new figure
        fig = plt.figure(figsize= (12,5))

        # Plot in decreasing order
        sns.countplot(x = df[feat], order = df[feat].value_counts().index)

        # Plot settings
        plt.title(feat, fontsize=20)
        # Rotate x-axis labels if more than 16
        if len(df[feat].unique()) > 16:
            plt.xticks(rotation=90);

# %%
# Call the function        
plot_feats_countplt(features_manned)
# Out:
# /var/folders/1z/4wn61b3d7nn1cnh1x42hr_xc0000gn/T/ipykernel_992/994167210.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize= (12,5))

# %% [markdown]
# ### INSIGHTS
#
# #### /!\  NaNs are not included in the plots !
#
# - 'manufacturer' included 'iPad' or 'GARMIN' --> these refer to electronic equipment rather than aircraft

# %% [markdown]
# ##### Examine 'Communication Breakdown' feature

# %%
list(df[df['Communication Breakdown'] == 'Party1 Flight Crew; Party2 Dispatch; Party2 Other']['Contributing Factors / Situations'])
# Out:
# ['Weather; Human Factors; Company Policy; Airport',
#  'Human Factors',
#  'Human Factors',
#  'Procedure']

# %% [markdown]
# ### Features related to unmanned aerial systems (UAS)
#
# A UAS (Unmanned Aircraft Systems) includes not only the UAV (or drone), but also the person on the ground controlling the flight and the system in place that connects both of them.

# %% [markdown]
# #### Find out how many UAS-entries we have

# %%
features_UAS_all = [
###################################
### FEATURES RELATED TO DRONES  ###
###################################
 'Latitude / Longitude (UAS)',
    'Operating Under Waivers / Exemptions / Authorizations (UAS)',
  'Waivers / Exemptions / Authorizations (UAS)',
  'Airworthiness Certification (UAS)', # Only 'Standard' value
  'Weight Category (UAS)',
  'Configuration (UAS)',
  'Flight Operated As (UAS)',
  'Flight Operated with Visual Observer (UAS)', # BVLOS (Beyond Visual Line of Sight) is a term relating to the operation of UAVs (unmanned aerial vehicles) and drones at distances outside the normal visible range of the pilot.
 'Control Mode (UAS)',
 'Flying In / Near / Over (UAS)',
 'Passenger Capable (UAS)', # There are only NaNs and 'N'
 'Type (UAS)',
 'Number of UAS Being Controlled (UAS)',
 'UAS Communication Breakdown',    
 'Airspace Authorization Provider (UAS)', # only NaN's in this feature --> drop ?

    
##################################################
### Additional entries for the above variables ###
##################################################
 'Airspace Authorization Provider (UAS).1',
 'Operating Under Waivers / Exemptions / Authorizations (UAS).1',
 'Waivers / Exemptions / Authorizations (UAS).1',
 'Airworthiness Certification (UAS).1',
 'Weight Category (UAS).1',
 'Configuration (UAS).1',
 'Flight Operated As (UAS).1',
 'Flight Operated with Visual Observer (UAS).1',
 'Control Mode (UAS).1',
 'Flying In / Near / Over (UAS).1',
 'Passenger Capable (UAS).1',
 'Type (UAS).1',
 'Number of UAS Being Controlled (UAS).1',    
##################################################
]

# %%
# Search and gather the rows that contain non-nan values for any of the UAS features into dataframes

files = [] # instantiate empty list

for feat in features_UAS_all:
    
    # append pandas DataFrames to 'files' --> files becomes list of df's.
    files.append(df.loc[df[feat].isna() == False])

# concatenate df's into 1 df:
df_UAS = pd.concat(files)

# Drop the duplicates; there definitely exist many, because we searched column-by-column
df_UAS = df_UAS.drop_duplicates(keep= 'first')

# %%
print("The data contain", len(df_UAS), "UAS-related entries.")
# Out:
# The data contain 88 UAS-related entries.

# %% [markdown]
# This quantity of UAS entries seems reasonable, because these data have NaN's in many MANNED-aircraft-related features, as shown in the next line. Note that 'Make Model Name' has no NaNs.

# %%
df_UAS.isna().sum()
# Out:
# ACN                                                               0
# Date                                                              0
# Local Time Of Day                                                10
# Locale Reference                                                  1
# State Reference                                                   0
# Relative Position.Angle.Radial                                   69
# Relative Position.Distance.Nautical Miles                        46
# Altitude.AGL.Single Value                                        54
# Altitude.MSL.Single Value                                        42
# Latitude / Longitude (UAS)                                       88
# Flight Conditions                                                 9
# Weather Elements / Visibility                                    43
# Work Environment Factor                                          87
# Light                                                            36
# Ceiling                                                          52
# RVR.Single Value                                                 88
# ATC / Advisory                                                   61
# Aircraft Operator                                                 3
# Make Model Name                                                   0
# Aircraft Zone                                                    88
# Crew Size                                                         9
# Operating Under FAR Part                                          5
# Flight Plan                                                       2
# Mission                                                           4
# Nav In Use                                                       66
# Flight Phase                                                      2
# Route In Use                                                     29
# Airspace                                                         14
# Maintenance Status.Maintenance Deferred                          88
# Maintenance Status.Records Complete                              88
# Maintenance Status.Released For Service                          88
# Maintenance Status.Required / Correct Doc On Board               88
# Maintenance Status.Maintenance Type                              88
# Maintenance Status.Maintenance Items Involved                    88
# Cabin Lighting                                                   88
# Number Of Seats.Number                                           88
# Passengers On Board.Number                                       88
# Crew Size Flight Attendant.Number Of Crew                        88
# Airspace Authorization Provider (UAS)                            88
# Operating Under Waivers / Exemptions / Authorizations (UAS)      74
# Waivers / Exemptions / Authorizations (UAS)                      86
# Airworthiness Certification (UAS)                                87
# Weight Category (UAS)                                            70
# Configuration (UAS)                                              69
# Flight Operated As (UAS)                                         73
# Flight Operated with Visual Observer (UAS)                       77
# Control Mode (UAS)                                               73
# Flying In / Near / Over (UAS)                                    70
# Passenger Capable (UAS)                                          87
# Type (UAS)                                                       72
# Number of UAS Being Controlled (UAS)                             72
# Aircraft Component                                               87
# Manufacturer                                                     88
# Aircraft Reference                                               87
# Problem                                                          87
# ATC / Advisory.1                                                 88
# Aircraft Operator.1                                              85
# Make Model Name.1                                                14
# Aircraft Zone.1                                                  88
# Crew Size.1                                                      86
# Operating Under FAR Part.1                                       87
# Flight Plan.1                                                    83
# Mission.1                                                        85
# Nav In Use.1                                                     88
# Flight Phase.1                                                   70
# Route In Use.1                                                   87
# Airspace.1                                                       24
# Maintenance Status.Maintenance Deferred.1                        88
# Maintenance Status.Records Complete.1                            88
# Maintenance Status.Released For Service.1                        88
# Maintenance Status.Required / Correct Doc On Board.1             88
# Maintenance Status.Maintenance Type.1                            88
# Maintenance Status.Maintenance Items Involved.1                  88
# Cabin Lighting.1                                                 88
# Number Of Seats.Number.1                                         88
# Passengers On Board.Number.1                                     88
# Crew Size Flight Attendant.Number Of Crew.1                      88
# Airspace Authorization Provider (UAS).1                          88
# Operating Under Waivers / Exemptions / Authorizations (UAS).1    87
# Waivers / Exemptions / Authorizations (UAS).1                    86
# Airworthiness Certification (UAS).1                              88
# Weight Category (UAS).1                                          86
# Configuration (UAS).1                                            72
# Flight Operated As (UAS).1                                       88
# Flight Operated with Visual Observer (UAS).1                     88
# Control Mode (UAS).1                                             88
# Flying In / Near / Over (UAS).1                                  22
# Passenger Capable (UAS).1                                        88
# Type (UAS).1                                                     88
# Number of UAS Being Controlled (UAS).1                           81
# Location Of Person                                                3
# Location In Aircraft                                             26
# Reporter Organization                                             9
# Function                                                          1
# Qualification                                                     7
# Experience                                                       26
# Cabin Activity                                                   88
# Human Factors                                                    16
# Communication Breakdown                                          88
# UAS Communication Breakdown                                      87
# ASRS Report Number.Accession Number                               0
# Location Of Person.1                                             81
# Location In Aircraft.1                                           81
# Reporter Organization.1                                          81
# Function.1                                                       80
# Qualification.1                                                  80
# Experience.1                                                     84
# Cabin Activity.1                                                 88
# Human Factors.1                                                  81
# Communication Breakdown.1                                        88
# UAS Communication Breakdown.1                                    88
# ASRS Report Number.Accession Number.1                            80
# Anomaly                                                           0
# Miss Distance                                                    40
# Were Passengers Involved In Event                                85
# Detector                                                          2
# When Detected                                                     6
# Result                                                            3
# Contributing Factors / Situations                                 2
# Primary Problem                                                   4
# Narrative                                                         0
# Callback                                                         74
# Narrative.1                                                      80
# Callback.1                                                       88
# Synopsis                                                          0
# Unnamed: 125                                                     88
# dtype: int64

# %%
df_UAS.head(3)
# Out:
#           ACN    Date Local Time Of Day Locale Reference State Reference  \
# 1021  1806950  202105         0601-1200      LUF.Airport              AZ
# 1041  1836972  202109         1201-1800      SEZ.Airport              AZ
# 1045  1841415  202109         1801-2400      LIT.Airport              AR
#
#       Relative Position.Angle.Radial  \
# 1021                             NaN
# 1041                             NaN
# 1045                             NaN
#
#       Relative Position.Distance.Nautical Miles  Altitude.AGL.Single Value  \
# 1021                                       10.0                      400.0
# 1041                                        5.0                      400.0
# 1045                                       11.0                      190.0
#
#       Altitude.MSL.Single Value  Latitude / Longitude (UAS) Flight Conditions  \
# 1021                        NaN                         NaN               NaN
# 1041                        NaN                         NaN               VMC
# 1045                        NaN                         NaN               VMC
#
#      Weather Elements / Visibility Work Environment Factor     Light Ceiling  \
# 1021                            10                     NaN  Daylight     CLR
# 1041                Turbulence; 10                     NaN  Daylight     CLR
# 1045                            10                     NaN      Dusk     CLR
#
#      RVR.Single Value ATC / Advisory              Aircraft Operator  \
# 1021              NaN            NaN      Commercial Operator (UAS)
# 1041              NaN            NaN  Recreational / Hobbyist (UAS)
# 1045              NaN            NaN  Recreational / Hobbyist (UAS)
#
#                                         Make Model Name Aircraft Zone  \
# 1021                                  DJI Phantom 4 Pro           NaN
# 1041                              Micro UAS; Multirotor           NaN
# 1045  Small UAS (At or above 0.55 lbs and less than ...           NaN
#
#       Crew Size                       Operating Under FAR Part Flight Plan  \
# 1021        1.0                                       Part 107        None
# 1041        2.0  Recreational Operations / Section 44809 (UAS)        None
# 1045        1.0  Recreational Operations / Section 44809 (UAS)        None
#
#                             Mission Nav In Use            Flight Phase  \
# 1021      Surveying / Mapping (UAS)        NaN          Hovering (UAS)
# 1041  Recreational / Hobbyist (UAS)        NaN  Cruise; Hovering (UAS)
# 1045  Recreational / Hobbyist (UAS)        NaN                 Descent
#
#      Route In Use     Airspace Maintenance Status.Maintenance Deferred  \
# 1021          NaN          NaN                                     NaN
# 1041         None          NaN                                     NaN
# 1045         None  Class G LIT                                     NaN
#
#      Maintenance Status.Records Complete  \
# 1021                                 NaN
# 1041                                 NaN
# 1045                                 NaN
#
#      Maintenance Status.Released For Service  \
# 1021                                     NaN
# 1041                                     NaN
# 1045                                     NaN
#
#      Maintenance Status.Required / Correct Doc On Board  \
# 1021                                                NaN
# 1041                                                NaN
# 1045                                                NaN
#
#      Maintenance Status.Maintenance Type  \
# 1021                                 NaN
# 1041                                 NaN
# 1045                                 NaN
#
#      Maintenance Status.Maintenance Items Involved Cabin Lighting  \
# 1021                                           NaN            NaN
# 1041                                           NaN            NaN
# 1045                                           NaN            NaN
#
#       Number Of Seats.Number  Passengers On Board.Number  \
# 1021                     NaN                         NaN
# 1041                     NaN                         NaN
# 1045                     NaN                         NaN
#
#       Crew Size Flight Attendant.Number Of Crew  \
# 1021                                        NaN
# 1041                                        NaN
# 1045                                        NaN
#
#       Airspace Authorization Provider (UAS)  \
# 1021                                    NaN
# 1041                                    NaN
# 1045                                    NaN
#
#      Operating Under Waivers / Exemptions / Authorizations (UAS)  \
# 1021                                                  N
# 1041                                                  N
# 1045                                                  N
#
#      Waivers / Exemptions / Authorizations (UAS)  \
# 1021                                         NaN
# 1041                                         NaN
# 1045                                         NaN
#
#      Airworthiness Certification (UAS) Weight Category (UAS)  \
# 1021                               NaN                 Small
# 1041                               NaN                 Micro
# 1045                               NaN                 Small
#
#      Configuration (UAS) Flight Operated As (UAS)  \
# 1021         Multi-Rotor                     VLOS
# 1041         Multi-Rotor                     VLOS
# 1045         Multi-Rotor                     VLOS
#
#      Flight Operated with Visual Observer (UAS) Control Mode (UAS)  \
# 1021                                        NaN     Manual Control
# 1041                                          Y     Manual Control
# 1045                                          N     Manual Control
#
#                           Flying In / Near / Over (UAS)  \
# 1021  Aircraft / UAS; Open Space / Field; No Drone Zone
# 1041                                      No Drone Zone
# 1045                                   Private Property
#
#      Passenger Capable (UAS) Type (UAS) Number of UAS Being Controlled (UAS)  \
# 1021                     NaN  Purchased                      Number of UAS 1
# 1041                     NaN  Purchased                      Number of UAS 1
# 1045                     NaN  Purchased                      Number of UAS 1
#
#                 Aircraft Component Manufacturer Aircraft Reference  \
# 1021                           NaN          NaN                NaN
# 1041  Ground Control Station (UAS)          NaN                  X
# 1045                           NaN          NaN                NaN
#
#                   Problem ATC / Advisory.1 Aircraft Operator.1  \
# 1021                  NaN              NaN            Military
# 1041  Improperly Operated              NaN                 NaN
# 1045                  NaN              NaN                 NaN
#
#                                 Make Model Name.1  Aircraft Zone.1  \
# 1021                                      Fighter              NaN
# 1041                                          NaN              NaN
# 1045  Small Aircraft; Low Wing; 1 Eng; Fixed Gear              NaN
#
#       Crew Size.1 Operating Under FAR Part.1 Flight Plan.1 Mission.1  \
# 1021          NaN                        NaN           NaN  Training
# 1041          NaN                        NaN           NaN       NaN
# 1045          NaN                        NaN           NaN       NaN
#
#      Nav In Use.1 Flight Phase.1 Route In Use.1                    Airspace.1  \
# 1021          NaN            NaN            NaN  Special Use ALERT AREA A-231
# 1041          NaN            NaN            NaN                           NaN
# 1045          NaN            NaN            NaN                   Class G LIT
#
#      Maintenance Status.Maintenance Deferred.1  \
# 1021                                       NaN
# 1041                                       NaN
# 1045                                       NaN
#
#       Maintenance Status.Records Complete.1  \
# 1021                                    NaN
# 1041                                    NaN
# 1045                                    NaN
#
#       Maintenance Status.Released For Service.1  \
# 1021                                        NaN
# 1041                                        NaN
# 1045                                        NaN
#
#       Maintenance Status.Required / Correct Doc On Board.1  \
# 1021                                                NaN
# 1041                                                NaN
# 1045                                                NaN
#
#      Maintenance Status.Maintenance Type.1  \
# 1021                                   NaN
# 1041                                   NaN
# 1045                                   NaN
#
#      Maintenance Status.Maintenance Items Involved.1  Cabin Lighting.1  \
# 1021                                             NaN               NaN
# 1041                                             NaN               NaN
# 1045                                             NaN               NaN
#
#       Number Of Seats.Number.1  Passengers On Board.Number.1  \
# 1021                       NaN                           NaN
# 1041                       NaN                           NaN
# 1045                       NaN                           NaN
#
#       Crew Size Flight Attendant.Number Of Crew.1  \
# 1021                                          NaN
# 1041                                          NaN
# 1045                                          NaN
#
#       Airspace Authorization Provider (UAS).1  \
# 1021                                      NaN
# 1041                                      NaN
# 1045                                      NaN
#
#      Operating Under Waivers / Exemptions / Authorizations (UAS).1  \
# 1021                                                NaN
# 1041                                                NaN
# 1045                                                NaN
#
#      Waivers / Exemptions / Authorizations (UAS).1  \
# 1021                                           NaN
# 1041                                           NaN
# 1045                                           NaN
#
#       Airworthiness Certification (UAS).1 Weight Category (UAS).1  \
# 1021                                  NaN                     NaN
# 1041                                  NaN                     NaN
# 1045                                  NaN                     NaN
#
#      Configuration (UAS).1  Flight Operated As (UAS).1  \
# 1021                   NaN                         NaN
# 1041                   NaN                         NaN
# 1045                   NaN                         NaN
#
#       Flight Operated with Visual Observer (UAS).1  Control Mode (UAS).1  \
# 1021                                           NaN                   NaN
# 1041                                           NaN                   NaN
# 1045                                           NaN                   NaN
#
#      Flying In / Near / Over (UAS).1  Passenger Capable (UAS).1  Type (UAS).1  \
# 1021                             NaN                        NaN           NaN
# 1041                             NaN                        NaN           NaN
# 1045                             NaN                        NaN           NaN
#
#      Number of UAS Being Controlled (UAS).1             Location Of Person  \
# 1021                                    NaN  Outdoor / Field Station (UAS)
# 1041                                    NaN  Outdoor / Field Station (UAS)
# 1045                                    NaN  Outdoor / Field Station (UAS)
#
#      Location In Aircraft          Reporter Organization  \
# 1021                  NaN      Commercial Operator (UAS)
# 1041                  NaN  Recreational / Hobbyist (UAS)
# 1045                  NaN  Recreational / Hobbyist (UAS)
#
#                                                Function  \
# 1021  Remote PIC (UAS); Person Manipulating Controls...
# 1041  Person Manipulating Controls (UAS); Remote PIC...
# 1045  Remote PIC (UAS); Person Manipulating Controls...
#
#                                     Qualification  \
# 1021               Flight Crew Remote Pilot (UAS)
# 1041  Flight Crew Private; Flight Crew Instrument
# 1045           Other TRUST completion certificate
#
#                                              Experience Cabin Activity  \
# 1021  Flight Crew Last 90 Days (UAS) 25.5; Flight Cr...            NaN
# 1041  Flight Crew Last 90 Days (UAS) 1; Flight Crew ...            NaN
# 1045  Flight Crew Last 90 Days (UAS) 8; Flight Crew ...            NaN
#
#                                           Human Factors  \
# 1021  Training / Qualification; Situational Awarenes...
# 1041  Confusion; Distraction; Human-Machine Interfac...
# 1045    Situational Awareness; Training / Qualification
#
#      Communication Breakdown UAS Communication Breakdown  \
# 1021                     NaN                         NaN
# 1041                     NaN                         NaN
# 1045                     NaN                         NaN
#
#       ASRS Report Number.Accession Number Location Of Person.1  \
# 1021                              1806950                  NaN
# 1041                              1836972                  NaN
# 1045                              1841415                  NaN
#
#      Location In Aircraft.1 Reporter Organization.1 Function.1  \
# 1021                    NaN                     NaN        NaN
# 1041                    NaN                     NaN        NaN
# 1045                    NaN                     NaN        NaN
#
#      Qualification.1 Experience.1 Cabin Activity.1 Human Factors.1  \
# 1021             NaN          NaN              NaN             NaN
# 1041             NaN          NaN              NaN             NaN
# 1045             NaN          NaN              NaN             NaN
#
#      Communication Breakdown.1  UAS Communication Breakdown.1  \
# 1021                       NaN                            NaN
# 1041                       NaN                            NaN
# 1045                       NaN                            NaN
#
#       ASRS Report Number.Accession Number.1  \
# 1021                                    NaN
# 1041                                    NaN
# 1045                                    NaN
#
#                                                 Anomaly  \
# 1021                         Conflict Airborne Conflict
# 1041  Aircraft Equipment Problem Critical; Deviation...
# 1045                                      Conflict NMAC
#
#                      Miss Distance Were Passengers Involved In Event  \
# 1021  Horizontal 500; Vertical 500                               NaN
# 1041                           NaN                               NaN
# 1045  Horizontal 110; Vertical 110                               NaN
#
#                           Detector When Detected  \
# 1021               Person UAS Crew     In-flight
# 1041  Person Visual Observer (UAS)     In-flight
# 1045               Person UAS Crew     In-flight
#
#                                    Result  \
# 1021      Flight Crew Took Evasive Action
# 1041  Aircraft Lost / Unrecoverable (UAS)
# 1045        General None Reported / Taken
#
#         Contributing Factors / Situations Primary Problem  \
# 1021  Human Factors; Chart Or Publication       Ambiguous
# 1041     Human Factors; Aircraft; Weather   Human Factors
# 1045                        Human Factors   Human Factors
#
#                                               Narrative  \
# 1021  I was on a mapping mission for a housing devel...
# 1041  On a typical week-end trip with friends; we wa...
# 1045  I was flying my small UAS when what was possib...
#
#                                                Callback Narrative.1  \
# 1021                                                NaN         NaN
# 1041  Reporter did not provide any additional inform...         NaN
# 1045  Reporter stated the aircraft was a low wing tr...         NaN
#
#      Callback.1                                           Synopsis  \
# 1021        NaN  Remote pilot was flying a UAS 100 ft. below a ...
# 1041        NaN  Recreational UAS pilot had a fly away when the...
# 1045        NaN  Hobby UAS pilot had a near miss with a general...
#
#       Unnamed: 125
# 1021           NaN
# 1041           NaN
# 1045           NaN

# %% [markdown]
# #### Plot UAS features

# %%
features_UAS_to_plot = [
###################################
### FEATURES RELATED TO DRONES  ###
###################################
# 'Latitude / Longitude (UAS)',
    'Operating Under Waivers / Exemptions / Authorizations (UAS)',
  'Waivers / Exemptions / Authorizations (UAS)',
#  'Airworthiness Certification (UAS)', # Only 'Standard' value
  'Weight Category (UAS)',
  'Configuration (UAS)',
  'Flight Operated As (UAS)',
  'Flight Operated with Visual Observer (UAS)', # BVLOS (Beyond Visual Line of Sight) is a term relating to the operation of UAVs (unmanned aerial vehicles) and drones at distances outside the normal visible range of the pilot.
#  'Control Mode (UAS)',
#  'Flying In / Near / Over (UAS)',
#  'Passenger Capable (UAS)', # There are only NaNs and 'N'
#  'Type (UAS)',
#  'Number of UAS Being Controlled (UAS)',
#  'UAS Communication Breakdown',    
#  'Airspace Authorization Provider (UAS)', # only NaN's in this feature --> drop ?

    
##################################################
### Additional entries for the above variables ###
##################################################
#  'Airspace Authorization Provider (UAS).1',
#  'Operating Under Waivers / Exemptions / Authorizations (UAS).1',
#  'Waivers / Exemptions / Authorizations (UAS).1',
#  'Airworthiness Certification (UAS).1',
#  'Weight Category (UAS).1',
#  'Configuration (UAS).1',
#  'Flight Operated As (UAS).1',
#  'Flight Operated with Visual Observer (UAS).1',
#  'Control Mode (UAS).1',
#  'Flying In / Near / Over (UAS).1',
#  'Passenger Capable (UAS).1',
#  'Type (UAS).1',
#  'Number of UAS Being Controlled (UAS).1',    
##################################################
]

# %%
plot_feats_countplt(features_UAS_to_plot)

# %% [markdown]
# # IDEAS
#
# - bin the features that have many different values ?
# - do a plot with Bokeh on a US map that shows the numbers of events wrt state and/or 'Latitude / Longitude (UAS)'. Caution : the last applies to drones.
#
# #### Examine text variables
# - <strike> tokenize, filter stop words for the narratives, and synopsis </strike>
# - <strike> create a word cloud, word histogram for the narratives, and synopsis </strike>
# - do a word histogramm on all narratives simultaneously
# - examine similarity between two narratives (voir module 133? de text summarization)

# %% [markdown]
# ## Remove all UAS-related entries

# %%
# remove rows
df = df.drop(df_UAS.index, axis = 0)

# %%
# Check: 
len(df) + 88
# Out:
# 24063

# %%
# remove UAS-columns
df = df.drop(columns= features_UAS_all)

# %% [markdown]
# ## Find out which features we may use as labels for the narratives

# %% [markdown]
# #### 'Problem'

# %%
list(df['Problem'].unique())
# Out:
# [nan,
#  'Improperly Operated',
#  'Design; Improperly Operated',
#  'Malfunctioning; Design',
#  'Design',
#  'Malfunctioning',
#  'Failed',
#  'Improperly Operated; Design',
#  'Design; Improperly Operated; Malfunctioning',
#  'Improperly Operated; Malfunctioning',
#  'Improperly Operated; Failed',
#  'Malfunctioning; Improperly Operated',
#  'Design; Malfunctioning',
#  'Failed; Malfunctioning',
#  'Malfunctioning; Failed',
#  'Design; Malfunctioning; Improperly Operated',
#  'Failed; Improperly Operated',
#  'Design; Failed',
#  'Failed; Improperly Operated; Malfunctioning',
#  'Improperly Operated; Malfunctioning; Design',
#  'Failed; Design',
#  'Improperly Operated; Failed; Malfunctioning',
#  'Design; Failed; Malfunctioning']

# %%
print('out of', df['Problem'].isna().count(), 'entries', ', we have', df['Problem'].isna().sum(), "NaN's for 'Problem'")
print("Hence, it is not a good label for our data.")
# Out:
# out of 23975 entries , we have 19698 NaN's for 'Problem'
# Hence, it is not a good label for our data.

# %% [markdown]
# ### Examine the most common 'Contributing Factors / Situations' per 'Primary Problem'

# %%
print("There are", df.isna().sum()['Primary Problem'], "entries with Primary Problem == NaN.")
# Out:
# There are 95 entries with Primary Problem == NaN.

# %%
# List of all Primary Problems in the dataset
# exclude the entries, where 'Primary Problem is NaN'
prim_probs = list(df[df['Primary Problem'].isna() == False]['Primary Problem'].unique())

# %%
print("The list of 'Primary Problems' in our dataset:")
prim_probs
# Out:
# The list of 'Primary Problems' in our dataset:
# ['Human Factors',
#  'Aircraft',
#  'Airport',
#  'Procedure',
#  'Ambiguous',
#  'Environment - Non Weather Related',
#  'Company Policy',
#  'Chart Or Publication',
#  'ATC Equipment / Nav Facility / Buildings',
#  'Airspace Structure',
#  'Weather',
#  'Equipment / Tooling',
#  'Manuals',
#  'Staffing',
#  'MEL',
#  'Software and Automation',
#  'Incorrect / Not Installed / Unavailable Part',
#  'Logbook Entry']

# %%
#plt.rcParams.update({'figure.max_open_warning': 0});

for problem in prim_probs:
    
    # Select the data corresponding to a particular Primary Problem
    df_prob = df[df['Primary Problem'] == problem]
    
    print("\nThere are", len(df_prob), "issues with", problem, "being the Primary Problem.")
    print("Among the", len(df_prob), "issues with", problem, "being the Primary Problem, there are", 
          df_prob["Contributing Factors / Situations"].isna().sum(), "NaN's under 'Contributing Factors / Situations'.")
    
    # Make a list of all Contributing Factors for a given Primary Problem:
    cf = list()
    for contr_fact in df_prob['Contributing Factors / Situations']:
        split = contr_fact.split(sep = '; ') # include a space after ';'
        cf = cf + split
        
    #print("For", problem, "the contributing factors are:", set(cf))
    
    # Countplot for the Contributing Factors
    fig = plt.figure(figsize= (10,3))
    sns.countplot(x = cf, order= pd.Series(cf).value_counts().index) # need to transform list to pd.Series for the ordering in countplot()
    plt.xticks(rotation=90)
    plt.title('Contributing Factors for Primary Problem == ' + problem, fontsize=20);
# Out:
# There are 8628 issues with Human Factors being the Primary Problem.
# Among the 8628 issues with Human Factors being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 2474 issues with Aircraft being the Primary Problem.
# Among the 2474 issues with Aircraft being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 776 issues with Airport being the Primary Problem.
# Among the 776 issues with Airport being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 4409 issues with Procedure being the Primary Problem.
# Among the 4409 issues with Procedure being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 2819 issues with Ambiguous being the Primary Problem.
# Among the 2819 issues with Ambiguous being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 801 issues with Environment - Non Weather Related being the Primary Problem.
# Among the 801 issues with Environment - Non Weather Related being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 516 issues with Company Policy being the Primary Problem.
# Among the 516 issues with Company Policy being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 692 issues with Chart Or Publication being the Primary Problem.
# Among the 692 issues with Chart Or Publication being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 781 issues with ATC Equipment / Nav Facility / Buildings being the Primary Problem.
# Among the 781 issues with ATC Equipment / Nav Facility / Buildings being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 596 issues with Airspace Structure being the Primary Problem.
# Among the 596 issues with Airspace Structure being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 972 issues with Weather being the Primary Problem.
# Among the 972 issues with Weather being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 141 issues with Equipment / Tooling being the Primary Problem.
# Among the 141 issues with Equipment / Tooling being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 70 issues with Manuals being the Primary Problem.
# Among the 70 issues with Manuals being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 140 issues with Staffing being the Primary Problem.
# Among the 140 issues with Staffing being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 26 issues with MEL being the Primary Problem.
# Among the 26 issues with MEL being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 18 issues with Software and Automation being the Primary Problem.
# Among the 18 issues with Software and Automation being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 18 issues with Incorrect / Not Installed / Unavailable Part being the Primary Problem.
# Among the 18 issues with Incorrect / Not Installed / Unavailable Part being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.
#
# There are 3 issues with Logbook Entry being the Primary Problem.
# Among the 3 issues with Logbook Entry being the Primary Problem, there are 0 NaN's under 'Contributing Factors / Situations'.

# %% [markdown]
# ### 'Anomaly'

# %%
list(df['Anomaly'].unique())
# Out:
# ['Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Taxiway',
#  'Inflight Event / Encounter CFTT / CFIT; Inflight Event / Encounter VFR In IMC; Inflight Event / Encounter Weather / Turbulence',
#  'Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude',
#  'Conflict NMAC',
#  'Conflict NMAC; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Inflight Event / Encounter Other / Unknown',
#  'Inflight Event / Encounter CFTT / CFIT; Inflight Event / Encounter Unstabilized Approach',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation / Discrepancy - Procedural Other / Unknown; Inflight Event / Encounter Weather / Turbulence',
#  'Inflight Event / Encounter Unstabilized Approach; Inflight Event / Encounter CFTT / CFIT',
#  'Conflict Airborne Conflict; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance',
#  'Airspace Violation All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural FAR',
#  'Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Wake Vortex Encounter',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Ground Event / Encounter Loss Of Aircraft Control',
#  'ATC Issue All Types; Conflict Airborne Conflict',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Undershoot; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Less Severe; Ground Event / Encounter Other / Unknown',
#  'Conflict Airborne Conflict; Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Other / Unknown',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Less Severe',
#  'ATC Issue All Types',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural FAR; Ground Incursion Runway',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'ATC Issue All Types; Conflict NMAC; Inflight Event / Encounter Other / Unknown',
#  'Conflict Airborne Conflict; Inflight Event / Encounter Other / Unknown',
#  'Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Conflict NMAC; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Airborne Conflict',
#  'Aircraft Equipment Problem Less Severe; Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Undershoot; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Aircraft Equipment Problem Less Severe; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Deviation - Speed All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Unstabilized Approach; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Critical',
#  'ATC Issue All Types; Conflict NMAC',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Security; Flight Deck / Cabin / Aircraft Event Other / Unknown',
#  'Aircraft Equipment Problem Less Severe; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Flight Deck / Cabin / Aircraft Event Smoke / Fire / Fumes / Odor; Ground Event / Encounter Other / Unknown',
#  'Aircraft Equipment Problem Less Severe; Deviation - Altitude Undershoot; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Conflict Ground Conflict; Critical; Ground Incursion Runway',
#  'Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Other / Unknown',
#  'Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway; Ground Incursion Taxiway',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Less Severe; Deviation - Altitude Undershoot; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Inflight Event / Encounter Wake Vortex Encounter',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Clearance; Ground Excursion Runway',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Critical; Deviation - Altitude Crossing Restriction Not Met; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Critical; Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Less Severe; Airspace Violation All Types; Deviation / Discrepancy - Procedural FAR',
#  'Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Excursion Taxiway',
#  'Aircraft Equipment Problem Less Severe; Airspace Violation All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Fuel Issue',
#  'Aircraft Equipment Problem Less Severe; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Event / Encounter Other / Unknown; Ground Incursion Runway',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict NMAC; Deviation / Discrepancy - Procedural Clearance',
#  'Aircraft Equipment Problem Critical; Deviation - Altitude Excursion From Assigned Altitude; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Critical; Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Deviation - Altitude Overshoot; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation / Discrepancy - Procedural Clearance; Ground Incursion Taxiway',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Other / Unknown',
#  'Aircraft Equipment Problem Critical; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Fuel Issue',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Critical; Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Critical; Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Less Severe; Flight Deck / Cabin / Aircraft Event Smoke / Fire / Fumes / Odor',
#  'ATC Issue All Types; Deviation - Altitude Overshoot; Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'No Specific Anomaly Occurred All Types',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance',
#  'Airspace Violation All Types; Conflict Airborne Conflict',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'Conflict NMAC; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Fuel Issue',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Less Severe; Airspace Violation All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural FAR',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Landing Without Clearance; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'Deviation / Discrepancy - Procedural FAR',
#  'ATC Issue All Types; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance',
#  'Aircraft Equipment Problem Critical; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Flight Deck / Cabin / Aircraft Event Other / Unknown; Inflight Event / Encounter Other / Unknown',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Wake Vortex Encounter',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Object',
#  'Deviation / Discrepancy - Procedural Other / Unknown',
#  'Deviation - Altitude Excursion From Assigned Altitude; Inflight Event / Encounter Wake Vortex Encounter',
#  'ATC Issue All Types; Inflight Event / Encounter Weather / Turbulence',
#  'Aircraft Equipment Problem Critical; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Clearance',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Event / Encounter Other / Unknown',
#  'Aircraft Equipment Problem Less Severe; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Ground Event / Encounter Object; Ground Excursion Runway',
#  'Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'Inflight Event / Encounter Object',
#  'Conflict NMAC; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Critical; Aircraft Equipment Problem Less Severe; Airspace Violation All Types',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Ground Event / Encounter Other / Unknown',
#  'Airspace Violation All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Aircraft Equipment Problem Less Severe; Airspace Violation All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence; Inflight Event / Encounter Wake Vortex Encounter',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Less Severe; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Unstabilized Approach',
#  'Conflict Airborne Conflict; Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural FAR',
#  'Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Ground Event / Encounter Other / Unknown',
#  'Airspace Violation All Types',
#  'Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Less Severe; Inflight Event / Encounter Other / Unknown',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural FAR; Ground Event / Encounter Other / Unknown; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Weight And Balance',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Taxiway',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Taxiway',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Airborne Conflict; Deviation / Discrepancy - Procedural FAR',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Ground Event / Encounter Aircraft',
#  'ATC Issue All Types; Conflict NMAC; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Airspace Violation All Types; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Runway; Ground Incursion Taxiway',
#  'ATC Issue All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Critical; Ground Excursion Runway; Inflight Event / Encounter Fuel Issue',
#  'ATC Issue All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Conflict NMAC; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Airspace Violation All Types; Conflict Airborne Conflict; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Airspace Violation All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Runway',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Flight Deck / Cabin / Aircraft Event Other / Unknown',
#  'ATC Issue All Types; Airspace Violation All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Ground Incursion Runway',
#  'Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Less Severe; Deviation - Altitude Excursion From Assigned Altitude; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Less Severe; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance',
#  'Airspace Violation All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Runway',
#  nan,
#  'Airspace Violation All Types; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Less Severe; Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Conflict NMAC; Inflight Event / Encounter Bird / Animal',
#  'Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance',
#  'Aircraft Equipment Problem Critical; Deviation / Discrepancy - Procedural Maintenance; Ground Event / Encounter Object; Inflight Event / Encounter Object',
#  'Ground Event / Encounter Ground Strike - Aircraft',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'Deviation / Discrepancy - Procedural Other / Unknown; Ground Event / Encounter Object; Inflight Event / Encounter Object',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Ground Event / Encounter Object; Ground Excursion Runway; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation - Speed All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Inflight Event / Encounter Other / Unknown',
#  'Deviation - Altitude Excursion From Assigned Altitude',
#  'Other Unwanted situation',
#  'Aircraft Equipment Problem Critical; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Flight Deck / Cabin / Aircraft Event Illness / Injury; Inflight Event / Encounter Other / Unknown',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Runway; Inflight Event / Encounter Unstabilized Approach',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Airspace Violation All Types; Deviation / Discrepancy - Procedural FAR',
#  'Inflight Event / Encounter Loss Of Aircraft Control; Inflight Event / Encounter Wake Vortex Encounter',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Inflight Event / Encounter VFR In IMC; Inflight Event / Encounter Weather / Turbulence',
#  'Aircraft Equipment Problem Critical; Inflight Event / Encounter Unstabilized Approach',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT; Inflight Event / Encounter Unstabilized Approach',
#  'ATC Issue All Types; Deviation - Altitude Overshoot; Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Ground Excursion Taxiway',
#  'Ground Event / Encounter Other / Unknown; Ground Incursion Runway',
#  'Conflict NMAC; Ground Event / Encounter Object; Inflight Event / Encounter Object',
#  'Aircraft Equipment Problem Less Severe; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Wake Vortex Encounter',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Ground Event / Encounter Other / Unknown; Inflight Event / Encounter Other / Unknown',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Event / Encounter Object; Inflight Event / Encounter Object',
#  'Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Airborne Conflict; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Other / Unknown',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT',
#  'Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Flight Deck / Cabin / Aircraft Event Other / Unknown; Inflight Event / Encounter CFTT / CFIT',
#  'Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway; Ground Incursion Taxiway; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Airspace Violation All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Ground Excursion Runway; Inflight Event / Encounter CFTT / CFIT',
#  'Deviation / Discrepancy - Procedural Clearance; Ground Event / Encounter Object; Ground Excursion Runway; Inflight Event / Encounter Object',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Altitude Overshoot; Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance',
#  'Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Conflict NMAC; Deviation / Discrepancy - Procedural FAR; Inflight Event / Encounter Wake Vortex Encounter',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Conflict NMAC; Conflict Ground Conflict; Less Severe; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Less Severe; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Conflict Airborne Conflict; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance',
#  'Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude; Deviation - Altitude Undershoot; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Weight And Balance',
#  'ATC Issue All Types; Deviation - Altitude Overshoot; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Airborne Conflict; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Object',
#  'Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Less Severe; Inflight Event / Encounter Weather / Turbulence',
#  'Conflict NMAC; Inflight Event / Encounter Object',
#  'ATC Issue All Types; Aircraft Equipment Problem Less Severe; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Landing Without Clearance',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Airspace Violation All Types; Conflict NMAC; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Landing Without Clearance; Ground Incursion Runway; Inflight Event / Encounter Weather / Turbulence',
#  'Aircraft Equipment Problem Less Severe; Deviation - Speed All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Conflict NMAC; Inflight Event / Encounter Other / Unknown',
#  'Deviation / Discrepancy - Procedural FAR; Inflight Event / Encounter Weather / Turbulence; Inflight Event / Encounter VFR In IMC',
#  'Inflight Event / Encounter Object; Inflight Event / Encounter Unstabilized Approach',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Taxiway',
#  'ATC Issue All Types; Aircraft Equipment Problem Less Severe; Conflict Airborne Conflict',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Other / Unknown',
#  'ATC Issue All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Airspace Violation All Types; Conflict Airborne Conflict',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Aircraft Equipment Problem Less Severe; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Airborne Conflict; Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation - Altitude Undershoot; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation / Discrepancy - Procedural Hazardous Material Violation; Deviation / Discrepancy - Procedural Published Material / Policy; Flight Deck / Cabin / Aircraft Event Other / Unknown',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Ground Event / Encounter Other / Unknown; Inflight Event / Encounter Wake Vortex Encounter',
#  'Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural FAR',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Airspace Violation All Types; Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Clearance',
#  'Conflict Ground Conflict; Less Severe',
#  'Airspace Violation All Types; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Other / Unknown',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Fuel Issue',
#  'ATC Issue All Types; Airspace Violation All Types; Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude',
#  'Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Event / Encounter Other / Unknown',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Unstabilized Approach',
#  'ATC Issue All Types; Ground Event / Encounter Other / Unknown',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Runway',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Maintenance',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Event / Encounter Loss Of Aircraft Control; Inflight Event / Encounter Wake Vortex Encounter',
#  'Conflict NMAC; Deviation - Altitude Excursion From Assigned Altitude; Deviation - Track / Heading All Types',
#  'ATC Issue All Types; Conflict NMAC; Deviation - Track / Heading All Types',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Other / Unknown',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Airborne Conflict; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Deviation - Altitude Excursion From Assigned Altitude; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Other / Unknown',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural FAR',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Fuel Issue; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Conflict NMAC; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Wake Vortex Encounter',
#  'Conflict Airborne Conflict; Deviation / Discrepancy - Procedural FAR; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Conflict NMAC; Deviation / Discrepancy - Procedural Other / Unknown',
#  'Conflict Ground Conflict; Critical',
#  'Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Conflict NMAC; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Unstabilized Approach',
#  'Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Clearance; Ground Event / Encounter Loss Of Aircraft Control; Ground Incursion Runway',
#  'ATC Issue All Types; Deviation - Track / Heading All Types; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Ground Event / Encounter Vehicle',
#  'Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Wake Vortex Encounter',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Wake Vortex Encounter',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Wake Vortex Encounter',
#  'ATC Issue All Types; Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Event / Encounter Other / Unknown',
#  'ATC Issue All Types; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT',
#  'Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Wake Vortex Encounter; Inflight Event / Encounter Loss Of Aircraft Control',
#  'ATC Issue All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Ground Event / Encounter Ground Strike - Aircraft; Ground Event / Encounter Loss Of Aircraft Control',
#  'ATC Issue All Types; Deviation - Altitude Overshoot; Deviation - Altitude Crossing Restriction Not Met; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Clearance',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Fuel Issue',
#  'Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural FAR; Ground Incursion Runway',
#  'ATC Issue All Types; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Runway',
#  'ATC Issue All Types; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT',
#  'Inflight Event / Encounter Weather / Turbulence',
#  'Deviation / Discrepancy - Procedural Hazardous Material Violation; Deviation / Discrepancy - Procedural Published Material / Policy; Flight Deck / Cabin / Aircraft Event Illness / Injury; Ground Incursion Taxiway',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation - Speed All Types; Inflight Event / Encounter Weather / Turbulence',
#  'Airspace Violation All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural FAR',
#  'Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'ATC Issue All Types; Conflict Ground Conflict; Critical; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Taxiway',
#  'ATC Issue All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Weather / Turbulence; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural FAR; Inflight Event / Encounter Weather / Turbulence; Inflight Event / Encounter Fuel Issue',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Unstabilized Approach; Inflight Event / Encounter Weather / Turbulence',
#  'Conflict Airborne Conflict; Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation - Speed All Types; Deviation - Track / Heading All Types; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Aircraft Equipment Problem Less Severe; Ground Event / Encounter Loss Of Aircraft Control; Inflight Event / Encounter Weather / Turbulence',
#  'Airspace Violation All Types; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Deviation - Altitude Excursion From Assigned Altitude; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Weather / Turbulence; Inflight Event / Encounter Unstabilized Approach',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Ground Event / Encounter Object',
#  'ATC Issue All Types; Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Taxiway',
#  'Aircraft Equipment Problem Less Severe; Conflict Airborne Conflict; Inflight Event / Encounter Wake Vortex Encounter',
# ...
#  'ATC Issue All Types; Airspace Violation All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Undershoot; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Excursion Runway',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Inflight Event / Encounter Fuel Issue; Inflight Event / Encounter Weather / Turbulence',
#  'Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway; Ground Incursion Taxiway',
#  'Deviation - Speed All Types; Deviation / Discrepancy - Procedural FAR; Inflight Event / Encounter CFTT / CFIT; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Taxiway',
#  'Ground Event / Encounter Loss Of Aircraft Control; Ground Excursion Runway; Inflight Event / Encounter Wake Vortex Encounter',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Clearance; Ground Event / Encounter Other / Unknown; Ground Incursion Taxiway',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation - Speed All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Airspace Violation All Types; Conflict Airborne Conflict; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Ground Conflict; Critical; Ground Event / Encounter Vehicle',
#  'Aircraft Equipment Problem Less Severe; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Aircraft Equipment Problem Less Severe; Ground Event / Encounter Ground Strike - Aircraft; Inflight Event / Encounter Unstabilized Approach; Inflight Event / Encounter Weather / Turbulence',
#  'Inflight Event / Encounter Loss Of Aircraft Control; Inflight Event / Encounter Unstabilized Approach; Inflight Event / Encounter Wake Vortex Encounter',
#  'Airspace Violation All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Object',
#  'Airspace Violation All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Runway',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'Flight Deck / Cabin / Aircraft Event Illness / Injury; Inflight Event / Encounter Weather / Turbulence',
#  'Aircraft Equipment Problem Less Severe; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Other / Unknown',
#  'ATC Issue All Types; Aircraft Equipment Problem Critical; Deviation / Discrepancy - Procedural Landing Without Clearance',
#  'Ground Event / Encounter Loss Of Aircraft Control; Ground Event / Encounter Ground Strike - Aircraft',
#  'Inflight Event / Encounter Wake Vortex Encounter; Inflight Event / Encounter Weather / Turbulence; Inflight Event / Encounter Unstabilized Approach',
#  'ATC Issue All Types; Deviation - Speed All Types',
#  'Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Ground Event / Encounter Object; Inflight Event / Encounter Loss Of Aircraft Control; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Other / Unknown',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Flight Deck / Cabin / Aircraft Event Other / Unknown',
#  'Aircraft Equipment Problem Less Severe; Deviation - Altitude Overshoot; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Flight Deck / Cabin / Aircraft Event Other / Unknown',
#  'Deviation - Altitude Undershoot; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Deviation - Altitude Overshoot; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Deviation - Altitude Overshoot; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Taxiway',
#  'Conflict Ground Conflict; Critical; Flight Deck / Cabin / Aircraft Event Illness / Injury',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Deviation - Altitude Crossing Restriction Not Met; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Ground Incursion Taxiway',
#  'ATC Issue All Types; Conflict Airborne Conflict; Inflight Event / Encounter Unstabilized Approach',
#  'ATC Issue All Types; Airspace Violation All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict NMAC; Deviation / Discrepancy - Procedural Published Material / Policy; Flight Deck / Cabin / Aircraft Event Other / Unknown',
#  'Conflict NMAC; Inflight Event / Encounter Unstabilized Approach',
#  'ATC Issue All Types; Aircraft Equipment Problem Less Severe; Airspace Violation All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT',
#  'Conflict NMAC; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR',
#  'ATC Issue All Types; Conflict Airborne Conflict; Conflict NMAC; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Conflict Airborne Conflict; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Less Severe; Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Unstabilized Approach',
#  'Aircraft Equipment Problem Less Severe; Deviation - Speed All Types; Inflight Event / Encounter Wake Vortex Encounter',
#  'Ground Event / Encounter Loss Of Aircraft Control; Ground Event / Encounter Ground Strike - Aircraft; Ground Excursion Runway; Inflight Event / Encounter Weather / Turbulence',
#  'Ground Event / Encounter Ground Strike - Aircraft; Inflight Event / Encounter Weather / Turbulence; Inflight Event / Encounter Wake Vortex Encounter',
#  'ATC Issue All Types; Conflict Ground Conflict; Critical; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Taxiway',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Ground Incursion Runway; Ground Incursion Taxiway',
#  'ATC Issue All Types; Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Clearance',
#  'Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy; Flight Deck / Cabin / Aircraft Event Passenger Electronic Device; Flight Deck / Cabin / Aircraft Event Passenger Misconduct',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural FAR; Inflight Event / Encounter CFTT / CFIT',
#  'ATC Issue All Types; Deviation - Altitude Overshoot; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Altitude Crossing Restriction Not Met',
#  'Conflict NMAC; Deviation - Altitude Excursion From Assigned Altitude',
#  'Conflict Airborne Conflict; Deviation - Altitude Crossing Restriction Not Met; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR',
#  'ATC Issue All Types; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway',
#  'Aircraft Equipment Problem Less Severe; Deviation - Track / Heading All Types; Inflight Event / Encounter Loss Of Aircraft Control; Inflight Event / Encounter Unstabilized Approach',
#  'ATC Issue All Types; Ground Event / Encounter Person / Animal / Bird',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural FAR; Inflight Event / Encounter Unstabilized Approach; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Wake Vortex Encounter',
#  'Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Weight And Balance; Ground Event / Encounter Ground Strike - Aircraft',
#  'Aircraft Equipment Problem Less Severe; Inflight Event / Encounter Fuel Issue',
#  'ATC Issue All Types; Deviation - Altitude Overshoot; Inflight Event / Encounter CFTT / CFIT',
#  'Deviation - Speed All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter CFTT / CFIT; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Inflight Event / Encounter Loss Of Aircraft Control; Inflight Event / Encounter Wake Vortex Encounter',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Wake Vortex Encounter',
#  'ATC Issue All Types; Aircraft Equipment Problem Less Severe; Deviation - Speed All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Unstabilized Approach',
#  'Airspace Violation All Types; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural FAR',
#  'ATC Issue All Types; Airspace Violation All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR',
#  'Aircraft Equipment Problem Less Severe; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Unstabilized Approach',
#  'ATC Issue All Types; Conflict Airborne Conflict; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Weather / Turbulence',
#  'Aircraft Equipment Problem Less Severe; Flight Deck / Cabin / Aircraft Event Other / Unknown; Inflight Event / Encounter Weather / Turbulence',
#  'Deviation / Discrepancy - Procedural Clearance; Ground Incursion Runway; Inflight Event / Encounter Weather / Turbulence',
#  'Inflight Event / Encounter Wake Vortex Encounter; Inflight Event / Encounter Unstabilized Approach',
#  'Deviation - Altitude Excursion From Assigned Altitude; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Clearance; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Deviation - Speed All Types; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'ATC Issue All Types; Aircraft Equipment Problem Critical; Conflict Airborne Conflict; Deviation / Discrepancy - Procedural Published Material / Policy',
#  'Aircraft Equipment Problem Less Severe; Inflight Event / Encounter Unstabilized Approach; Inflight Event / Encounter Bird / Animal',
#  'ATC Issue All Types; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence; Inflight Event / Encounter CFTT / CFIT',
#  'Deviation - Altitude Overshoot; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Published Material / Policy; Inflight Event / Encounter Weather / Turbulence',
#  'ATC Issue All Types; Aircraft Equipment Problem Less Severe; Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Conflict Ground Conflict; Less Severe; Deviation - Track / Heading All Types; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural FAR; Deviation / Discrepancy - Procedural Clearance',
#  'ATC Issue All Types; Deviation / Discrepancy - Procedural Clearance; Deviation / Discrepancy - Procedural FAR; Ground Incursion Runway; Ground Incursion Taxiway',
#  ...]

# %%
# Make a list of all Anomaly entries
anomalies = list()
for entry in df['Anomaly']:
    split = str(entry).split(sep = '; ') # include a space after ';'
    anomalies = anomalies + split

# Countplot for Anomaly:
fig = plt.figure(figsize= (18,7))

sns.countplot(x = anomalies, order= pd.Series(anomalies).value_counts().index) # need to transform list to pd.Series for the ordering in countplot()
plt.xticks(rotation=90)
plt.title('Anomaly', fontsize=20);

# %% [markdown]
# ### Is 'Anomaly' the label our robot should corretly label the narratives with...?
#
# Note:
#
# - each narrative can be labelled with several anomalies

# %% [markdown]
# ### 'Human Factors'

# %% [markdown]
# There is a top-level feature in the dataset referring to the 'Human Factors' in more detail.

# %%
len(df["Human Factors"])
# Out:
# 23975

# %%
print("From a total of", len(df["Human Factors"]), "entries, there are", df['Human Factors'].isna().sum(), "non-NaN entries.")
# Out:
# From a total of 23975 entries, there are 3981 non-NaN entries.

# %%
list(df['Human Factors'].unique())
# Out:
# ['Situational Awareness',
#  'Situational Awareness; Workload; Human-Machine Interface; Communication Breakdown; Confusion',
#  'Confusion; Situational Awareness',
#  'Situational Awareness; Training / Qualification',
#  'Other / Unknown',
#  nan,
#  'Situational Awareness; Distraction; Time Pressure; Communication Breakdown',
#  'Communication Breakdown',
#  'Training / Qualification; Situational Awareness',
#  'Distraction; Situational Awareness; Workload',
#  'Communication Breakdown; Situational Awareness; Confusion',
#  'Situational Awareness; Training / Qualification; Confusion',
#  'Communication Breakdown; Confusion; Situational Awareness',
#  'Distraction; Situational Awareness; Confusion',
#  'Communication Breakdown; Other / Unknown',
#  'Communication Breakdown; Situational Awareness',
#  'Training / Qualification; Situational Awareness; Human-Machine Interface; Time Pressure',
#  'Time Pressure; Physiological - Other; Distraction; Confusion; Situational Awareness',
#  'Human-Machine Interface',
#  'Situational Awareness; Distraction',
#  'Time Pressure; Human-Machine Interface; Distraction; Communication Breakdown',
#  'Communication Breakdown; Situational Awareness; Time Pressure; Workload',
#  'Communication Breakdown; Distraction; Situational Awareness',
#  'Time Pressure; Workload; Distraction; Communication Breakdown',
#  'Situational Awareness; Confusion; Training / Qualification; Communication Breakdown',
#  'Communication Breakdown; Confusion; Time Pressure',
#  'Confusion; Human-Machine Interface',
#  'Confusion; Distraction; Situational Awareness',
#  'Distraction; Human-Machine Interface; Communication Breakdown; Workload; Time Pressure; Confusion',
#  'Situational Awareness; Communication Breakdown; Confusion',
#  'Distraction',
#  'Confusion; Human-Machine Interface; Situational Awareness',
#  'Communication Breakdown; Confusion',
#  'Training / Qualification; Situational Awareness; Human-Machine Interface; Communication Breakdown',
#  'Training / Qualification; Situational Awareness; Communication Breakdown; Distraction',
#  'Distraction; Situational Awareness; Communication Breakdown',
#  'Confusion',
#  'Situational Awareness; Confusion; Communication Breakdown',
#  'Human-Machine Interface; Training / Qualification',
#  'Confusion; Training / Qualification',
#  'Distraction; Situational Awareness; Human-Machine Interface',
#  'Confusion; Situational Awareness; Communication Breakdown',
#  'Human-Machine Interface; Situational Awareness',
#  'Confusion; Distraction; Training / Qualification',
#  'Human-Machine Interface; Situational Awareness; Confusion',
#  'Situational Awareness; Distraction; Confusion; Communication Breakdown',
#  'Troubleshooting; Human-Machine Interface; Distraction; Confusion',
#  'Confusion; Situational Awareness; Training / Qualification',
#  'Training / Qualification; Distraction; Communication Breakdown; Situational Awareness',
#  'Situational Awareness; Communication Breakdown; Confusion; Training / Qualification',
#  'Training / Qualification; Confusion; Human-Machine Interface; Situational Awareness',
#  'Human-Machine Interface; Situational Awareness; Communication Breakdown; Confusion',
#  'Confusion; Human-Machine Interface; Situational Awareness; Troubleshooting',
#  'Situational Awareness; Communication Breakdown; Distraction',
#  'Troubleshooting; Situational Awareness; Human-Machine Interface; Distraction; Confusion; Workload',
#  'Human-Machine Interface; Confusion',
#  'Human-Machine Interface; Time Pressure',
#  'Communication Breakdown; Confusion; Training / Qualification',
#  'Communication Breakdown; Training / Qualification; Time Pressure',
#  'Other / Unknown; Training / Qualification',
#  'Workload; Distraction; Situational Awareness; Communication Breakdown',
#  'Communication Breakdown; Confusion; Situational Awareness; Fatigue',
#  'Physiological - Other',
#  'Situational Awareness; Communication Breakdown',
#  'Distraction; Workload; Situational Awareness; Communication Breakdown',
#  'Communication Breakdown; Confusion; Human-Machine Interface; Situational Awareness; Workload',
#  'Distraction; Physiological - Other',
#  'Situational Awareness; Distraction; Communication Breakdown; Workload',
#  'Other / Unknown; Situational Awareness',
#  'Communication Breakdown; Training / Qualification; Situational Awareness; Confusion; Workload',
#  'Distraction; Human-Machine Interface',
#  'Distraction; Workload',
#  'Situational Awareness; Communication Breakdown; Other / Unknown',
#  'Workload; Distraction; Confusion; Communication Breakdown',
#  'Communication Breakdown; Confusion; Human-Machine Interface; Distraction',
#  'Situational Awareness; Human-Machine Interface; Confusion; Communication Breakdown',
#  'Workload; Troubleshooting; Situational Awareness; Distraction; Confusion',
#  'Distraction; Confusion; Communication Breakdown',
#  'Distraction; Confusion; Communication Breakdown; Situational Awareness',
#  'Time Pressure; Situational Awareness; Communication Breakdown',
#  'Time Pressure; Communication Breakdown; Situational Awareness',
#  'Fatigue; Human-Machine Interface; Distraction',
#  'Communication Breakdown; Distraction; Time Pressure',
#  'Communication Breakdown; Distraction',
#  'Confusion; Distraction; Situational Awareness; Communication Breakdown',
#  'Distraction; Time Pressure; Communication Breakdown; Confusion',
#  'Situational Awareness; Confusion',
#  'Communication Breakdown; Situational Awareness; Time Pressure',
#  'Distraction; Time Pressure; Situational Awareness; Human-Machine Interface; Confusion',
#  'Troubleshooting; Distraction',
#  'Confusion; Human-Machine Interface; Training / Qualification',
#  'Distraction; Situational Awareness',
#  'Human-Machine Interface; Situational Awareness; Confusion; Distraction',
#  'Distraction; Troubleshooting; Communication Breakdown; Confusion',
#  'Confusion; Human-Machine Interface; Situational Awareness; Workload',
#  'Communication Breakdown; Situational Awareness; Distraction; Time Pressure',
#  'Communication Breakdown; Confusion; Distraction',
#  'Time Pressure; Workload; Communication Breakdown',
#  'Situational Awareness; Human-Machine Interface',
#  'Confusion; Other / Unknown',
#  'Communication Breakdown; Training / Qualification',
#  'Workload; Situational Awareness; Distraction; Communication Breakdown',
#  'Training / Qualification',
#  'Confusion; Communication Breakdown; Distraction',
#  'Distraction; Other / Unknown',
#  'Distraction; Communication Breakdown; Confusion',
#  'Training / Qualification; Situational Awareness; Confusion; Distraction',
#  'Workload; Situational Awareness; Distraction; Confusion; Communication Breakdown; Training / Qualification',
#  'Troubleshooting; Distraction; Confusion; Communication Breakdown; Situational Awareness',
#  'Communication Breakdown; Confusion; Distraction; Situational Awareness; Troubleshooting',
#  'Communication Breakdown; Confusion; Distraction; Situational Awareness; Workload',
#  'Communication Breakdown; Time Pressure; Situational Awareness',
#  'Confusion; Troubleshooting',
#  'Training / Qualification; Confusion',
#  'Confusion; Workload; Troubleshooting; Training / Qualification; Human-Machine Interface',
#  'Human-Machine Interface; Fatigue',
#  'Workload; Confusion; Communication Breakdown',
#  'Situational Awareness; Communication Breakdown; Confusion; Distraction; Training / Qualification',
#  'Distraction; Communication Breakdown',
#  'Confusion; Troubleshooting; Communication Breakdown; Situational Awareness; Distraction',
#  'Confusion; Communication Breakdown; Human-Machine Interface',
#  'Troubleshooting; Workload; Time Pressure; Distraction; Confusion',
#  'Troubleshooting; Situational Awareness; Confusion; Distraction',
#  'Time Pressure; Confusion',
#  'Situational Awareness; Distraction; Communication Breakdown; Confusion',
#  'Time Pressure; Situational Awareness; Distraction; Communication Breakdown; Confusion',
#  'Distraction; Situational Awareness; Time Pressure',
#  'Distraction; Situational Awareness; Troubleshooting; Workload; Communication Breakdown; Confusion',
#  'Communication Breakdown; Confusion; Situational Awareness; Training / Qualification',
#  'Communication Breakdown; Time Pressure',
#  'Situational Awareness; Time Pressure; Distraction; Workload; Communication Breakdown; Confusion',
#  'Distraction; Troubleshooting; Workload',
#  'Distraction; Situational Awareness; Troubleshooting; Confusion',
#  'Situational Awareness; Troubleshooting; Workload; Confusion; Distraction',
#  'Workload; Troubleshooting; Time Pressure; Situational Awareness; Distraction; Confusion; Communication Breakdown',
#  'Training / Qualification; Human-Machine Interface; Confusion; Workload',
#  'Communication Breakdown; Confusion; Distraction; Situational Awareness',
#  'Confusion; Situational Awareness; Troubleshooting; Communication Breakdown',
#  'Workload; Human-Machine Interface; Situational Awareness',
#  'Fatigue',
#  'Confusion; Distraction; Troubleshooting; Time Pressure; Situational Awareness',
#  'Confusion; Communication Breakdown; Distraction; Situational Awareness',
#  'Time Pressure; Situational Awareness; Distraction; Confusion',
#  'Human-Machine Interface; Workload; Distraction; Time Pressure; Situational Awareness; Confusion; Communication Breakdown',
#  'Distraction; Communication Breakdown; Confusion; Situational Awareness',
#  'Situational Awareness; Workload; Communication Breakdown; Distraction',
#  'Situational Awareness; Workload; Communication Breakdown; Confusion; Distraction',
#  'Workload; Situational Awareness; Human-Machine Interface; Training / Qualification',
#  'Workload; Distraction; Confusion',
#  'Time Pressure; Situational Awareness; Confusion; Communication Breakdown',
#  'Training / Qualification; Confusion; Distraction',
#  'Situational Awareness; Workload; Confusion; Distraction; Human-Machine Interface',
#  'Communication Breakdown; Confusion; Workload; Troubleshooting; Situational Awareness',
#  'Communication Breakdown; Confusion; Training / Qualification; Situational Awareness',
#  'Situational Awareness; Confusion; Distraction',
#  'Workload; Distraction',
#  'Physiological - Other; Situational Awareness; Time Pressure',
#  'Other / Unknown; Workload; Situational Awareness',
#  'Time Pressure; Communication Breakdown',
#  'Distraction; Confusion; Communication Breakdown; Situational Awareness; Workload',
#  'Communication Breakdown; Workload; Confusion',
#  'Confusion; Situational Awareness; Workload',
#  'Communication Breakdown; Situational Awareness; Workload',
#  'Distraction; Confusion',
#  'Workload; Situational Awareness',
#  'Training / Qualification; Situational Awareness; Distraction',
#  'Workload; Time Pressure; Distraction; Confusion; Communication Breakdown; Situational Awareness',
#  'Time Pressure; Workload; Situational Awareness',
#  'Workload; Training / Qualification; Human-Machine Interface',
#  'Situational Awareness; Distraction; Confusion',
#  'Workload; Communication Breakdown; Human-Machine Interface; Distraction',
#  'Troubleshooting; Distraction; Confusion; Human-Machine Interface',
#  'Confusion; Distraction; Human-Machine Interface; Situational Awareness',
#  'Communication Breakdown; Human-Machine Interface; Situational Awareness',
#  'Confusion; Communication Breakdown',
#  'Situational Awareness; Distraction; Communication Breakdown; Workload; Training / Qualification',
#  'Situational Awareness; Workload',
#  'Confusion; Communication Breakdown; Training / Qualification',
#  'Workload; Situational Awareness; Communication Breakdown',
#  'Fatigue; Situational Awareness; Time Pressure; Workload',
#  'Situational Awareness; Human-Machine Interface; Communication Breakdown; Training / Qualification',
#  'Situational Awareness; Training / Qualification; Communication Breakdown',
#  'Time Pressure; Workload; Situational Awareness; Distraction; Confusion; Communication Breakdown',
#  'Confusion; Distraction; Situational Awareness; Workload',
#  'Situational Awareness; Communication Breakdown; Confusion; Distraction',
#  'Troubleshooting; Training / Qualification; Human-Machine Interface; Confusion',
#  'Confusion; Distraction; Situational Awareness; Troubleshooting; Communication Breakdown',
#  'Confusion; Situational Awareness; Workload; Distraction',
#  'Fatigue; Situational Awareness; Training / Qualification',
#  'Workload; Human-Machine Interface; Situational Awareness; Time Pressure; Confusion; Communication Breakdown; Distraction',
#  'Training / Qualification; Communication Breakdown; Situational Awareness',
#  'Situational Awareness; Confusion; Training / Qualification',
#  'Situational Awareness; Communication Breakdown; Workload',
#  'Communication Breakdown; Physiological - Other; Situational Awareness',
#  'Communication Breakdown; Confusion; Distraction; Human-Machine Interface; Situational Awareness',
#  'Distraction; Confusion; Communication Breakdown; Situational Awareness; Workload; Troubleshooting',
#  'Training / Qualification; Situational Awareness; Communication Breakdown',
#  'Workload; Situational Awareness; Confusion; Distraction; Communication Breakdown',
#  'Communication Breakdown; Situational Awareness; Training / Qualification',
#  'Confusion; Distraction; Situational Awareness; Time Pressure; Communication Breakdown',
#  'Distraction; Situational Awareness; Workload; Troubleshooting',
#  'Distraction; Workload; Human-Machine Interface',
#  'Workload; Situational Awareness; Communication Breakdown; Distraction',
#  'Situational Awareness; Confusion; Communication Breakdown; Distraction',
#  'Communication Breakdown; Fatigue; Situational Awareness',
#  'Confusion; Distraction; Situational Awareness; Workload; Human-Machine Interface',
#  'Situational Awareness; Confusion; Workload; Communication Breakdown',
#  'Confusion; Situational Awareness; Human-Machine Interface',
#  'Situational Awareness; Distraction; Workload',
#  'Situational Awareness; Workload; Communication Breakdown; Confusion; Distraction; Human-Machine Interface',
#  'Training / Qualification; Confusion; Situational Awareness',
#  'Physiological - Other; Situational Awareness',
#  'Communication Breakdown; Confusion; Distraction; Situational Awareness; Time Pressure; Workload',
#  'Communication Breakdown; Confusion; Human-Machine Interface; Situational Awareness; Time Pressure; Workload; Distraction',
#  'Fatigue; Situational Awareness; Distraction',
#  'Confusion; Distraction; Workload',
#  'Confusion; Troubleshooting; Human-Machine Interface',
#  'Confusion; Fatigue; Training / Qualification',
#  'Communication Breakdown; Distraction; Training / Qualification; Situational Awareness',
#  'Situational Awareness; Training / Qualification; Human-Machine Interface; Confusion',
#  'Situational Awareness; Workload; Human-Machine Interface; Distraction; Confusion',
#  'Training / Qualification; Communication Breakdown',
#  'Situational Awareness; Fatigue',
#  'Distraction; Time Pressure; Workload; Communication Breakdown',
#  'Time Pressure; Situational Awareness; Distraction; Confusion; Workload',
#  'Human-Machine Interface; Time Pressure; Workload',
#  'Troubleshooting; Confusion',
#  'Training / Qualification; Workload; Time Pressure; Situational Awareness',
#  'Workload; Situational Awareness; Confusion; Distraction',
#  'Communication Breakdown; Confusion; Distraction; Situational Awareness; Workload; Time Pressure',
#  'Troubleshooting; Situational Awareness',
#  'Communication Breakdown; Training / Qualification; Situational Awareness',
#  'Confusion; Situational Awareness; Troubleshooting; Distraction; Human-Machine Interface',
#  'Time Pressure; Communication Breakdown; Confusion; Distraction; Situational Awareness; Training / Qualification; Workload',
#  'Situational Awareness; Training / Qualification; Distraction',
#  'Situational Awareness; Time Pressure',
#  'Communication Breakdown; Confusion; Workload; Time Pressure; Situational Awareness; Distraction',
#  'Communication Breakdown; Confusion; Human-Machine Interface; Situational Awareness; Training / Qualification',
#  'Communication Breakdown; Distraction; Human-Machine Interface; Situational Awareness',
#  'Human-Machine Interface; Distraction; Confusion; Communication Breakdown',
#  'Time Pressure; Situational Awareness',
#  'Confusion; Distraction; Time Pressure',
#  'Workload; Distraction; Situational Awareness',
#  'Situational Awareness; Workload; Distraction',
#  'Workload; Human-Machine Interface; Time Pressure',
#  'Workload; Time Pressure; Situational Awareness; Communication Breakdown',
#  'Other / Unknown; Time Pressure; Communication Breakdown',
#  'Situational Awareness; Distraction; Training / Qualification; Workload',
#  'Troubleshooting; Human-Machine Interface; Situational Awareness',
#  'Workload; Distraction; Time Pressure',
#  'Human-Machine Interface; Troubleshooting',
#  'Confusion; Communication Breakdown; Time Pressure; Workload; Training / Qualification',
#  'Time Pressure',
#  'Human-Machine Interface; Communication Breakdown',
#  'Situational Awareness; Confusion; Human-Machine Interface',
#  'Communication Breakdown; Situational Awareness; Time Pressure; Fatigue',
#  'Distraction; Workload; Situational Awareness',
#  'Workload; Time Pressure',
#  'Human-Machine Interface; Training / Qualification; Confusion',
#  'Confusion; Communication Breakdown; Situational Awareness',
#  'Training / Qualification; Time Pressure; Situational Awareness; Communication Breakdown; Confusion',
#  'Time Pressure; Distraction',
#  'Distraction; Situational Awareness; Communication Breakdown; Confusion',
#  'Confusion; Time Pressure',
#  'Distraction; Fatigue; Situational Awareness; Time Pressure; Confusion',
#  'Troubleshooting; Communication Breakdown; Situational Awareness',
#  'Time Pressure; Workload; Troubleshooting',
#  'Time Pressure; Troubleshooting; Communication Breakdown',
#  'Troubleshooting; Workload',
#  'Workload; Communication Breakdown',
#  'Situational Awareness; Time Pressure; Communication Breakdown',
#  'Workload; Situational Awareness; Confusion',
#  'Confusion; Communication Breakdown; Workload',
#  'Workload; Fatigue; Physiological - Other; Situational Awareness; Time Pressure',
#  'Situational Awareness; Workload; Time Pressure; Fatigue',
#  'Situational Awareness; Distraction; Confusion; Human-Machine Interface',
#  'Situational Awareness; Other / Unknown',
#  'Troubleshooting; Communication Breakdown; Confusion',
#  'Training / Qualification; Situational Awareness; Human-Machine Interface',
#  'Workload; Time Pressure; Situational Awareness',
#  'Training / Qualification; Communication Breakdown; Confusion; Situational Awareness',
#  'Human-Machine Interface; Situational Awareness; Distraction; Confusion; Communication Breakdown',
#  'Distraction; Training / Qualification; Confusion; Communication Breakdown',
#  'Time Pressure; Situational Awareness; Distraction; Workload; Communication Breakdown',
#  'Confusion; Situational Awareness; Time Pressure',
#  'Situational Awareness; Distraction; Communication Breakdown',
#  'Situational Awareness; Human-Machine Interface; Distraction',
#  'Confusion; Distraction',
#  'Troubleshooting; Situational Awareness; Communication Breakdown',
#  'Situational Awareness; Distraction; Confusion; Troubleshooting',
#  'Situational Awareness; Workload; Time Pressure; Confusion',
#  'Other / Unknown; Communication Breakdown',
#  'Communication Breakdown; Troubleshooting',
#  'Situational Awareness; Troubleshooting; Communication Breakdown',
#  'Situational Awareness; Communication Breakdown; Training / Qualification',
#  'Troubleshooting; Communication Breakdown; Situational Awareness; Distraction',
#  'Other / Unknown; Workload',
#  'Workload; Training / Qualification; Situational Awareness',
#  'Troubleshooting; Situational Awareness; Confusion; Human-Machine Interface; Workload',
#  'Distraction; Communication Breakdown; Situational Awareness',
#  'Troubleshooting; Confusion; Communication Breakdown; Situational Awareness',
#  'Training / Qualification; Time Pressure; Situational Awareness; Troubleshooting; Human-Machine Interface',
#  'Workload; Situational Awareness; Distraction',
#  'Human-Machine Interface; Situational Awareness; Communication Breakdown; Confusion; Workload; Distraction',
#  'Workload',
#  'Distraction; Confusion; Situational Awareness',
#  'Situational Awareness; Human-Machine Interface; Confusion; Communication Breakdown; Training / Qualification; Time Pressure',
#  'Human-Machine Interface; Confusion; Troubleshooting; Workload',
#  'Confusion; Human-Machine Interface; Situational Awareness; Workload; Distraction',
#  'Confusion; Communication Breakdown; Workload; Situational Awareness',
#  'Distraction; Human-Machine Interface; Workload',
#  'Human-Machine Interface; Situational Awareness; Communication Breakdown',
#  'Situational Awareness; Human-Machine Interface; Confusion',
#  'Distraction; Training / Qualification; Situational Awareness; Communication Breakdown',
#  'Other / Unknown; Situational Awareness; Confusion',
#  'Training / Qualification; Human-Machine Interface; Situational Awareness; Confusion; Fatigue',
#  'Workload; Troubleshooting; Training / Qualification; Distraction; Time Pressure',
#  'Workload; Training / Qualification; Situational Awareness; Human-Machine Interface; Distraction; Confusion',
#  'Workload; Time Pressure; Confusion; Communication Breakdown',
#  'Distraction; Human-Machine Interface; Time Pressure; Workload; Communication Breakdown',
#  'Confusion; Human-Machine Interface; Communication Breakdown',
#  'Communication Breakdown; Training / Qualification; Other / Unknown',
#  'Confusion; Communication Breakdown; Situational Awareness; Human-Machine Interface',
#  'Troubleshooting; Confusion; Communication Breakdown; Distraction',
#  'Communication Breakdown; Situational Awareness; Troubleshooting; Workload; Distraction',
#  'Training / Qualification; Workload',
#  'Time Pressure; Situational Awareness; Distraction; Communication Breakdown',
#  'Distraction; Human-Machine Interface; Communication Breakdown',
#  'Training / Qualification; Workload; Human-Machine Interface; Time Pressure',
#  'Workload; Time Pressure; Human-Machine Interface',
#  'Communication Breakdown; Confusion; Situational Awareness; Workload',
#  'Confusion; Distraction; Situational Awareness; Time Pressure; Workload',
#  'Communication Breakdown; Confusion; Human-Machine Interface; Troubleshooting',
#  'Human-Machine Interface; Situational Awareness; Confusion; Communication Breakdown',
#  'Fatigue; Confusion; Situational Awareness',
#  'Communication Breakdown; Human-Machine Interface; Training / Qualification; Workload; Situational Awareness',
#  'Training / Qualification; Confusion; Workload',
#  'Communication Breakdown; Confusion; Distraction; Situational Awareness; Time Pressure',
#  'Distraction; Training / Qualification; Time Pressure; Confusion; Communication Breakdown',
#  'Confusion; Workload',
#  'Training / Qualification; Communication Breakdown; Situational Awareness; Workload',
#  'Communication Breakdown; Human-Machine Interface; Training / Qualification',
#  'Workload; Training / Qualification; Situational Awareness; Human-Machine Interface',
#  'Communication Breakdown; Confusion; Other / Unknown',
#  'Confusion; Training / Qualification; Time Pressure; Situational Awareness; Distraction; Workload',
#  'Communication Breakdown; Confusion; Situational Awareness; Distraction',
#  'Human-Machine Interface; Confusion; Troubleshooting',
#  'Workload; Time Pressure; Human-Machine Interface; Distraction; Communication Breakdown; Confusion',
#  'Other / Unknown; Situational Awareness; Communication Breakdown',
#  'Training / Qualification; Human-Machine Interface; Situational Awareness; Troubleshooting',
#  'Troubleshooting',
#  'Human-Machine Interface; Communication Breakdown; Time Pressure; Situational Awareness; Workload',
#  'Situational Awareness; Troubleshooting; Communication Breakdown; Physiological - Other',
#  'Fatigue; Communication Breakdown; Distraction',
#  'Communication Breakdown; Other / Unknown; Workload',
#  'Physiological - Other; Situational Awareness; Training / Qualification',
#  'Workload; Communication Breakdown; Confusion; Human-Machine Interface; Situational Awareness',
#  'Training / Qualification; Other / Unknown',
#  'Situational Awareness; Workload; Confusion; Communication Breakdown; Training / Qualification',
#  'Troubleshooting; Workload; Situational Awareness; Human-Machine Interface; Distraction',
#  'Communication Breakdown; Distraction; Training / Qualification; Workload',
#  'Distraction; Confusion; Communication Breakdown; Workload; Time Pressure; Human-Machine Interface',
#  'Communication Breakdown; Workload; Situational Awareness; Distraction',
#  'Communication Breakdown; Time Pressure; Workload',
#  'Human-Machine Interface; Distraction; Situational Awareness',
#  'Physiological - Other; Workload',
#  'Distraction; Training / Qualification',
#  'Confusion; Physiological - Other',
#  'Situational Awareness; Confusion; Other / Unknown',
#  'Troubleshooting; Situational Awareness; Human-Machine Interface; Distraction; Workload; Confusion',
#  'Human-Machine Interface; Troubleshooting; Time Pressure',
#  'Situational Awareness; Human-Machine Interface; Communication Breakdown',
#  'Human-Machine Interface; Communication Breakdown; Distraction; Training / Qualification; Workload',
#  'Workload; Communication Breakdown; Distraction; Time Pressure; Training / Qualification',
#  'Human-Machine Interface; Confusion; Communication Breakdown; Training / Qualification',
#  'Fatigue; Workload',
#  'Communication Breakdown; Confusion; Fatigue; Situational Awareness',
#  'Fatigue; Workload; Situational Awareness; Physiological - Other; Communication Breakdown; Confusion; Distraction',
#  'Distraction; Human-Machine Interface; Time Pressure; Training / Qualification; Workload',
#  'Human-Machine Interface; Confusion; Communication Breakdown',
#  'Time Pressure; Workload',
#  'Confusion; Situational Awareness; Workload; Communication Breakdown',
#  'Communication Breakdown; Distraction; Workload',
#  'Distraction; Time Pressure; Workload',
#  'Workload; Situational Awareness; Confusion; Communication Breakdown; Distraction',
#  'Confusion; Situational Awareness; Training / Qualification; Communication Breakdown',
#  'Confusion; Distraction; Situational Awareness; Human-Machine Interface',
#  'Communication Breakdown; Time Pressure; Troubleshooting; Workload; Confusion',
#  'Communication Breakdown; Fatigue',
#  'Communication Breakdown; Workload; Human-Machine Interface; Distraction',
#  'Communication Breakdown; Other / Unknown; Situational Awareness',
#  'Communication Breakdown; Human-Machine Interface; Situational Awareness; Workload; Distraction; Confusion',
#  'Human-Machine Interface; Confusion; Communication Breakdown; Situational Awareness',
#  'Confusion; Situational Awareness; Training / Qualification; Workload',
#  'Time Pressure; Training / Qualification',
#  'Communication Breakdown; Confusion; Situational Awareness; Time Pressure',
#  'Distraction; Communication Breakdown; Time Pressure',
#  'Other / Unknown; Time Pressure',
#  'Training / Qualification; Time Pressure; Situational Awareness',
#  'Workload; Distraction; Confusion; Communication Breakdown; Training / Qualification',
#  'Fatigue; Human-Machine Interface',
#  'Physiological - Other; Situational Awareness; Confusion; Distraction',
#  'Human-Machine Interface; Situational Awareness; Distraction',
#  'Communication Breakdown; Training / Qualification; Distraction',
#  'Distraction; Human-Machine Interface; Situational Awareness; Workload; Confusion; Time Pressure; Communication Breakdown',
#  'Workload; Training / Qualification; Communication Breakdown',
#  'Communication Breakdown; Confusion; Distraction; Workload; Time Pressure',
#  'Confusion; Fatigue',
#  'Distraction; Human-Machine Interface; Troubleshooting; Confusion',
#  'Workload; Situational Awareness; Confusion; Communication Breakdown',
#  'Physiological - Other; Distraction',
#  'Time Pressure; Workload; Confusion',
#  'Workload; Training / Qualification; Situational Awareness; Confusion',
#  'Training / Qualification; Workload; Communication Breakdown; Time Pressure',
#  'Distraction; Confusion; Human-Machine Interface',
#  'Communication Breakdown; Training / Qualification; Confusion',
#  'Communication Breakdown; Confusion; Troubleshooting; Distraction',
#  'Situational Awareness; Distraction; Confusion; Workload',
#  'Troubleshooting; Confusion; Human-Machine Interface; Distraction',
#  'Communication Breakdown; Confusion; Situational Awareness; Training / Qualification; Troubleshooting',
#  'Distraction; Troubleshooting; Communication Breakdown',
#  'Communication Breakdown; Distraction; Confusion',
#  'Time Pressure; Communication Breakdown; Confusion',
#  'Communication Breakdown; Fatigue; Time Pressure',
#  'Confusion; Distraction; Communication Breakdown',
#  'Communication Breakdown; Distraction; Training / Qualification',
#  'Communication Breakdown; Confusion; Time Pressure; Workload',
#  'Communication Breakdown; Confusion; Troubleshooting',
#  'Situational Awareness; Confusion; Communication Breakdown; Workload',
#  'Situational Awareness; Training / Qualification; Fatigue; Confusion; Distraction',
#  'Communication Breakdown; Confusion; Distraction; Time Pressure; Workload',
#  'Fatigue; Situational Awareness',
#  'Workload; Distraction; Confusion; Communication Breakdown; Situational Awareness',
#  'Training / Qualification; Human-Machine Interface; Situational Awareness',
#  'Distraction; Situational Awareness; Training / Qualification; Communication Breakdown; Confusion',
#  'Distraction; Confusion; Situational Awareness; Communication Breakdown',
#  'Training / Qualification; Workload; Confusion; Communication Breakdown',
#  'Troubleshooting; Workload; Communication Breakdown; Confusion; Distraction; Human-Machine Interface; Time Pressure',
#  'Troubleshooting; Confusion; Communication Breakdown; Training / Qualification',
#  'Confusion; Training / Qualification; Communication Breakdown',
#  'Workload; Troubleshooting; Distraction; Confusion; Communication Breakdown',
#  'Workload; Distraction; Communication Breakdown; Time Pressure',
#  'Situational Awareness; Human-Machine Interface; Distraction; Communication Breakdown; Workload',
#  'Time Pressure; Confusion; Situational Awareness',
#  'Confusion; Distraction; Training / Qualification; Situational Awareness',
#  'Situational Awareness; Troubleshooting; Confusion; Distraction',
#  'Workload; Troubleshooting; Time Pressure; Distraction; Situational Awareness; Confusion',
#  'Workload; Situational Awareness; Distraction; Communication Breakdown; Confusion',
#  'Troubleshooting; Situational Awareness; Distraction; Confusion; Communication Breakdown; Workload',
#  'Confusion; Communication Breakdown; Time Pressure; Workload; Troubleshooting',
#  'Situational Awareness; Confusion; Communication Breakdown; Time Pressure',
#  'Confusion; Distraction; Situational Awareness; Troubleshooting; Workload',
#  'Workload; Time Pressure; Distraction; Situational Awareness; Confusion; Communication Breakdown',
#  'Distraction; Confusion; Human-Machine Interface; Troubleshooting',
#  'Distraction; Confusion; Workload',
#  'Time Pressure; Confusion; Situational Awareness; Communication Breakdown',
#  'Time Pressure; Confusion; Distraction; Situational Awareness; Communication Breakdown',
#  'Situational Awareness; Time Pressure; Communication Breakdown; Confusion; Distraction',
#  'Situational Awareness; Time Pressure; Communication Breakdown; Confusion',
#  'Troubleshooting; Situational Awareness; Distraction; Confusion',
#  'Confusion; Workload; Distraction; Situational Awareness; Time Pressure',
#  'Confusion; Troubleshooting; Distraction; Situational Awareness',
#  'Workload; Distraction; Human-Machine Interface; Confusion; Troubleshooting',
#  'Situational Awareness; Communication Breakdown; Training / Qualification; Distraction; Confusion',
#  'Confusion; Distraction; Troubleshooting',
#  'Confusion; Communication Breakdown; Situational Awareness; Distraction',
#  'Troubleshooting; Communication Breakdown; Workload; Confusion; Distraction',
#  'Workload; Time Pressure; Confusion; Communication Breakdown; Situational Awareness',
#  'Communication Breakdown; Workload; Troubleshooting; Training / Qualification; Time Pressure; Situational Awareness; Distraction; Confusion',
#  'Confusion; Distraction; Situational Awareness; Training / Qualification; Communication Breakdown',
#  'Communication Breakdown; Distraction; Situational Awareness; Workload',
#  'Workload; Training / Qualification; Confusion; Distraction; Situational Awareness; Troubleshooting',
#  'Communication Breakdown; Fatigue; Situational Awareness; Time Pressure; Workload; Confusion',
#  'Time Pressure; Fatigue; Distraction; Confusion; Communication Breakdown',
#  'Troubleshooting; Situational Awareness; Human-Machine Interface; Confusion; Distraction',
#  'Workload; Human-Machine Interface; Confusion',
#  'Distraction; Human-Machine Interface; Situational Awareness; Workload',
#  'Confusion; Distraction; Situational Awareness; Time Pressure',
#  'Troubleshooting; Time Pressure; Situational Awareness; Confusion; Communication Breakdown; Distraction',
#  'Time Pressure; Workload; Situational Awareness; Human-Machine Interface; Distraction; Communication Breakdown; Confusion',
#  'Communication Breakdown; Confusion; Distraction; Other / Unknown; Situational Awareness; Training / Qualification; Troubleshooting; Workload',
#  'Communication Breakdown; Confusion; Distraction; Situational Awareness; Troubleshooting; Workload',
#  'Time Pressure; Distraction; Confusion; Communication Breakdown; Situational Awareness',
#  'Workload; Time Pressure; Situational Awareness; Distraction; Confusion; Communication Breakdown',
#  'Workload; Training / Qualification; Time Pressure; Confusion; Communication Breakdown',
#  'Distraction; Confusion; Situational Awareness; Workload; Troubleshooting',
#  'Distraction; Confusion; Situational Awareness; Time Pressure; Troubleshooting',
#  'Communication Breakdown; Human-Machine Interface; Time Pressure; Workload',
#  'Confusion; Distraction; Fatigue; Situational Awareness; Workload; Communication Breakdown',
#  'Troubleshooting; Situational Awareness; Confusion; Communication Breakdown',
#  'Workload; Distraction; Fatigue',
#  'Workload; Troubleshooting; Training / Qualification; Confusion; Distraction; Situational Awareness',
#  'Training / Qualification; Workload; Communication Breakdown; Confusion; Distraction; Situational Awareness',
#  'Distraction; Situational Awareness; Confusion; Time Pressure; Communication Breakdown',
#  'Workload; Confusion; Distraction; Fatigue; Situational Awareness',
#  'Workload; Communication Breakdown; Distraction; Situational Awareness',
#  'Troubleshooting; Communication Breakdown; Confusion; Distraction; Situational Awareness; Workload',
#  'Communication Breakdown; Distraction; Situational Awareness; Time Pressure; Workload',
#  'Situational Awareness; Workload; Troubleshooting; Distraction; Confusion; Communication Breakdown',
#  'Communication Breakdown; Confusion; Situational Awareness; Distraction; Workload; Time Pressure',
#  'Human-Machine Interface; Distraction; Confusion; Situational Awareness; Troubleshooting',
#  'Distraction; Workload; Communication Breakdown; Confusion; Training / Qualification',
#  'Situational Awareness; Training / Qualification; Communication Breakdown; Confusion',
#  'Time Pressure; Confusion; Communication Breakdown; Situational Awareness',
#  'Workload; Communication Breakdown; Confusion',
#  'Communication Breakdown; Troubleshooting; Time Pressure; Distraction',
#  'Distraction; Fatigue; Situational Awareness; Confusion; Communication Breakdown',
#  'Distraction; Situational Awareness; Training / Qualification; Workload; Confusion',
#  'Confusion; Workload; Time Pressure',
#  'Human-Machine Interface; Distraction; Confusion; Situational Awareness',
#  'Distraction; Confusion; Situational Awareness; Training / Qualification',
#  'Distraction; Troubleshooting; Situational Awareness; Human-Machine Interface; Confusion',
#  'Training / Qualification; Workload; Communication Breakdown; Confusion; Distraction',
#  'Human-Machine Interface; Workload; Time Pressure; Situational Awareness; Distraction; Communication Breakdown; Confusion',
#  'Situational Awareness; Distraction; Time Pressure; Troubleshooting; Workload; Communication Breakdown',
#  'Communication Breakdown; Troubleshooting; Situational Awareness; Distraction; Confusion',
#  'Distraction; Confusion; Communication Breakdown; Situational Awareness; Time Pressure',
#  'Communication Breakdown; Workload; Situational Awareness; Confusion; Distraction',
#  'Distraction; Workload; Troubleshooting; Situational Awareness',
#  'Human-Machine Interface; Troubleshooting; Training / Qualification',
#  'Confusion; Distraction; Workload; Training / Qualification; Situational Awareness',
#  'Workload; Distraction; Confusion; Time Pressure',
#  'Human-Machine Interface; Communication Breakdown; Confusion; Distraction; Workload',
#  'Situational Awareness; Distraction; Confusion; Communication Breakdown; Training / Qualification',
#  'Workload; Situational Awareness; Human-Machine Interface',
#  'Situational Awareness; Workload; Distraction; Confusion',
#  'Troubleshooting; Workload; Confusion; Distraction; Human-Machine Interface',
#  'Distraction; Situational Awareness; Confusion; Communication Breakdown',
#  'Situational Awareness; Workload; Confusion',
#  'Human-Machine Interface; Confusion; Situational Awareness',
#  'Communication Breakdown; Human-Machine Interface',
#  'Confusion; Communication Breakdown; Distraction; Time Pressure; Situational Awareness',
#  'Distraction; Communication Breakdown; Situational Awareness; Time Pressure',
#  'Communication Breakdown; Situational Awareness; Workload; Confusion',
#  'Confusion; Distraction; Situational Awareness; Time Pressure; Troubleshooting; Workload',
#  'Communication Breakdown; Confusion; Distraction; Fatigue; Situational Awareness; Workload',
#  'Distraction; Confusion; Communication Breakdown; Time Pressure',
#  'Communication Breakdown; Time Pressure; Workload; Distraction; Confusion; Situational Awareness',
#  'Confusion; Troubleshooting; Situational Awareness',
#  'Workload; Time Pressure; Situational Awareness; Distraction; Confusion; Communication Breakdown; Troubleshooting',
#  'Distraction; Situational Awareness; Time Pressure; Troubleshooting; Workload; Communication Breakdown',
#  'Communication Breakdown; Workload; Situational Awareness; Confusion',
#  'Distraction; Situational Awareness; Time Pressure; Communication Breakdown; Confusion',
#  'Confusion; Time Pressure; Workload; Human-Machine Interface',
#  'Distraction; Time Pressure',
#  'Workload; Time Pressure; Distraction; Confusion; Communication Breakdown',
#  'Distraction; Troubleshooting',
#  'Troubleshooting; Situational Awareness; Distraction; Communication Breakdown; Confusion',
#  'Time Pressure; Fatigue',
#  'Communication Breakdown; Confusion; Human-Machine Interface; Time Pressure; Distraction',
#  'Situational Awareness; Time Pressure; Distraction; Training / Qualification; Communication Breakdown',
#  'Training / Qualification; Confusion; Communication Breakdown',
#  'Fatigue; Confusion',
#  'Troubleshooting; Situational Awareness; Distraction; Communication Breakdown; Workload',
#  'Confusion; Distraction; Situational Awareness; Workload; Communication Breakdown',
#  'Situational Awareness; Troubleshooting; Workload; Distraction; Confusion',
#  'Communication Breakdown; Confusion; Distraction; Troubleshooting',
#  'Time Pressure; Situational Awareness; Distraction; Communication Breakdown; Training / Qualification; Workload',
#  'Situational Awareness; Fatigue; Distraction; Confusion; Time Pressure; Workload',
#  'Workload; Situational Awareness; Communication Breakdown; Time Pressure',
#  'Workload; Human-Machine Interface; Time Pressure; Distraction',
#  'Distraction; Confusion; Communication Breakdown; Situational Awareness; Workload; Time Pressure',
#  'Workload; Situational Awareness; Human-Machine Interface; Confusion; Communication Breakdown',
#  'Human-Machine Interface; Situational Awareness; Workload',
#  'Situational Awareness; Workload; Confusion; Communication Breakdown',
#  'Confusion; Communication Breakdown; Human-Machine Interface; Workload; Situational Awareness',
#  'Workload; Confusion; Communication Breakdown; Situational Awareness',
#  'Workload; Troubleshooting; Confusion',
#  'Situational Awareness; Distraction; Confusion; Communication Breakdown; Time Pressure; Workload',
#  'Human-Machine Interface; Training / Qualification; Workload; Fatigue; Distraction',
#  'Training / Qualification; Human-Machine Interface; Confusion',
#  'Training / Qualification; Troubleshooting',
#  'Distraction; Human-Machine Interface; Troubleshooting',
#  'Situational Awareness; Fatigue; Training / Qualification',
#  'Distraction; Situational Awareness; Workload; Time Pressure',
#  'Workload; Confusion; Training / Qualification; Situational Awareness; Distraction',
#  'Confusion; Communication Breakdown; Situational Awareness; Time Pressure; Training / Qualification; Workload',
#  'Confusion; Communication Breakdown; Distraction; Workload',
#  'Situational Awareness; Confusion; Distraction; Communication Breakdown',
#  'Time Pressure; Workload; Distraction; Confusion; Situational Awareness',
#  'Human-Machine Interface; Fatigue; Workload; Situational Awareness; Distraction; Communication Breakdown',
#  'Confusion; Distraction; Time Pressure; Workload; Communication Breakdown',
#  'Troubleshooting; Distraction; Communication Breakdown',
#  'Workload; Communication Breakdown; Situational Awareness',
#  'Workload; Distraction; Situational Awareness; Confusion',
#  'Situational Awareness; Distraction; Fatigue; Confusion',
#  'Confusion; Human-Machine Interface; Situational Awareness; Distraction',
#  'Situational Awareness; Workload; Communication Breakdown; Confusion',
#  'Troubleshooting; Workload; Human-Machine Interface; Confusion; Distraction',
#  'Communication Breakdown; Distraction; Human-Machine Interface',
#  'Situational Awareness; Communication Breakdown; Time Pressure; Training / Qualification',
#  'Workload; Troubleshooting; Situational Awareness; Distraction; Confusion; Communication Breakdown',
#  'Situational Awareness; Training / Qualification; Workload',
#  'Situational Awareness; Confusion; Workload',
#  'Training / Qualification; Workload; Situational Awareness',
#  'Situational Awareness; Confusion; Fatigue',
#  'Situational Awareness; Training / Qualification; Human-Machine Interface; Communication Breakdown',
#  'Confusion; Situational Awareness; Workload; Human-Machine Interface',
#  'Confusion; Fatigue; Human-Machine Interface; Situational Awareness; Training / Qualification',
#  'Confusion; Communication Breakdown; Other / Unknown',
#  'Communication Breakdown; Workload',
#  'Communication Breakdown; Distraction; Situational Awareness; Troubleshooting; Confusion',
#  'Situational Awareness; Workload; Confusion; Distraction',
#  'Communication Breakdown; Situational Awareness; Training / Qualification; Workload',
#  'Confusion; Distraction; Communication Breakdown; Situational Awareness',
#  'Training / Qualification; Situational Awareness; Confusion; Communication Breakdown',
#  'Workload; Troubleshooting; Situational Awareness; Human-Machine Interface; Confusion; Distraction',
#  'Distraction; Time Pressure; Training / Qualification; Situational Awareness',
#  'Confusion; Distraction; Situational Awareness; Training / Qualification',
#  'Communication Breakdown; Distraction; Confusion; Situational Awareness',
#  'Workload; Communication Breakdown; Situational Awareness; Distraction',
#  'Distraction; Human-Machine Interface; Training / Qualification; Situational Awareness',
#  'Training / Qualification; Confusion; Distraction; Situational Awareness',
#  'Confusion; Communication Breakdown; Situational Awareness; Distraction; Workload',
#  'Communication Breakdown; Confusion; Distraction; Workload',
#  'Troubleshooting; Situational Awareness; Distraction; Confusion; Human-Machine Interface',
#  'Workload; Troubleshooting; Situational Awareness; Confusion; Communication Breakdown; Distraction',
#  'Communication Breakdown; Confusion; Distraction; Troubleshooting; Situational Awareness',
#  'Confusion; Distraction; Workload; Troubleshooting; Situational Awareness',
#  'Confusion; Training / Qualification; Communication Breakdown; Workload; Distraction; Situational Awareness',
#  'Communication Breakdown; Confusion; Human-Machine Interface; Situational Awareness',
#  'Confusion; Human-Machine Interface; Troubleshooting',
#  'Troubleshooting; Workload; Confusion; Communication Breakdown; Situational Awareness; Distraction',
#  'Communication Breakdown; Confusion; Distraction; Situational Awareness; Training / Qualification',
#  'Communication Breakdown; Confusion; Workload; Situational Awareness; Distraction',
#  'Time Pressure; Workload; Confusion; Situational Awareness',
#  'Situational Awareness; Human-Machine Interface; Distraction; Confusion; Communication Breakdown; Troubleshooting',
#  'Human-Machine Interface; Communication Breakdown; Situational Awareness; Distraction; Confusion',
#  'Human-Machine Interface; Distraction; Troubleshooting; Confusion',
#  'Distraction; Confusion; Situational Awareness; Workload',
#  'Communication Breakdown; Confusion; Situational Awareness; Training / Qualification; Workload',
#  'Situational Awareness; Time Pressure; Training / Qualification; Troubleshooting; Communication Breakdown; Human-Machine Interface; Distraction; Confusion; Workload',
#  'Confusion; Time Pressure; Workload; Situational Awareness',
#  'Workload; Training / Qualification; Situational Awareness; Distraction; Confusion',
#  'Distraction; Confusion; Communication Breakdown; Workload',
#  'Distraction; Situational Awareness; Training / Qualification',
#  'Communication Breakdown; Confusion; Human-Machine Interface; Troubleshooting; Workload',
#  'Workload; Troubleshooting; Human-Machine Interface; Situational Awareness; Distraction; Confusion; Communication Breakdown',
#  'Human-Machine Interface; Time Pressure; Situational Awareness; Communication Breakdown; Distraction; Workload',
#  'Distraction; Situational Awareness; Workload; Training / Qualification',
#  'Communication Breakdown; Fatigue; Workload',
#  'Workload; Time Pressure; Situational Awareness; Confusion; Communication Breakdown',
#  'Troubleshooting; Workload; Confusion; Time Pressure',
#  'Distraction; Confusion; Fatigue; Workload; Time Pressure; Situational Awareness',
#  'Training / Qualification; Troubleshooting; Confusion; Human-Machine Interface; Situational Awareness',
#  'Situational Awareness; Time Pressure; Troubleshooting; Workload; Confusion; Distraction; Human-Machine Interface',
#  'Situational Awareness; Workload; Communication Breakdown',
#  'Human-Machine Interface; Distraction',
#  'Situational Awareness; Human-Machine Interface; Time Pressure; Workload',
#  'Confusion; Situational Awareness; Workload; Training / Qualification',
#  'Situational Awareness; Other / Unknown; Distraction; Communication Breakdown',
#  'Workload; Situational Awareness; Time Pressure; Communication Breakdown',
#  'Workload; Communication Breakdown; Distraction',
#  'Workload; Distraction; Situational Awareness; Confusion; Communication Breakdown',
#  'Distraction; Situational Awareness; Time Pressure; Workload',
#  'Communication Breakdown; Confusion; Workload; Situational Awareness',
#  'Time Pressure; Workload; Communication Breakdown; Confusion; Distraction; Situational Awareness',
#  'Workload; Communication Breakdown; Situational Awareness; Confusion',
#  'Confusion; Communication Breakdown; Situational Awareness; Troubleshooting',
#  'Situational Awareness; Training / Qualification; Confusion; Distraction',
#  'Distraction; Fatigue',
#  'Confusion; Distraction; Workload; Situational Awareness',
#  'Communication Breakdown; Confusion; Distraction; Human-Machine Interface; Situational Awareness; Training / Qualification; Workload',
#  'Troubleshooting; Workload; Confusion; Situational Awareness',
#  'Communication Breakdown; Confusion; Training / Qualification; Situational Awareness; Human-Machine Interface; Distraction',
#  'Distraction; Workload; Communication Breakdown',
#  'Human-Machine Interface; Fatigue; Distraction',
#  'Confusion; Workload; Troubleshooting; Situational Awareness; Communication Breakdown',
#  'Communication Breakdown; Distraction; Troubleshooting',
#  'Human-Machine Interface; Distraction; Confusion; Communication Breakdown; Physiological - Other; Training / Qualification; Situational Awareness',
#  'Workload; Confusion; Time Pressure; Distraction; Situational Awareness',
# ...
#  'Workload; Confusion; Distraction; Situational Awareness; Time Pressure',
#  'Situational Awareness; Confusion; Communication Breakdown; Training / Qualification; Time Pressure',
#  'Communication Breakdown; Time Pressure; Confusion; Workload',
#  'Communication Breakdown; Time Pressure; Training / Qualification',
#  'Situational Awareness; Communication Breakdown; Distraction; Human-Machine Interface',
#  'Situational Awareness; Troubleshooting; Confusion',
#  'Distraction; Time Pressure; Workload; Communication Breakdown; Confusion; Other / Unknown; Situational Awareness',
#  'Training / Qualification; Human-Machine Interface',
#  'Communication Breakdown; Time Pressure; Distraction',
#  'Situational Awareness; Communication Breakdown; Time Pressure',
#  'Training / Qualification; Communication Breakdown; Distraction',
#  'Time Pressure; Workload; Communication Breakdown; Situational Awareness',
#  'Troubleshooting; Fatigue; Communication Breakdown; Confusion',
#  'Distraction; Human-Machine Interface; Other / Unknown; Situational Awareness; Workload',
#  'Confusion; Situational Awareness; Human-Machine Interface; Communication Breakdown',
#  'Situational Awareness; Time Pressure; Communication Breakdown; Distraction',
#  'Workload; Training / Qualification; Situational Awareness; Communication Breakdown',
#  'Troubleshooting; Distraction; Communication Breakdown; Confusion',
#  'Situational Awareness; Troubleshooting; Communication Breakdown; Confusion; Human-Machine Interface',
#  'Time Pressure; Workload; Communication Breakdown; Distraction; Situational Awareness',
#  'Communication Breakdown; Situational Awareness; Training / Qualification; Confusion',
#  'Troubleshooting; Confusion; Distraction; Human-Machine Interface; Situational Awareness',
#  'Communication Breakdown; Distraction; Situational Awareness; Confusion',
#  'Troubleshooting; Workload; Communication Breakdown',
#  'Situational Awareness; Time Pressure; Training / Qualification',
#  'Situational Awareness; Workload; Confusion; Physiological - Other',
#  'Confusion; Distraction; Troubleshooting; Workload',
#  'Training / Qualification; Time Pressure; Communication Breakdown',
#  'Workload; Communication Breakdown; Troubleshooting',
#  'Distraction; Time Pressure; Situational Awareness',
#  'Fatigue; Situational Awareness; Human-Machine Interface',
#  'Distraction; Fatigue; Human-Machine Interface',
#  'Troubleshooting; Workload; Human-Machine Interface',
#  'Time Pressure; Communication Breakdown; Human-Machine Interface',
#  'Time Pressure; Distraction; Situational Awareness',
#  'Situational Awareness; Distraction; Troubleshooting; Workload',
#  'Workload; Confusion; Communication Breakdown; Time Pressure',
#  'Time Pressure; Human-Machine Interface; Communication Breakdown',
#  'Troubleshooting; Situational Awareness; Distraction',
#  'Communication Breakdown; Fatigue; Human-Machine Interface',
#  'Other / Unknown; Communication Breakdown; Situational Awareness; Troubleshooting; Time Pressure',
#  'Human-Machine Interface; Situational Awareness; Distraction; Communication Breakdown',
#  'Communication Breakdown; Human-Machine Interface; Confusion',
#  'Workload; Situational Awareness; Troubleshooting',
#  'Distraction; Time Pressure; Workload; Situational Awareness',
#  'Time Pressure; Situational Awareness; Confusion',
#  'Troubleshooting; Time Pressure; Situational Awareness; Distraction; Confusion; Workload',
#  'Workload; Troubleshooting; Situational Awareness; Communication Breakdown; Distraction',
#  'Distraction; Workload; Situational Awareness; Confusion',
#  'Situational Awareness; Workload; Communication Breakdown; Confusion; Human-Machine Interface',
#  'Confusion; Situational Awareness; Time Pressure; Communication Breakdown',
#  'Workload; Time Pressure; Situational Awareness; Distraction; Human-Machine Interface; Confusion',
#  'Troubleshooting; Workload; Time Pressure',
#  'Confusion; Situational Awareness; Human-Machine Interface; Distraction; Troubleshooting',
#  'Confusion; Communication Breakdown; Human-Machine Interface; Time Pressure; Situational Awareness',
#  'Confusion; Distraction; Troubleshooting; Human-Machine Interface',
#  'Human-Machine Interface; Distraction; Time Pressure; Workload; Situational Awareness',
#  'Troubleshooting; Distraction; Situational Awareness; Confusion',
#  'Human-Machine Interface; Workload; Confusion; Distraction',
#  'Communication Breakdown; Confusion; Time Pressure; Situational Awareness',
#  'Time Pressure; Workload; Communication Breakdown; Distraction',
#  'Communication Breakdown; Confusion; Other / Unknown; Situational Awareness; Workload; Troubleshooting',
#  'Distraction; Human-Machine Interface; Confusion; Communication Breakdown; Time Pressure; Workload; Troubleshooting',
#  'Confusion; Communication Breakdown; Situational Awareness; Workload; Other / Unknown; Fatigue; Distraction',
#  'Communication Breakdown; Confusion; Other / Unknown; Situational Awareness; Time Pressure; Workload',
#  'Distraction; Situational Awareness; Training / Qualification; Workload; Communication Breakdown',
#  'Situational Awareness; Confusion; Communication Breakdown; Training / Qualification',
#  'Training / Qualification; Situational Awareness; Human-Machine Interface; Distraction; Confusion; Troubleshooting',
#  'Communication Breakdown; Confusion; Distraction; Situational Awareness; Training / Qualification; Workload',
#  'Time Pressure; Workload; Situational Awareness; Distraction; Confusion',
#  'Confusion; Communication Breakdown; Situational Awareness; Workload',
#  'Training / Qualification; Human-Machine Interface; Situational Awareness; Time Pressure',
#  'Training / Qualification; Time Pressure; Distraction; Situational Awareness; Confusion; Communication Breakdown',
#  'Confusion; Communication Breakdown; Distraction; Workload; Situational Awareness',
#  'Distraction; Human-Machine Interface; Situational Awareness; Workload; Confusion',
#  'Communication Breakdown; Workload; Training / Qualification; Time Pressure; Situational Awareness; Physiological - Other',
#  'Time Pressure; Distraction; Confusion; Communication Breakdown; Training / Qualification; Workload; Situational Awareness',
#  'Situational Awareness; Other / Unknown; Communication Breakdown',
#  'Communication Breakdown; Distraction; Human-Machine Interface; Workload',
#  'Time Pressure; Workload; Situational Awareness; Human-Machine Interface; Distraction; Confusion',
#  'Training / Qualification; Distraction; Situational Awareness; Time Pressure',
#  'Human-Machine Interface; Distraction; Confusion; Communication Breakdown; Training / Qualification',
#  'Human-Machine Interface; Time Pressure; Distraction; Confusion; Communication Breakdown',
#  'Communication Breakdown; Distraction; Situational Awareness; Training / Qualification; Confusion',
#  'Human-Machine Interface; Workload; Troubleshooting',
#  'Workload; Communication Breakdown; Distraction; Situational Awareness; Human-Machine Interface; Fatigue',
#  'Time Pressure; Confusion; Communication Breakdown',
#  'Distraction; Human-Machine Interface; Situational Awareness; Time Pressure; Workload',
#  'Situational Awareness; Other / Unknown; Distraction; Communication Breakdown; Fatigue',
#  'Time Pressure; Workload; Human-Machine Interface; Distraction; Communication Breakdown; Confusion',
#  'Training / Qualification; Communication Breakdown; Confusion',
#  'Confusion; Time Pressure; Distraction',
#  'Situational Awareness; Distraction; Workload; Human-Machine Interface',
#  'Workload; Time Pressure; Situational Awareness; Confusion; Distraction',
#  'Situational Awareness; Human-Machine Interface; Confusion; Workload',
#  'Human-Machine Interface; Workload; Time Pressure; Distraction; Confusion',
#  'Human-Machine Interface; Confusion; Troubleshooting; Situational Awareness',
#  'Physiological - Other; Distraction; Communication Breakdown; Time Pressure; Workload; Situational Awareness',
#  'Human-Machine Interface; Situational Awareness; Time Pressure; Workload; Distraction',
#  'Workload; Human-Machine Interface; Confusion; Distraction',
#  'Human-Machine Interface; Time Pressure; Workload; Distraction',
#  'Confusion; Distraction; Human-Machine Interface; Situational Awareness; Time Pressure; Workload; Communication Breakdown',
#  'Other / Unknown; Human-Machine Interface',
#  'Situational Awareness; Training / Qualification; Troubleshooting; Workload',
#  'Communication Breakdown; Distraction; Situational Awareness; Training / Qualification',
#  'Communication Breakdown; Workload; Training / Qualification; Human-Machine Interface; Distraction; Confusion',
#  'Time Pressure; Situational Awareness; Fatigue; Workload; Distraction',
#  'Situational Awareness; Human-Machine Interface; Distraction; Confusion; Communication Breakdown; Troubleshooting; Workload',
#  'Workload; Time Pressure; Human-Machine Interface; Distraction; Confusion',
#  'Situational Awareness; Time Pressure; Training / Qualification; Workload; Confusion; Fatigue',
#  'Training / Qualification; Troubleshooting; Communication Breakdown',
#  'Confusion; Workload; Human-Machine Interface',
#  'Workload; Training / Qualification; Human-Machine Interface; Distraction; Situational Awareness',
#  'Workload; Time Pressure; Distraction; Communication Breakdown; Confusion',
#  'Human-Machine Interface; Confusion; Situational Awareness; Distraction; Communication Breakdown',
#  'Human-Machine Interface; Situational Awareness; Training / Qualification',
#  'Human-Machine Interface; Confusion; Distraction',
#  'Situational Awareness; Confusion; Communication Breakdown; Training / Qualification; Human-Machine Interface',
#  'Confusion; Workload; Human-Machine Interface; Communication Breakdown',
#  'Human-Machine Interface; Training / Qualification; Situational Awareness',
#  'Workload; Situational Awareness; Distraction; Confusion; Communication Breakdown',
#  'Workload; Human-Machine Interface; Distraction',
#  'Training / Qualification; Human-Machine Interface; Confusion; Situational Awareness',
#  'Workload; Time Pressure; Confusion; Communication Breakdown; Human-Machine Interface',
#  'Workload; Training / Qualification; Confusion; Distraction; Troubleshooting',
#  'Communication Breakdown; Situational Awareness; Fatigue; Time Pressure',
#  'Distraction; Confusion; Physiological - Other',
#  'Situational Awareness; Human-Machine Interface; Time Pressure',
#  'Troubleshooting; Workload; Distraction; Confusion; Communication Breakdown; Situational Awareness',
#  'Time Pressure; Workload; Confusion; Communication Breakdown',
#  'Other / Unknown; Confusion',
#  'Confusion; Communication Breakdown; Time Pressure; Situational Awareness',
#  'Situational Awareness; Distraction; Time Pressure; Confusion; Workload',
#  'Communication Breakdown; Distraction; Situational Awareness; Workload; Confusion',
#  'Situational Awareness; Distraction; Confusion; Communication Breakdown; Workload',
#  'Training / Qualification; Situational Awareness; Confusion; Human-Machine Interface',
#  'Communication Breakdown; Human-Machine Interface; Workload',
#  'Workload; Confusion',
#  'Confusion; Distraction; Human-Machine Interface; Workload',
#  'Communication Breakdown; Confusion; Distraction; Human-Machine Interface; Situational Awareness; Workload',
#  'Workload; Communication Breakdown; Confusion; Distraction; Situational Awareness; Time Pressure',
#  'Workload; Human-Machine Interface; Distraction; Confusion; Communication Breakdown; Situational Awareness',
#  'Confusion; Communication Breakdown; Situational Awareness; Troubleshooting; Training / Qualification',
#  'Confusion; Communication Breakdown; Fatigue; Workload; Situational Awareness',
#  'Distraction; Situational Awareness; Workload; Confusion',
#  'Workload; Human-Machine Interface; Confusion; Communication Breakdown; Time Pressure',
#  'Confusion; Workload; Troubleshooting; Training / Qualification; Situational Awareness; Distraction; Communication Breakdown',
#  'Distraction; Human-Machine Interface; Workload; Communication Breakdown; Confusion',
#  'Situational Awareness; Fatigue; Other / Unknown',
#  'Distraction; Troubleshooting; Situational Awareness; Confusion; Communication Breakdown',
#  'Physiological - Other; Time Pressure; Troubleshooting; Workload',
#  'Communication Breakdown; Confusion; Troubleshooting; Situational Awareness; Distraction',
#  'Distraction; Situational Awareness; Time Pressure; Workload; Communication Breakdown; Confusion',
#  'Workload; Human-Machine Interface; Distraction; Confusion; Communication Breakdown; Time Pressure',
#  'Distraction; Time Pressure; Workload; Confusion; Communication Breakdown',
#  'Troubleshooting; Situational Awareness; Distraction; Human-Machine Interface',
#  'Communication Breakdown; Confusion; Workload; Distraction; Situational Awareness; Training / Qualification',
#  'Distraction; Human-Machine Interface; Confusion',
#  'Situational Awareness; Communication Breakdown; Confusion; Distraction; Troubleshooting',
#  'Confusion; Workload; Distraction; Situational Awareness; Time Pressure; Communication Breakdown',
#  'Situational Awareness; Troubleshooting; Distraction; Communication Breakdown; Confusion',
#  'Distraction; Troubleshooting; Time Pressure; Communication Breakdown; Confusion; Situational Awareness',
#  'Physiological - Other; Fatigue; Workload',
#  'Troubleshooting; Training / Qualification; Situational Awareness; Confusion; Distraction',
#  'Situational Awareness; Time Pressure; Workload; Human-Machine Interface; Communication Breakdown; Confusion; Distraction',
#  'Training / Qualification; Situational Awareness; Human-Machine Interface; Distraction; Communication Breakdown; Confusion',
#  'Situational Awareness; Communication Breakdown; Confusion; Troubleshooting',
#  'Workload; Troubleshooting; Situational Awareness; Distraction',
#  'Troubleshooting; Time Pressure; Situational Awareness; Distraction; Confusion; Communication Breakdown; Workload',
#  'Fatigue; Other / Unknown',
#  'Communication Breakdown; Confusion; Human-Machine Interface',
#  'Confusion; Communication Breakdown; Time Pressure; Workload',
#  'Situational Awareness; Training / Qualification; Workload; Communication Breakdown; Distraction',
#  'Distraction; Situational Awareness; Troubleshooting',
#  'Distraction; Communication Breakdown; Workload',
#  'Communication Breakdown; Human-Machine Interface; Training / Qualification; Situational Awareness',
#  'Confusion; Distraction; Situational Awareness; Time Pressure; Troubleshooting; Workload; Communication Breakdown',
#  'Communication Breakdown; Physiological - Other',
#  'Situational Awareness; Distraction; Confusion; Communication Breakdown; Time Pressure',
#  'Situational Awareness; Fatigue; Distraction; Communication Breakdown; Confusion',
#  'Time Pressure; Workload; Human-Machine Interface; Confusion',
#  'Communication Breakdown; Situational Awareness; Time Pressure; Distraction; Workload',
#  'Communication Breakdown; Confusion; Distraction; Training / Qualification',
#  'Distraction; Workload; Communication Breakdown; Confusion',
#  'Distraction; Situational Awareness; Training / Qualification; Workload',
#  'Workload; Training / Qualification; Situational Awareness; Distraction; Confusion; Communication Breakdown',
#  'Workload; Situational Awareness; Confusion; Communication Breakdown; Physiological - Other',
#  'Situational Awareness; Workload; Time Pressure; Fatigue; Confusion',
#  'Training / Qualification; Situational Awareness; Confusion',
#  'Workload; Situational Awareness; Human-Machine Interface; Distraction',
#  'Situational Awareness; Communication Breakdown; Confusion; Distraction; Workload',
#  'Situational Awareness; Human-Machine Interface; Distraction; Confusion; Communication Breakdown; Training / Qualification',
#  'Workload; Time Pressure; Situational Awareness; Confusion; Communication Breakdown; Distraction',
#  'Situational Awareness; Training / Qualification; Time Pressure; Distraction; Communication Breakdown',
#  'Workload; Situational Awareness; Communication Breakdown; Confusion',
#  'Confusion; Distraction; Troubleshooting; Training / Qualification; Situational Awareness',
#  'Situational Awareness; Distraction; Confusion; Training / Qualification',
#  ...]

# %%
# Make a list of all 'Human Factor' entries
hum_facts = list()
for entry in df['Human Factors']:
    split = str(entry).split(sep = '; ') # include a space after ';'
    hum_facts = hum_facts + split

# Countplot:
fig = plt.figure(figsize= (13,7))

sns.countplot(x = hum_facts, order= pd.Series(hum_facts).value_counts().index) # need to transform list to pd.Series for the ordering in countplot()
plt.xticks(rotation=90)
plt.title('Human Factors', fontsize=20);

# %% [markdown]
# ### These 'Human Factor' entries are also interesting and challenging labels that our robot should corretly label the narratives with

# %%
# Make a list of all 'Human Factor.1' entries
hum_facts = list()
for entry in df['Human Factors.1']:
    split = str(entry).split(sep = '; ') # include a space after ';'
    hum_facts = hum_facts + split

# Countplot:
fig = plt.figure(figsize= (13,7))

sns.countplot(x = hum_facts, order= pd.Series(hum_facts).value_counts().index) # need to transform list to pd.Series for the ordering in countplot()
plt.xticks(rotation=90)
plt.title('Human Factors.1', fontsize=20);

# %% [markdown]
# The 'Human Factors.1' follow the same hierarchy as the 'Human Factors' entries (except nan).

# %% [markdown]
# ### 'Function'

# %%
list(df['Function'].unique())
# Out:
# ['Departure; Approach',
#  'Enroute',
#  'Pilot Flying; First Officer',
#  'Ground',
#  'Single Pilot',
#  'Approach; Departure',
#  'Pilot Not Flying; Instructor',
#  'Captain; Pilot Not Flying',
#  'Pilot Flying',
#  'Pilot Not Flying; Captain',
#  'First Officer; Pilot Not Flying',
#  'Captain; Pilot Flying',
#  'Pilot Flying; Captain',
#  'Local',
#  'Pilot Not Flying; First Officer',
#  'First Officer',
#  'Instructor; Pilot Not Flying',
#  'Single Pilot; Pilot Flying',
#  'Instructor; Pilot Flying',
#  'First Officer; Pilot Flying',
#  'Ground; Supervisor / CIC',
#  'Captain',
#  'Pilot Flying; Single Pilot',
#  nan,
#  'Pilot Not Flying; Relief Pilot',
#  'Pilot Not Flying',
#  'Flight Service',
#  'Pilot Flying; Trainee',
#  'Captain; Instructor',
#  'Pilot Not Flying; Check Pilot; Captain',
#  'Instructor',
#  'Pilot Not Flying; Instructor; Captain',
#  'Other / Unknown',
#  'Pilot Flying; Instructor',
#  'Traffic Management',
#  'Check Pilot; Instructor',
#  'Supervisor / CIC',
#  'Captain; Single Pilot',
#  'Enroute; Handoff / Assist',
#  'Departure',
#  'Approach',
#  'Ground; Local; Flight Data / Clearance Delivery',
#  'Trainee; Pilot Flying',
#  'Observer',
#  'Pilot Not Flying; Check Pilot',
#  'Approach; Instructor',
#  'Flight Data / Clearance Delivery',
#  'Captain; Pilot Flying; Single Pilot',
#  'Ramp',
#  'Single Pilot; Instructor; Pilot Flying',
#  'Check Pilot; Captain',
#  'Local; Trainee',
#  'Approach; Supervisor / CIC',
#  'Captain; Instructor; Pilot Flying',
#  'Trainee; Approach',
#  'Departure; Instructor',
#  'Relief Pilot',
#  'Approach; Local',
#  'Enroute; Instructor',
#  'FBO Personnel',
#  'Handoff / Assist; Enroute',
#  'Supervisor / CIC; Ground',
#  'Local; Supervisor / CIC',
#  'Enroute; Supervisor / CIC',
#  'Dispatcher',
#  'Instructor; Local',
#  'Captain; Check Pilot; Pilot Not Flying',
#  'Supervisor / CIC; Enroute',
#  'Trainee; Local',
#  'Pilot Not Flying; Captain; Check Pilot',
#  'Check Pilot',
#  'Single Pilot; Captain',
#  'Departure; Enroute',
#  'Captain; Check Pilot',
#  'Flight Attendant (On Duty)',
#  'Local; Instructor',
#  'Flight Data / Clearance Delivery; Ground; Supervisor / CIC; Local',
#  'Handoff / Assist; Approach',
#  'Approach; Instructor; Pilot Not Flying',
#  'Check Pilot; Pilot Not Flying; Captain',
#  'Local; Pilot Flying; Captain; Single Pilot',
#  'Enroute; Oceanic',
#  'Instructor; Approach',
#  'Ground; Local',
#  'Handoff / Assist; Local; Supervisor / CIC',
#  'Flight Attendant In Charge',
#  'Check Pilot; Instructor; Pilot Not Flying',
#  'Instructor; Enroute',
#  'Supervisor / CIC; Local',
#  'Technician',
#  'Captain; Flight Engineer / Second Officer; Pilot Flying; Single Pilot',
#  'Captain; Single Pilot; Pilot Flying',
#  'Approach; Captain; Pilot Flying',
#  'Supervisor / CIC; Approach',
#  'Oceanic; Enroute',
#  'Instructor; Approach; Departure',
#  'Single Pilot; Captain; Pilot Flying',
#  'Pilot Flying; Check Pilot; Captain',
#  'Check Pilot; Instructor; Pilot Not Flying; Captain',
#  'Captain; Check Pilot; Pilot Not Flying; Instructor',
#  'First Officer; Relief Pilot',
#  'Pilot Flying; Captain; Instructor',
#  'Relief Pilot; Pilot Not Flying; First Officer',
#  'Handoff / Assist',
#  'Trainee; Enroute',
#  'First Officer; Relief Pilot; Pilot Not Flying',
#  'Local; Handoff / Assist',
#  'Ground; Instructor',
#  'Single Pilot; Pilot Not Flying',
#  'Pilot Flying; Captain; Single Pilot',
#  'Flight Data / Clearance Delivery; Ground; Supervisor / CIC',
#  'Approach; Departure; Trainee',
#  'Instructor; Ground',
#  'Instructor; Single Pilot',
#  'Handoff / Assist; Local',
#  'Pilot Flying; Single Pilot; Captain',
#  'Trainee; Pilot Not Flying',
#  'Instructor; Oceanic',
#  'Oceanic',
#  'Captain; Ramp',
#  'Coordinator',
#  'Single Pilot; Pilot Flying; First Officer; Gate Agent / CSR',
#  'Departure; Approach; Instructor',
#  'Supervisor / CIC; Flight Data / Clearance Delivery',
#  'Local; Flight Data / Clearance Delivery; Ground',
#  'Instructor; Departure',
#  'Ground; Local; Supervisor / CIC',
#  'Departure; Pilot Flying',
#  'Vehicle Driver',
#  'Lead Technician',
#  'Departure; Trainee',
#  'Local; Coordinator',
#  'Approach; Handoff / Assist',
#  'Departure; Handoff / Assist',
#  'Handoff / Assist; Enroute; Trainee',
#  'Flight Attendant In Charge; Flight Attendant (On Duty)',
#  'Enroute; Approach',
#  'Departure; Coordinator',
#  'Check Pilot; Pilot Not Flying',
#  'Enroute; Pilot Flying; Single Pilot',
#  'Single Pilot; Pilot Flying; Captain',
#  'Local; Ground',
#  'Local; Pilot Flying; Single Pilot',
#  'Local; Captain; Pilot Flying',
#  'Flight Attendant (On Duty); Captain; Pilot Flying',
#  'Departure; Captain; Pilot Flying',
#  'Dispatcher; Ramp',
#  'Passenger',
#  'Pilot Flying; Other / Unknown',
#  'Trainee',
#  'Approach; Trainee',
#  'Flight Engineer / Second Officer; Single Pilot; Pilot Flying',
#  'Flight Data / Clearance Delivery; Supervisor / CIC',
#  'Enroute; Captain; Pilot Not Flying',
#  'Single Pilot; Flight Engineer / Second Officer',
#  'Other / Unknown; Other / Unknown',
#  'Captain; Check Pilot; Pilot Flying',
#  'Pilot Not Flying; Safety Pilot',
#  'Pilot Not Flying; Relief Pilot; First Officer',
#  'Enroute; Trainee',
#  'Flight Data / Clearance Delivery; Local; Ground',
#  'Enroute; Traffic Management',
#  'First Officer; Pilot Not Flying; Check Pilot',
#  'Coordinator; Supervisor / CIC',
#  'Trainee; Handoff / Assist',
#  'Instructor; Departure; Approach',
#  'Flight Data / Clearance Delivery; Handoff / Assist; Instructor',
#  'Check Pilot; Captain; Pilot Not Flying',
#  'Check Pilot; Captain; Pilot Flying',
#  'Flight Data / Clearance Delivery; Ground',
#  'Trainee; Departure; Approach',
#  'Captain; Instructor; Pilot Not Flying',
#  'Single Pilot; Instructor',
#  'Single Pilot; Pilot Not Flying; Instructor',
#  'skydiver',
#  'Pilot Not Flying; Single Pilot',
#  'Approach; Supervisor / CIC; Departure',
#  'Other / Unknown; Unicom Operations',
#  'Captain; Flight Engineer / Second Officer',
#  'Single Pilot; First Officer; Pilot Flying',
#  'Check Pilot; Pilot Flying; Captain',
#  'First Officer; Relief Pilot; Pilot Flying',
#  'First Officer; Pilot Not Flying; Relief Pilot',
#  'Relief Pilot; Captain',
#  'Instructor; Check Pilot; Pilot Flying',
#  'Flight Engineer / Second Officer',
#  'Pilot Flying; Captain; Check Pilot',
#  'First Officer; Pilot Flying; Relief Pilot',
#  'Relief Pilot; Pilot Flying',
#  'Pilot Not Flying; Flight Engineer / Second Officer',
#  'Relief Pilot; First Officer',
#  'Flight Attendant (On Duty); Flight Attendant In Charge',
#  'Relief Pilot; First Officer; Pilot Not Flying',
#  'Relief Pilot; Pilot Flying; First Officer',
#  'Pilot Not Flying; First Officer; Relief Pilot',
#  'Pilot Not Flying; Captain; Relief Pilot',
#  'Captain; Pilot Not Flying; Check Pilot',
#  'Pilot Not Flying; Relief Pilot; Captain',
#  'Supervisor / CIC; Handoff / Assist; Approach; Departure',
#  'Pilot Flying; Relief Pilot',
#  'Local; Supervisor / CIC; Ground; Flight Data / Clearance Delivery',
#  'Captain; Other / Unknown',
#  'Relief Pilot; Pilot Not Flying',
#  'Traffic Management; Enroute; Instructor',
#  'Captain; Pilot Flying; Check Pilot',
#  'Pilot Flying; Instructor; Captain',
#  'Pilot Flying; Check Pilot',
#  'Off Duty',
#  'Handoff / Assist; Oceanic',
#  'Pilot Flying; First Officer; Airport Personnel',
#  'Pilot Flying; Single Pilot; Ramp',
#  'Relief Pilot; Pilot Not Flying; Captain',
#  'Safety Manager',
#  'Flight Data / Clearance Delivery; Captain',
#  'Approach; First Officer; Pilot Flying',
#  'Ground; Pilot Flying',
#  'Captain; Relief Pilot',
#  'Flight Data / Clearance Delivery; Approach',
#  'Local; First Officer; Pilot Not Flying',
#  'Relief Pilot; First Officer; Pilot Flying',
#  'Captain; Technician; Lead Technician',
#  'Approach; Captain; Pilot Not Flying',
#  'First Officer; Pilot Flying; Pilot Not Flying',
#  'Trainee; Technician',
#  'Flight Engineer / Second Officer; Pilot Not Flying',
#  'Check Pilot; Pilot Flying',
#  'Approach; Enroute',
#  'Ramp; Safety Analyst',
#  'Instructor; Captain',
#  'Captain; SAFETY MANAGER',
#  'Pilot Not Flying; Instructor; DPE',
#  'SMS Analyst',
#  'Pilot Flying; Captain; Flight Engineer / Second Officer',
#  'Other / Unknown; Safety Ananlyst',
#  'Departure; Approach; Enroute',
#  'Departure; Supervisor / CIC',
#  'Ground; Supervisor / CIC; Local',
#  'Supervisor / CIC; Local; Flight Data / Clearance Delivery; Ground',
#  'Single Pilot; Trainee',
#  'Approach; Enroute; Departure',
#  'Instructor; Enroute; Handoff / Assist',
#  'Enroute; Approach; Departure',
#  'Approach; Enroute; Supervisor / CIC',
#  'Supervisor / CIC; Local; Instructor',
#  'Captain; Pilot Flying; Vehicle Driver',
#  'Trainee; Ground',
#  'Local; Approach; Departure; Ground; Flight Data / Clearance Delivery',
#  'Approach; Enroute; Handoff / Assist',
#  'Handoff / Assist; Trainee',
#  'Supervisor / CIC; Flight Data / Clearance Delivery; Ground',
#  'Departure; Approach; Supervisor / CIC',
#  'Flight Data / Clearance Delivery; Ground; Local; Supervisor / CIC',
#  'Captain; Lead Technician',
#  'Enroute; Captain; Pilot Flying',
#  'Approach; Pilot Flying; First Officer',
#  'Supervisor / CIC; Local; Ground',
#  'Trainee; Pilot Not Flying; Single Pilot',
#  'Single Pilot; Pilot Not Flying; Observer',
#  'Ground; Flight Data / Clearance Delivery; Local',
#  'Approach; Coordinator',
#  'Traffic Management; Enroute',
#  'Ground; Instructor; Local',
#  'First Officer; Check Pilot; Pilot Flying; Instructor',
#  'Departure; Approach; Enroute; Trainee',
#  'Operations Manager',
#  'Local; Ground; Instructor',
#  'Ground; Flight Data / Clearance Delivery; Supervisor / CIC',
#  'Ground; Supervisor / CIC; Flight Data / Clearance Delivery',
#  'Supervisor / CIC; Traffic Management',
#  'Instructor; Ground; Local',
#  'Local; Approach',
#  'Safety Officer',
#  'Ground; Single Pilot; Pilot Flying',
#  'Ground; Captain; Pilot Flying',
#  'Ground; First Officer; Pilot Not Flying',
#  'Pilot Flying; Flight Engineer / Second Officer',
#  'Dispatcher; Pilot Flying; First Officer',
#  'Pilot Not Flying; Captain; Instructor',
#  'Technician; Parts / Stores Personnel',
#  'Instructor; Flight Engineer / Second Officer',
#  'Flight Engineer / Second Officer; Pilot Flying; Captain',
#  'Ramp; Vehicle Driver',
#  'Trainee; Pilot Flying; Captain',
#  'Handoff / Assist; Instructor; Enroute',
#  'Local; Ground; Flight Data / Clearance Delivery',
#  'First Officer; Trainee; Pilot Not Flying',
#  'Flight Data / Clearance Delivery; Ground; Local',
#  'Instructor; Pilot Not Flying; First Officer',
#  'Supervisor / CIC; Traffic Management; Enroute',
#  'Traffic Management; Enroute; Supervisor / CIC',
#  'Instructor; Captain; Pilot Not Flying',
#  'Supervisor / CIC; Ground; Flight Data / Clearance Delivery',
#  'Flight Data / Clearance Delivery; Pilot Flying; Single Pilot',
#  'Pilot Not Flying; Captain; Other / Unknown',
#  'Supervisor / CIC; Instructor',
#  'Approach; Pilot Flying; Captain',
#  'Drone Operator',
#  'Oceanic; Pilot Not Flying; First Officer',
#  'Jet bridge Operator',
#  'Flight Data / Clearance Delivery; Supervisor / CIC; Ground',
#  'Airport Personnel',
#  'Enroute; Approach; Pilot Flying; Captain',
#  'Supervisor / CIC; Approach; Departure; Local',
#  'Instructor; Pilot Flying; Captain',
#  'Enroute; Departure',
#  'Captain; Pilot Not Flying; Relief Pilot',
#  'Instructor; First Officer; Check Pilot; Pilot Flying',
#  'Supervisor / CIC; Departure',
#  'Enroute; Flight Engineer / Second Officer',
#  'Captain; Check Pilot; Instructor',
#  'Pilot Flying; Single Pilot; With DPE',
#  'Single Pilot; Pilot Flying; Check Pilot; Captain',
#  'Local Civilian',
#  'Trainee; Departure',
#  'Approach; Departure; Instructor',
#  'Departure; Instructor; Approach',
#  'Check Pilot; First Officer; Pilot Not Flying',
#  'Approach; Traffic Management',
#  'Flight Data / Clearance Delivery; Local; Supervisor / CIC; Ground',
#  'Instructor; Pilot Flying; Single Pilot',
#  'Traffic Management; Approach',
#  'Supervisor / CIC; Approach; Instructor',
#  'Ground; Trainee',
#  'Approach; Departure; Supervisor / CIC',
#  'Flight Engineer / Second Officer; Captain; Pilot Flying',
#  'Check Pilot; Pilot Not Flying; Instructor',
#  'Captain; Pilot Flying; Technician; Inspector',
#  'First Officer; Ramp',
#  'Trainee; First Officer',
#  'Supervisor / CIC; Ground; Local',
#  'Off Duty; Other / Unknown',
#  'Trainee; Captain; Pilot Flying',
#  'Departure; Single Pilot',
#  'Trainee; Pilot Flying; Single Pilot',
#  'Approach; Captain; Pilot Flying; Single Pilot',
#  'Pilot Flying; Flight Engineer / Second Officer; Captain',
#  'Single Pilot; Trainee; Pilot Flying']

# %%
# Make a list of all 'Function' entries
functions = list()
for entry in df['Function']:
    split = str(entry).split(sep = '; ') # include a space after ';'
    functions = functions + split

# Countplot:
fig = plt.figure(figsize= (13,7))

sns.countplot(x = functions, order= pd.Series(functions).value_counts().index) # need to transform list to pd.Series for the ordering in countplot()
plt.xticks(rotation=90)
plt.title('Functions', fontsize=20);

# %% [markdown]
# ### 'Qualification'

# %%
list(df['Qualification'].unique())
# Out:
# ['Air Traffic Control Developmental',
#  'Air Traffic Control Fully Certified',
#  nan,
#  'Flight Crew Private',
#  'Flight Crew Commercial; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Multiengine',
#  'Flight Crew Student',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor',
#  'Flight Crew Commercial',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Private; Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Commercial; Flight Crew Flight Instructor',
#  'Flight Crew Private; Flight Crew Instrument',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Instrument; Flight Crew Private',
#  'Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Multiengine; Flight Crew Commercial',
#  'Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Commercial',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Flight Engineer',
#  'Air Traffic Control Fully Certified; Flight Crew Instrument; Flight Crew Private',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Flight Instructor',
#  'Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Commercial; Flight Crew Flight Instructor',
#  'Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Instrument',
#  'Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Commercial',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Commercial',
#  'Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Commercial',
#  'Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Rotorcraft; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Glider; Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Glider; Flight Crew Instrument; Flight Crew Private',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Commercial; Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Commercial; Flight Crew Flight Engineer',
#  'Flight Crew Instrument; Flight Crew Private; Flight Crew Multiengine; Flight Crew Commercial',
#  'Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor',
#  'Flight Crew Multiengine; Flight Crew Rotorcraft; Flight Crew Instrument; Flight Crew Glider; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Flight Crew Multiengine; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Multiengine; Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Private; Flight Crew Instrument',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor',
#  'Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Commercial; Flight Crew Rotorcraft; Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Flight Crew Flight Instructor',
#  'Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Commercial',
#  'Flight Crew Multiengine; Flight Crew Private',
#  'Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Instrument',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer',
#  'Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Sea',
#  'Flight Crew Instrument; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine',
#  'Flight Crew Commercial; Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor',
#  'Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Attendant Current',
#  'Flight Crew Rotorcraft; Flight Crew Sea; Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Sea',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Commercial',
#  'Flight Crew Lighter-Than-Air; Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Commercial',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Instrument',
#  'Air Traffic Control Fully Certified; Flight Crew Instrument',
#  'Dispatch Dispatcher; Flight Crew Private',
#  'Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Commercial',
#  'Dispatch Dispatcher',
#  'Flight Crew Flight Instructor; Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer',
#  'Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Flight Instructor',
#  'Maintenance Airframe; Maintenance Powerplant',
#  'Flight Crew Flight Engineer; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Commercial; Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine; Other ATP',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Commercial; Other SEA',
#  'Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Private; Flight Crew Glider; Other Glider',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Multiengine',
#  'Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Sport / Recreational',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine',
#  'Air Traffic Control Fully Certified; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Flight Engineer',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor',
#  'Maintenance Powerplant; Maintenance Inspection Authority; Maintenance Airframe',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Rotorcraft; Flight Crew Glider; Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Private',
#  'Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Sea; Flight Crew Multiengine',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Private',
#  'Flight Crew Multiengine',
#  'Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine; Maintenance Powerplant; Maintenance Airframe',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor',
#  'Flight Crew Sea; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Rotorcraft',
#  'Flight Crew Private; Flight Crew Sea; Flight Crew Instrument',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Private',
#  'Flight Crew Private; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Glider',
#  'Air Traffic Control Fully Certified; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Private',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Commercial; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine',
#  'Flight Crew Commercial; Flight Crew Rotorcraft',
#  'Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Glider; Flight Crew Flight Instructor',
#  'Flight Crew Commercial; Flight Crew Glider; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Sea; Flight Crew Flight Instructor',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Instrument',
#  'Flight Crew Rotorcraft; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Instrument',
#  'Flight Crew Flight Engineer; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Flight Instructor',
#  'Flight Crew Glider; Flight Crew Private',
#  'Flight Crew Instrument; Flight Crew Commercial; Flight Crew Flight Instructor',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Private; Flight Crew Sport / Recreational; Flight Crew Commercial',
#  'Flight Crew Flight Engineer; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Commercial; Flight Crew Instrument; Flight Crew Rotorcraft; Flight Crew Multiengine',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Flight Instructor',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Rotorcraft; Flight Crew Instrument',
#  'Flight Crew Rotorcraft; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Sea; Flight Crew Flight Engineer',
#  'Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor',
#  'Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Glider',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Commercial; Flight Crew Rotorcraft',
#  'Air Traffic Control Fully Certified; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Rotorcraft; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Instrument',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Commercial; Flight Crew Flight Engineer; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Sea',
#  'Flight Crew Flight Instructor; Flight Crew Rotorcraft; Flight Crew Commercial',
#  'Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Sea; Flight Crew Rotorcraft',
#  'Air Traffic Control Fully Certified; Flight Crew Instrument; Flight Crew Commercial; Flight Crew Multiengine',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Engineer',
#  'Air Traffic Control Fully Certified; Flight Crew Lighter-Than-Air',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Rotorcraft; Flight Crew Commercial',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Flight Instructor',
#  'Flight Crew Rotorcraft',
#  'Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Rotorcraft; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Glider; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Sea; Flight Crew Rotorcraft',
#  'Flight Crew Instrument; Flight Crew Rotorcraft; Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Multiengine; Flight Crew Rotorcraft',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Rotorcraft',
#  'Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Commercial',
#  'Flight Crew Glider; Flight Crew Private; Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Flight Instructor',
#  'Air Traffic Control Fully Certified; Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Commercial',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Commercial',
#  'Flight Crew Commercial; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Flight Engineer',
#  'Air Traffic Control Fully Certified; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Private; Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Commercial; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Private; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Flight Crew Commercial; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Multiengine',
#  'Flight Crew Private; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Commercial',
#  'Flight Crew Commercial; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Private',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Sea',
#  'Flight Crew Instrument; Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Private',
#  'Flight Crew Instrument; Flight Crew Private; Flight Crew Glider',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Maintenance Airframe; Maintenance Powerplant',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Commercial; Flight Crew Private',
#  'Air Traffic Control Fully Certified; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Commercial',
#  'Flight Crew Multiengine; Flight Crew Private; Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Commercial; Flight Crew Private',
#  'Flight Crew Commercial; Flight Crew Instrument; Flight Crew Sea',
#  'Air Traffic Control Fully Certified; Flight Crew Student',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Commercial; Other EASA/FAA',
#  'Flight Crew Rotorcraft; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Commercial; Flight Crew Glider; Flight Crew Instrument; Flight Crew Multiengine',
#  'Air Traffic Control Fully Certified; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Multiengine; Other type rated in this a/c',
#  'Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Other Commercial Rotorcraft',
#  'Air Traffic Control Fully Certified; Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Instrument',
#  'Maintenance Avionics; Maintenance Inspection Authority; Maintenance Powerplant; Maintenance Airframe',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer',
#  'Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Flight Engineer',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew

#  'Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Glider',
#  'Air Traffic Control Fully Certified; Flight Crew Commercial; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Glider; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Sea; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Rotorcraft; Flight Crew Commercial; Flight Crew Flight Instructor',
#  'Flight Crew Rotorcraft; Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Flight Crew Rotorcraft; Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine',
#  'Air Traffic Control Fully Certified; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Sea; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Air Traffic Control Fully Certified; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Instrument',
#  'Flight Attendant Current; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Private; Flight Crew Commercial',
#  'Flight Crew Multiengine; Flight Crew Sea; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Instrument; Flight Crew Private; Flight Crew Student',
#  'Flight Crew Sea; Flight Crew Private; Flight Crew Instrument',
#  'Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Flight Engineer; Flight Crew Multiengine',
#  'Flight Crew Flight Engineer; Flight Crew Private',
#  'Air Traffic Control Fully Certified; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Flight Crew Private; Flight Crew Flight Engineer',
#  'Air Traffic Control Fully Certified; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Glider; Flight Crew Sport / Recreational',
#  'Air Traffic Control Fully Certified; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Glider; Other Glider',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Flight Instructor; Other Remote Pilot',
#  'Flight Crew Private; Flight Crew Instrument; Other A&P',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine; Other DPE',
#  'Flight Crew Student; Other endorsed for solo flight',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Other CFI-I',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Commercial; Flight Crew Flight Instructor',
#  'Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Glider',
#  'Flight Crew Multiengine; Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Instrument; Maintenance Powerplant; Maintenance Airframe',
#  'Flight Crew Rotorcraft; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Glider; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Glider; Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Rotorcraft',
#  'Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer',
#  'Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Sea; Flight Crew Glider; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Instrument; Flight Crew Rotorcraft',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Rotorcraft',
#  'Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine',
#  'Flight Crew Commercial; Flight Crew Instrument; Flight Crew Rotorcraft; Flight Crew Flight Instructor',
#  'Flight Crew Rotorcraft; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Commercial',
#  'Flight Crew Sea; Flight Crew Air Transport Pilot (ATP); Flight Crew Glider; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Flight Crew Rotorcraft; Flight Crew Sea; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Private; Flight Crew Multiengine',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Commercial',
#  'Flight Crew Commercial; Flight Crew Glider; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Sea',
#  'Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Commercial',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Instructor',
#  'Flight Crew Instrument; Flight Crew Rotorcraft; Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Flight Crew Private; Flight Crew Glider',
#  'Flight Crew Rotorcraft; Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Multiengine; Flight Crew Rotorcraft; Flight Crew Commercial; Flight Crew Instrument',
#  'Flight Crew Multiengine; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Air Traffic Control Fully Certified; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Glider; Flight Crew Commercial',
#  'Flight Crew Flight Engineer; Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Flight Instructor; Flight Crew Lighter-Than-Air',
#  'Air Traffic Control Fully Certified; Dispatch Dispatcher; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Air Traffic Control Fully Certified; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor',
#  'Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP); Flight Crew Commercial; Flight Crew Flight Instructor',
#  'Flight Crew Instrument; Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Commercial',
#  'Flight Crew Private; Flight Crew Rotorcraft',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Commercial; Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Maintenance Airframe; Maintenance Powerplant',
#  'Other Remote Pilot',
#  'Flight Crew Private; Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Multiengine; Other ATP',
#  'Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Flight Instructor',
#  'Flight Crew Private; Flight Crew Commercial',
#  'Flight Crew Commercial; Flight Crew Rotorcraft; Flight Crew Instrument; Flight Crew Flight Instructor',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Commercial; Other TAIL WHEEL',
#  'Flight Crew Instrument; Flight Crew Commercial; Flight Crew Flight Instructor; Other LSA repairman',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Private',
#  'Flight Crew Flight Engineer; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Rotorcraft; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Rotorcraft',
#  'Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Private; Flight Crew Instrument',
#  'Flight Crew Commercial; Flight Crew Flight Engineer',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Rotorcraft',
#  'Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Rotorcraft; Flight Crew Glider',
#  'Flight Crew Instrument; Flight Crew Glider; Flight Crew Commercial; Flight Crew Multiengine',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine; Flight Crew Rotorcraft',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Flight Instructor; Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP)',
#  'Flight Crew Multiengine; Flight Crew Flight Instructor; Flight Crew Commercial',
#  'Flight Crew Commercial; Flight Crew Flight Engineer; Flight Crew Multiengine; Flight Crew Instrument',
#  'Flight Crew Glider; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Sea',
#  'Flight Crew Commercial; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Rotorcraft',
#  'Flight Crew Flight Engineer; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Rotorcraft; Flight Crew Commercial',
#  'Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Flight Engineer',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor; Flight Crew Flight Engineer',
#  'Flight Crew Commercial; Flight Crew Glider; Flight Crew Instrument',
#  'Flight Crew Multiengine; Flight Crew Sea; Flight Crew Commercial; Flight Crew Flight Instructor; Flight Crew Instrument',
#  'Flight Crew Commercial; Flight Crew Multiengine; Flight Crew Instrument; Maintenance Airframe; Maintenance Powerplant',
#  'Air Traffic Control Fully Certified; Flight Crew Air Transport Pilot (ATP); Flight Crew Multiengine',
#  'Flight Crew Flight Instructor; Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Flight Engineer',
#  'Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Flight Instructor; Flight Crew Commercial; Maintenance Airframe; Maintenance Powerplant',
#  'Flight Crew Flight Instructor; Flight Crew Commercial; Flight Crew Instrument; Flight Crew Private',
#  'Flight Crew Instrument; Flight Crew Rotorcraft; Flight Crew Commercial; Flight Crew Flight Instructor',
#  'Air Traffic Control Fully Certified; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Commercial; Flight Crew Flight Instructor',
#  'Air Traffic Control Fully Certified; Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Air Transport Pilot (ATP)',
#  'Air Traffic Control Fully Certified; Flight Crew Multiengine; Flight Crew Instrument; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Instructor',
#  'Air Traffic Control Fully Certified; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Instrument; Flight Crew Multiengine; Flight Crew Commercial; Flight Crew Private',
#  'Air Traffic Control Fully Certified; Flight Crew Air Transport Pilot (ATP); Flight Crew Flight Engineer; Flight Crew Flight Instructor; Flight Crew Instrument; Flight Crew Multiengine',
#  'Flight Crew Air Transport Pilot (ATP); Flight Crew Instrument; Flight Crew Multiengine; Maintenance Airframe; Maintenance Powerplant']

# %%
# Make a list of all 'Qualification' entries
qualifications = list()
for entry in df['Qualification']:
    split = str(entry).split(sep = '; ') # include a space after ';'
    qualifications = qualifications + split

# Countplot:
fig = plt.figure(figsize= (13,7))

sns.countplot(x = qualifications, order= pd.Series(qualifications).value_counts().index) # need to transform list to pd.Series for the ordering in countplot()
plt.xticks(rotation=90)
plt.title('Qualification', fontsize=20);

# %% [markdown]
# ### 'Experience'

# %%
list(df['Experience'].unique())
# Out:
# [nan,
#  'Flight Crew Last 90 Days 156; Flight Crew Type 290',
#  'Flight Crew Last 90 Days 7; Flight Crew Total 314; Flight Crew Type 140',
#  'Flight Crew Last 90 Days 45; Flight Crew Total 4500; Flight Crew Type 1100',
#  'Flight Crew Last 90 Days 300; Flight Crew Total 5500; Flight Crew Type 4000',
#  'Flight Crew Last 90 Days 210; Flight Crew Total 17550; Flight Crew Type 10250',
#  'Flight Crew Last 90 Days 178; Flight Crew Type 12000',
#  'Flight Crew Last 90 Days 25; Flight Crew Total 220; Flight Crew Type 160',
#  'Flight Crew Last 90 Days 185',
#  'Flight Crew Last 90 Days 75; Flight Crew Total 3850; Flight Crew Type 675',
#  'Flight Crew Last 90 Days 75; Flight Crew Total 12500; Flight Crew Type 1425',
#  'Flight Crew Last 90 Days 5; Flight Crew Total 65; Flight Crew Type 63',
#  'Flight Crew Last 90 Days 61; Flight Crew Total 7000; Flight Crew Type 300',
#  'Flight Crew Last 90 Days 100; Flight Crew Total 8900; Flight Crew Type 1800',
#  'Flight Crew Last 90 Days 29; Flight Crew Total 8090; Flight Crew Type 5000',
#  'Flight Crew Last 90 Days 298; Flight Crew Type 3500',
#  'Flight Crew Last 90 Days 75; Flight Crew Total 11150; Flight Crew Type 1300',
#  'Flight Crew Last 90 Days 24; Flight Crew Total 1150; Flight Crew Type 1000',
#  'Flight Crew Last 90 Days 120; Flight Crew Total 20000; Flight Crew Type 8000',
#  'Flight Crew Last 90 Days 46; Flight Crew Total 412; Flight Crew Type 42',
#  'Flight Crew Last 90 Days 210; Flight Crew Total 8500; Flight Crew Type 2000',
#  'Flight Crew Last 90 Days 90; Flight Crew Total 8000; Flight Crew Type 3500',
#  'Flight Crew Last 90 Days 437; Flight Crew Type 9700',
#  'Flight Crew Last 90 Days 320',
#  'Flight Crew Last 90 Days 35; Flight Crew Total 3100; Flight Crew Type 2900',
#  'Flight Crew Last 90 Days 318',
#  'Flight Crew Last 90 Days 15; Flight Crew Total
air Traffic Control; Person Flight Crew',
#  'Automation Aircraft Other Automation; Person Flight Crew',
#  'Automation Aircraft Terrain Warning',
#  'Automation Aircraft RA; Person Flight Crew; Person Air Traffic Control',
#  'Automation Aircraft RA; Person Air Traffic Control; Person Flight Crew',
#  'Automation Aircraft Other Automation; Person Air Traffic Control; Person Flight Crew',
#  'Automation Aircraft TA; Person Flight Crew',
#  'Person Ground Personnel',
#  'Person Other Person',
#  'Automation Air Traffic Control; Person Flight Crew',
#  'Automation Aircraft RA',
#  'Person Flight Crew; Person Ground Personnel',
#  'Person Flight Crew; Person Passenger',
#  'Person Air Traffic Control; Person Ground Personnel',
#  'Person Maintenance',
#  'Automation Air Traffic Control; Person Air Traffic Control',
#  'Automation Aircraft Terrain Warning; Person Air Traffic Control; Person Flight Crew',
#  'Automation Aircraft Terrain Warning; Automation Air Traffic Control',
#  'Automation Aircraft RA; Person Flight Crew',
#  'Automation Aircraft Other Automation; Person Air Traffic Control',
#  nan,
#  'Automation Aircraft RA; Person Air Traffic Control',
#  'Person Dispatch',
#  'Person Observer',
#  'Automation Air Traffic Control',
#  'Person Observer; Person Flight Crew',
#  'Person Flight Crew; Person Air Traffic Control',
#  'Automation Air Traffic Control; Person Air Traffic Control; Person Flight Crew',
#  'Automation Aircraft Other Automation',
#  'Automation Aircraft Terrain Warning; Person Flight Crew; Person Air Traffic Control',
#  'Person Passenger',
#  'Person Flight Crew; Person Flight Attendant',
#  'Automation Aircraft TA',
#  'Person Other Person; Person Air Traffic Control',
#  'Automation Aircraft TA; Automation Aircraft RA; Person Air Traffic Control; Person Flight Crew',
#  'Person Other Person; Person Flight Crew',
#  'Person Flight Attendant',
#  'Person Flight Attendant; Person Flight Crew',
#  'Automation Aircraft RA; Automation Aircraft TA; Person Air Traffic Control; Person Flight Crew',
#  'Automation Aircraft TA; Automation Aircraft RA',
#  'Automation Aircraft TA; Automation Aircraft RA; Person Flight Crew',
#  'Automation Aircraft RA; Automation Aircraft TA',
#  'Person Flight Attendant; Person Ground Personnel; Person Flight Crew',
#  'Automation Air Traffic Control; Person Flight Crew; Person Air Traffic Control',
#  'Automation Aircraft RA; Automation Aircraft TA; Person Flight Crew',
#  'Person Dispatch; Person Ground Personnel',
#  'Automation Aircraft RA; Automation Aircraft TA; Person Air Traffic Control',
#  'Person Passenger; Person Air Traffic Control',
#  'Automation Aircraft TA; Person Flight Crew; Person Passenger',
#  'Automation Aircraft Other Automation; Person Flight Attendant',
#  'Automation Aircraft RA; Automation Aircraft Terrain Warning; Person Flight Crew',
#  'Automation Aircraft TA; Person Passenger',
#  'Automation Aircraft Other Automation; Automation Aircraft RA; Automation Aircraft TA; Person Flight Crew',
#  'Automation Aircraft TA; Person Air Traffic Control',
#  'Person Gate Agent / CSR',
#  'Automation Aircraft Terrain Warning; Person Air Traffic Control',
#  'Automation Air Traffic Control; Person Other Person',
#  'Automation Air Traffic Control; Automation Aircraft RA; Person Air Traffic Control',
#  'Person Flight Crew; Person Dispatch',
#  'Automation Aircraft TA; Person Air Traffic Control; Person Flight Crew',
#  'Person Air Traffic Control; Person Observer',
#  'Automation Aircraft Other Automation; Person Flight Crew; Person Air Traffic Control',
#  'Automation Aircraft Terrain Warning; Automation Aircraft Other Automation; Person Flight Crew',
#  'Person Flight Crew; Person Observer',
#  'Automation Aircraft Terrain Warning; Automation Air Traffic Control; Person Flight Crew; Person Air Traffic Control',
#  'Automation Aircraft TA; Automation Aircraft Other Automation; Person Flight Crew',
#  'Person Passenger; Person Observer; Person Flight Crew',
#  'Person Observer; Person Air Traffic Control',
#  'Person Passenger; Person Flight Crew',
#  'Person Ground Personnel; Person Flight Crew',
#  'Automation Air Traffic Control; Automation Aircraft Terrain Warning; Person Air Traffic Control',
#  'Automation Aircraft Terrain Warning; Automation Aircraft TA',
#  'Person Flight Crew; Person Other Person',
#  'Person Flight Crew; Person Maintenance',
#  'Automation Aircraft RA; Automation Aircraft Terrain Warning',
#  'Person Air Traffic Control; Person Dispatch; Person Flight Crew',
#  'Automation Aircraft TA; Automation Aircraft Terrain Warning',
#  'Automation Aircraft TA; Person Flight Crew; Person Air Traffic Control',
#  'Automation Aircraft TA; Automation Air Traffic Control; Automation Aircraft RA; Person Air Traffic Control; Person Flight Crew',
#  'Automation Air Traffic Control; Automation Aircraft Terrain Warning',
#  'Person Flight Attendant; Person Flight Crew; Person Passenger',
#  'Automation Aircraft Terrain Warning; Automation Aircraft RA; Person Flight Crew; Person Air Traffic Control',
#  'Person Flight Crew; Person Gate Agent / CSR',
#  'Automation Aircraft Other Automation; Automation Aircraft Terrain Warning; Person Flight Crew',
#  'Person Dispatch; Person Flight Crew',
#  'Person Observer; Person Flight Crew; Person Air Traffic Control',
#  'Automation Aircraft RA; Automation Air Traffic Control; Person Air Traffic Control; Person Flight Crew',
#  'Person Maintenance; Person Passenger',
#  'Automation Aircraft Other Automation; Person Flight Crew; Person Ground Personnel',
#  'Person Flight Attendant; Person Passenger',
#  'Person Maintenance; Person Flight Crew',
#  'Automation Aircraft RA; Automation Aircraft TA; Person Flight Crew; Person Air Traffic Control',
#  'Person Air Traffic Control; Person Dispatch',
#  'Automation Aircraft TA; Automation Aircraft RA; Person Flight Crew; Person Observer',
#  'Person Flight Crew; Person Observer; Person Air Traffic Control',
#  'Automation Aircraft Terrain Warning; Automation Aircraft TA; Person Flight Crew',
#  'Automation Aircraft Other Automation; Automation Air Traffic Control; Person Flight Crew; Person Air Traffic Control',
#  'Automation Aircraft Other Automation; Person Maintenance',
#  'Person Passenger; Person Flight Attendant',
#  'Person Flight Attendant; Person Flight Crew; Person Ground Personnel',
#  'Person Flight Attendant; Person Gate Agent / CSR',
#  'Person Ground Personnel; Person Gate Agent / CSR',
#  'Automation Aircraft TA; Automation Aircraft Terrain Warning; Person Flight Crew',
#  'Automation Aircraft Terrain Warning; Person Flight Attendant',
#  'Person Flight Crew; Person Flight Attendant; Person Passenger',
#  'Automation Aircraft TA; Automation Aircraft RA; Person Air Traffic Control',
#  'Automation Air Traffic Control; Automation Aircraft RA; Person Flight Crew',
#  'Person Dispatch; Person Maintenance',
#  'Automation Air Traffic Control; Automation Aircraft RA; Person Air Traffic Control; Person Flight Crew',
#  'Automation Aircraft TA; Person Dispatch; Person Flight Crew',
#  'Automation Aircraft Other Automation; Person Observer; Person Flight Crew; Person Air Traffic Control',
#  'Automation Aircraft RA; Person Observer; Person Flight Crew',
#  'Person Maintenance; Person Dispatch',
#  'Person Flight Crew; Person Air Traffic Control; Person Other Person',
#  'Person Flight Attendant; Person Other Person',
#  'Person Ground Personnel; Person Other Person',
#  'Person Other Person; Person Ground Personnel',
#  'Person Ground Personnel; Person Other Person; Person Flight Attendant',
#  'Person Flight Crew; Person Flight Attendant; Person Other Person; Person Passenger',
#  'Person Ground Personnel; Person Maintenance',
#  'Automation Air Traffic Control; Automation Aircraft RA',
#  'Person Flight Attendant; Person Ground Personnel; Person Passenger',
#  'Automation Aircraft Other Automation; Person Flight Crew; Person Flight Attendant',
#  'Automation Aircraft Other Automation; Automation Aircraft TA; Person Flight Crew',
#  'Person Dispatch; Person Air Traffic Control',
#  'Person Air Traffic Control; Person Flight Crew; Person Ground Personnel',
#  'Automation Aircraft RA; Automation Air Traffic Control',
#  'Person Passenger; Person Ground Personnel; Person Other Person',
#  'Person Gate Agent / CSR; Person Air Traffic Control',
#  'Automation Air Traffic Control; Automation Aircraft Other Automation; Person Air Traffic Control',
#  'Automation Aircraft Other Automation; Person Flight Crew; Person Other Person',
#  'Automation Aircraft Other Automation; Person Flight Attendant; Person Flight Crew',
#  'Person Maintenance; Person Ground Personnel',
#  'Automation Air Traffic Control; Automation Aircraft Terrain Warning; Person Flight Crew; Person Air Traffic Control',
#  'Person Air Traffic Control; Person Other Person',
#  'Person Air Traffic Control; Person Gate Agent / CSR',
#  'Automation Aircraft RA; Person Air Traffic Control; Person Flight Crew; Person Ground Personnel',
#  'Person Flight Attendant; Person Passenger; Person Flight Crew',
#  'Person Air Traffic Control; Person Flight Attendant',
#  'Automation Air Traffic Control; Automation Aircraft Other Automation; Person Flight Crew',
#  'Person Flight Attendant; Person Air Traffic Control',
#  'Automation Air Traffic Control; Automation Aircraft Terrain Warning; Person Air Traffic Control; Person Flight Crew',
#  'Automation Aircraft Terrain Warning; Person Dispatch; Person Flight Crew',
#  'Person Other Person; Person Flight Attendant',
#  'Automation Aircraft TA; Automation Aircraft RA; Automation Aircraft Terrain Warning',
#  'Automation Aircraft TA; Automation Air Traffic Control',
#  'Person Gate Agent / CSR; Person Ground Personnel',
#  'Person Gate Agent / CSR; Person Ground Personnel; Person Dispatch',
#  'Person Ground Personnel; Person Dispatch',
#  'Automation Aircraft Terrain Warning; Automation Air Traffic Control; Person Air Traffic Control',
#  'Person Air Traffic Control; Person Passenger',
#  'Automation Aircraft Terrain Warning; Person Other Person',
#  'Automation Aircraft Other Automation; Automation Aircraft Terrain Warning; Person Air Traffic Control',
#  'Automation Aircraft Other Automation; Person Other Person',
#  'Automation Aircraft RA; Person Other Person',
#  'Automation Aircraft Other Automation; Automation Aircraft RA; Person Flight Crew',
#  'Automation Aircraft RA; Automation Air Traffic Control; Person Air Traffic Control',
#  'Automation Aircraft RA; Automation Aircraft TA; Automation Air Traffic Control; Person Air Traffic Control',
#  'Person Dispatch; Person Other Person']

# %%
# Make a list of all 'Detector' entries
detector = list()
for entry in df['Detector']:
    split = str(entry).split(sep = '; ') # include a space after ';'
    detector = detector + split

# Countplot:
fig = plt.figure(figsize= (13,7))

sns.countplot(x = detector, order= pd.Series(detector).value_counts().index) # need to transform list to pd.Series for the ordering in countplot()
plt.xticks(rotation=90)
plt.title('Detector', fontsize=20);

# %% [markdown]
# ### 'Result'

# %%
list(df['Result'].unique())
# Out:
# ['Air Traffic Control Issued New Clearance',
#  'General None Reported / Taken',
#  'Flight Crew Returned To Clearance; Flight Crew Became Reoriented',
#  'Air Traffic Control Provided Assistance; Flight Crew Diverted; Flight Crew Landed As Precaution; General Declared Emergency',
#  'Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Took Evasive Action',
#  'Aircraft Aircraft Damaged; Flight Crew Diverted; General Maintenance Action',
#  'Flight Crew Took Evasive Action; Flight Crew Became Reoriented; Flight Crew Returned To Clearance',
#  'Flight Crew Returned To Clearance',
#  'Air Traffic Control Provided Assistance; Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Returned To Clearance; Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Returned To Clearance; Flight Crew Became Reoriented; Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance',
#  'Flight Crew Regained Aircraft Control',
#  nan,
#  'Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Took Evasive Action; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew FLC complied w / Automation / Advisory',
#  'Flight Crew Requested ATC Assistance / Clarification; Flight Crew Took Evasive Action',
#  'Flight Crew Became Reoriented; Flight Crew Returned To Clearance; Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued Advisory / Alert',
#  'Air Traffic Control Provided Assistance',
#  'Aircraft Equipment Problem Dissipated; Flight Crew FLC Overrode Automation',
#  'Flight Crew Became Reoriented',
#  'Air Traffic Control Provided Assistance; Aircraft Equipment Problem Dissipated; Flight Crew Diverted; Flight Crew Returned To Departure Airport; Flight Crew Landed As Precaution; General Maintenance Action',
#  'General Flight Cancelled / Delayed; General Work Refused',
#  'Aircraft Aircraft Damaged; Flight Crew Returned To Departure Airport; Flight Crew Landed As Precaution; General Flight Cancelled / Delayed; General Maintenance Action',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Overcame Equipment Problem; Flight Crew Became Reoriented',
#  'General Declared Emergency; General Evacuated',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Air Traffic Control Separated Traffic',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented',
#  'Air Traffic Control Issued New Clearance; Flight Crew Requested ATC Assistance / Clarification',
#  'Flight Crew FLC complied w / Automation / Advisory',
#  'General Declared Emergency',
#  'Flight Crew Became Reoriented; Flight Crew FLC Overrode Automation; Flight Crew Returned To Clearance',
#  'Flight Crew Returned To Clearance; Flight Crew Overcame Equipment Problem',
#  'Flight Crew Exited Penetrated Airspace',
#  'Flight Crew Landed As Precaution; General Maintenance Action',
#  'Air Traffic Control Issued New Clearance; Flight Crew Became Reoriented',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew FLC Overrode Automation',
#  'Flight Crew Became Reoriented; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew FLC complied w / Automation / Advisory; Flight Crew Regained Aircraft Control',
#  'Air Traffic Control Issued New Clearance; Flight Crew Took Evasive Action',
#  'Flight Crew Returned To Clearance; Flight Crew FLC Overrode Automation; Flight Crew Became Reoriented',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert',
#  'Flight Crew Overcame Equipment Problem; General Declared Emergency',
#  'Flight Crew Requested ATC Assistance / Clarification; Flight Crew Took Evasive Action; Flight Crew Exited Penetrated Airspace; Flight Crew Became Reoriented',
#  'Flight Crew Overcame Equipment Problem; Flight Crew Returned To Clearance',
#  'Flight Crew Overcame Equipment Problem',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew Overcame Equipment Problem; Flight Crew Returned To Clearance',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Returned To Clearance',
#  'Aircraft Aircraft Damaged; Flight Crew Became Reoriented',
#  'Flight Crew Returned To Departure Airport; General Work Refused',
#  'Flight Crew Returned To Departure Airport; Flight Crew Took Evasive Action',
#  'Flight Crew Became Reoriented; Flight Crew FLC complied w / Automation / Advisory; Flight Crew Overcame Equipment Problem',
#  'Air Traffic Control Issued New Clearance; Flight Crew Executed Go Around / Missed Approach',
#  'Aircraft Aircraft Damaged; Flight Crew Became Reoriented; General Maintenance Action',
#  'Air Traffic Control Issued New Clearance; Flight Crew Became Reoriented; Flight Crew Returned To Clearance',
#  'Aircraft Aircraft Damaged',
#  'Flight Crew Requested ATC Assistance / Clarification',
#  'Flight Crew Returned To Gate; Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew Overcame Equipment Problem',
#  'Air Traffic Control Provided Assistance; Air Traffic Control Issued Advisory / Alert; Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew Returned To Clearance',
#  'Flight Crew Became Reoriented; Flight Crew Took Evasive Action',
#  'Flight Crew Took Evasive Action; Flight Crew Requested ATC Assistance / Clarification; Flight Crew FLC complied w / Automation / Advisory',
#  'Aircraft Equipment Problem Dissipated',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew Became Reoriented',
#  'Air Traffic Control Provided Assistance; Air Traffic Control Issued New Clearance; Flight Crew Returned To Clearance',
#  'Air Traffic Control Separated Traffic',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Provided Assistance',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Provided Assistance',
#  'Flight Crew Landed in Emergency Condition',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew Executed Go Around / Missed Approach; Flight Crew Took Evasive Action',
#  'Air Traffic Control Separated Traffic; Flight Crew Returned To Clearance',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew Returned To Clearance; Flight Crew Became Reoriented',
#  'Flight Crew Took Evasive Action; Flight Crew Became Reoriented',
#  'Flight Crew Became Reoriented; Flight Crew Returned To Clearance',
#  'Air Traffic Control Issued New Clearance; Flight Crew Became Reoriented; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew FLC complied w / Automation / Advisory; Flight Crew Took Evasive Action',
#  'Flight Crew Landed in Emergency Condition; Flight Crew Returned To Departure Airport; General Declared Emergency; General Maintenance Action',
#  'Air Traffic Control Issued New Clearance; Flight Crew Returned To Clearance',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew Returned To Clearance',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew Took Evasive Action; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Provided Assistance; Air Traffic Control Separated Traffic',
#  'Air Traffic Control Provided Assistance; General Declared Emergency',
#  'General Physical Injury / Incapacitation',
#  'Air Traffic Control Issued New Clearance; Flight Crew Took Evasive Action; Flight Crew Executed Go Around / Missed Approach; Flight Crew Regained Aircraft Control',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew Became Reoriented; Flight Crew Took Evasive Action',
#  'Flight Crew Rejected Takeoff',
#  'Air Traffic Control Separated Traffic; Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert',
#  'Flight Crew Landed As Precaution; Flight Crew Returned To Departure Airport',
#  'Flight Crew Landed As Precaution; Flight Crew Diverted; General Maintenance Action',
#  'Flight Crew Took Evasive Action; Flight Crew Requested ATC Assistance / Clarification',
#  'Flight Crew Rejected Takeoff; Flight Crew Returned To Gate; General Flight Cancelled / Delayed; General Maintenance Action',
#  'Air Traffic Control Issued New Clearance; Aircraft Automation Overrode Flight Crew; Flight Crew Returned To Clearance; Flight Crew Became Reoriented',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Provided Assistance; Flight Crew Returned To Clearance',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Took Evasive Action; Flight Crew Became Reoriented; Flight Crew Returned To Clearance',
#  'Flight Crew Returned To Gate; General Maintenance Action',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew Returned To Clearance',
#  'Flight Crew Took Evasive Action; Flight Crew Returned To Clearance; Flight Crew FLC Overrode Automation',
#  'Flight Crew Executed Go Around / Missed Approach; Flight Crew Took Evasive Action',
#  'Flight Crew Requested ATC Assistance / Clarification; General Police / Security Involved',
#  'Flight Crew Became Reoriented; General Maintenance Action',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Separated Traffic',
#  'Flight Crew Returned To Clearance; Flight Crew Took Evasive Action',
#  'General Physical Injury / Incapacitation; General Work Refused',
#  'Air Traffic Control Issued New Clearance; Flight Crew Took Evasive Action; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew Executed Go Around / Missed Approach',
#  'Flight Crew FLC Overrode Automation',
#  'Air Traffic Control Issued New Clearance; Flight Crew Took Evasive Action; Flight Crew Returned To Clearance; Flight Crew Became Reoriented',
#  'Flight Crew Became Reoriented; Flight Crew FLC complied w / Automation / Advisory; Flight Crew Took Evasive Action',
#  'Flight Crew Took Evasive Action; Flight Crew Returned To Clearance; Flight Crew Became Reoriented',
#  'Flight Crew FLC Overrode Automation; Flight Crew Took Evasive Action; Flight Crew Became Reoriented; General Maintenance Action',
#  'Air Traffic Control Separated Traffic; Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance',
#  'Flight Crew Became Reoriented; General Physical Injury / Incapacitation',
#  'Flight Crew Overcame Equipment Problem; Flight Crew Returned To Departure Airport',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Provided Assistance; General Flight Cancelled / Delayed',
#  'Flight Crew Requested ATC Assistance / Clarification; Flight Crew Became Reoriented',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Provided Assistance; Flight Crew Overcame Equipment Problem; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Provided Assistance; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Provided Assistance; Flight Crew Became Reoriented; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew FLC complied w / Automation / Advisory',
#  'General Flight Cancelled / Delayed',
#  'Air Traffic Control Issued New Clearance; General Flight Cancelled / Delayed',
#  'Flight Crew Overcame Equipment Problem; Flight Crew Became Reoriented',
#  'Air Traffic Control Issued New Clearance; Flight Crew Returned To Departure Airport; General Maintenance Action',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Separated Traffic; Air Traffic Control Provided Assistance; Air Traffic Control Issued New Clearance; General Flight Cancelled / Delayed',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Executed Go Around / Missed Approach; Flight Crew Took Evasive Action',
#  'Air Traffic Control Separated Traffic; Air Traffic Control Issued New Clearance; Flight Crew FLC complied w / Automation / Advisory',
#  'Air Traffic Control Issued New Clearance; Flight Crew Overcame Equipment Problem',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Separated Traffic; Flight Crew Executed Go Around / Missed Approach',
#  'Flight Crew FLC complied w / Automation / Advisory; Flight Crew Took Evasive Action; Flight Crew Became Reoriented',
#  'Air Traffic Control Issued New Clearance; Flight Crew FLC Overrode Automation; Flight Crew Became Reoriented',
#  'Flight Crew Became Reoriented; Flight Crew Took Evasive Action; Flight Crew Returned To Clearance',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Provided Assistance; Air Traffic Control Issued New Clearance; Flight Crew Took Evasive Action',
#  'Flight Crew FLC complied w / Automation / Advisory; Flight Crew Took Evasive Action',
#  'Air Traffic Control Provided Assistance; Air Traffic Control Issued New Clearance; Flight Crew Executed Go Around / Missed Approach; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Separated Traffic; Air Traffic Control Issued Advisory / Alert; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Returned To Departure Airport; Flight Crew Became Reoriented',
#  'General Work Refused',
#  'Flight Crew Diverted',
#  'Flight Crew FLC Overrode Automation; Flight Crew Became Reoriented',
#  'Flight Crew FLC complied w / Automation / Advisory; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Took Evasive Action',
#  'Flight Crew Rejected Takeoff; Flight Crew Took Evasive Action',
#  'Flight Crew Took Evasive Action; Flight Crew FLC complied w / Automation / Advisory; Flight Crew Executed Go Around / Missed Approach',
#  'Flight Crew Regained Aircraft Control; Flight Crew Returned To Clearance',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Provided Assistance; Flight Crew Executed Go Around / Missed Approach',
#  'Aircraft Aircraft Damaged; Flight Crew Regained Aircraft Control; General Maintenance Action',
#  'Air Traffic Control Provided Assistance; Air Traffic Control Issued New Clearance',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew Executed Go Around / Missed Approach; Flight Crew FLC complied w / Automation / Advisory; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Took Evasive Action',
#  'Flight Crew Took Evasive Action; Flight Crew Regained Aircraft Control',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Separated Traffic; Air Traffic Control Issued New Clearance; Flight Crew FLC complied w / Automation / Advisory',
#  'Aircraft Aircraft Damaged; General Evacuated',
#  'Flight Crew Became Reoriented; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Provided Assistance; Air Traffic Control Separated Traffic; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Separated Traffic; Flight Crew Requested ATC Assistance / Clarification',
#  'Flight Crew Executed Go Around / Missed Approach; Flight Crew Diverted; General Flight Cancelled / Delayed',
#  'Air Traffic Control Issued New Clearance; Flight Crew Took Evasive Action; Flight Crew Regained Aircraft Control; Flight Crew Requested ATC Assistance / Clarification; General Physical Injury / Incapacitation',
#  'Air Traffic Control Issued New Clearance; Flight Crew Rejected Takeoff',
#  'Air Traffic Control Issued New Clearance; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Became Reoriented',
#  'Air Traffic Control Provided Assistance; Flight Crew Landed As Precaution; Flight Crew Diverted; Flight Crew Executed Go Around / Missed Approach',
#  'General Maintenance Action',
#  'Air Traffic Control Provided Assistance; Flight Crew Became Reoriented; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew Took Evasive Action; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Provided Assistance; Flight Crew FLC complied w / Automation / Advisory; Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued New Clearance; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Took Evasive Action',
#  'Aircraft Equipment Problem Dissipated; Flight Crew Regained Aircraft Control; General Maintenance Action',
#  'General Maintenance Action; General Flight Cancelled / Delayed',
#  'Air Traffic Control Issued New Clearance; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Took Evasive Action',
#  '

#  'Air Traffic Control Issued New Clearance; Air Traffic Control Separated Traffic; Flight Crew Returned To Clearance',
#  'Flight Crew Took Evasive Action; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Returned To Clearance',
#  'Air Traffic Control Provided Assistance; Air Traffic Control Issued New Clearance; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued New Clearance; Flight Crew Returned To Clearance; Flight Crew Requested ATC Assistance / Clarification',
#  'Flight Crew Requested ATC Assistance / Clarification; Flight Crew Returned To Clearance',
#  'Flight Crew Diverted; Flight Crew Inflight Shutdown; Flight Crew Landed in Emergency Condition; General Declared Emergency; General Maintenance Action',
#  'Air Traffic Control Separated Traffic; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Separated Traffic; Air Traffic Control Provided Assistance; Air Traffic Control Issued New Clearance',
#  'Flight Crew Requested ATC Assistance / Clarification; Flight Crew Took Evasive Action; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Provided Assistance; Air Traffic Control Separated Traffic; Air Traffic Control Issued New Clearance; Flight Crew Executed Go Around / Missed Approach',
# ...
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Separated Traffic; Flight Crew Requested ATC Assistance / Clarification; Flight Crew FLC complied w / Automation / Advisory',
#  'General Evacuated',
#  'Aircraft Aircraft Damaged; Flight Crew Rejected Takeoff; General Evacuated',
#  'Air Traffic Control Issued New Clearance; Flight Crew Became Reoriented; Flight Crew Took Evasive Action; General Physical Injury / Incapacitation',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew Returned To Clearance; Flight Crew Took Evasive Action; Flight Crew Became Reoriented',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew Regained Aircraft Control; Flight Crew Landed As Precaution; Flight Crew Diverted; Flight Crew Took Evasive Action; General Maintenance Action',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Landed As Precaution; Flight Crew Took Evasive Action; Flight Crew FLC complied w / Automation / Advisory; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Provided Assistance; Aircraft Aircraft Damaged; Flight Crew Diverted; Flight Crew Landed As Precaution; Flight Crew Regained Aircraft Control; Flight Crew Requested ATC Assistance / Clarification',
#  'Flight Crew Took Evasive Action; Flight Crew Returned To Clearance; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Regained Aircraft Control',
#  'Air Traffic Control Issued New Clearance; Flight Crew Took Evasive Action; Flight Crew Requested ATC Assistance / Clarification; General Maintenance Action',
#  'Air Traffic Control Issued New Clearance; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Became Reoriented; Flight Crew FLC complied w / Automation / Advisory',
#  'Flight Crew Returned To Clearance; General Maintenance Action',
#  'Air Traffic Control Issued New Clearance; Flight Crew Returned To Clearance; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew Returned To Clearance; Flight Crew Became Reoriented; Flight Crew Overcame Equipment Problem',
#  'Air Traffic Control Separated Traffic; Air Traffic Control Issued New Clearance; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Requested ATC Assistance / Clarification; General Police / Security Involved',
#  'Air Traffic Control Provided Assistance; Flight Crew FLC Overrode Automation; Flight Crew Became Reoriented; Flight Crew Returned To Clearance',
#  'Air Traffic Control Provided Assistance; Flight Crew Became Reoriented; Flight Crew Returned To Clearance; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew FLC complied w / Automation / Advisory; Flight Crew Returned To Clearance',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Separated Traffic; Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew Executed Go Around / Missed Approach; General Flight Cancelled / Delayed',
#  'Flight Crew Landed As Precaution; Flight Crew Executed Go Around / Missed Approach',
#  'Air Traffic Control Issued Advisory / Alert; Flight Crew Returned To Clearance; Flight Crew Exited Penetrated Airspace',
#  'Air Traffic Control Issued New Clearance; Flight Crew Landed As Precaution; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Diverted; General Maintenance Action',
#  'Air Traffic Control Separated Traffic; Air Traffic Control Issued New Clearance; General Flight Cancelled / Delayed',
#  'Air Traffic Control Provided Assistance; Flight Crew Requested ATC Assistance / Clarification; General Maintenance Action',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Provided Assistance; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Separated Traffic; Flight Crew Landed in Emergency Condition',
#  'Flight Crew Took Evasive Action; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Returned To Gate; General Physical Injury / Incapacitation',
#  'Air Traffic Control Provided Assistance; Flight Crew Requested ATC Assistance / Clarification; General Release Refused / Aircraft Not Accepted',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Separated Traffic; Air Traffic Control Issued New Clearance; Flight Crew Became Reoriented',
#  'Air Traffic Control Provided Assistance; Flight Crew Became Reoriented; Flight Crew Regained Aircraft Control',
#  'Air Traffic Control Issued New Clearance; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Executed Go Around / Missed Approach; Flight Crew Took Evasive Action; General Flight Cancelled / Delayed',
#  'Flight Crew Took Evasive Action; Flight Crew Returned To Clearance; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Provided Assistance; Flight Crew Took Evasive Action; Flight Crew Regained Aircraft Control',
#  'Flight Crew Took Evasive Action; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Landed As Precaution',
#  'Air Traffic Control Provided Assistance; Flight Crew Regained Aircraft Control',
#  'Air Traffic Control Separated Traffic; Air Traffic Control Provided Assistance; Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew Returned To Clearance; Flight Crew Became Reoriented; Flight Crew Requested ATC Assistance / Clarification',
#  'Flight Crew Executed Go Around / Missed Approach; Flight Crew FLC complied w / Automation / Advisory; Flight Crew Took Evasive Action; General Flight Cancelled / Delayed',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew Became Reoriented; Flight Crew FLC complied w / Automation / Advisory',
#  'Flight Crew FLC Overrode Automation; Flight Crew FLC complied w / Automation / Advisory',
#  'Flight Crew FLC Overrode Automation; Flight Crew Became Reoriented; Flight Crew Returned To Clearance',
#  'Air Traffic Control Issued New Clearance; Flight Crew FLC Overrode Automation; Flight Crew Returned To Clearance; Flight Crew Became Reoriented',
#  'Air Traffic Control Issued New Clearance; Flight Crew Landed in Emergency Condition',
#  'Air Traffic Control Issued New Clearance; Flight Crew Returned To Clearance; Flight Crew Regained Aircraft Control; Flight Crew Requested ATC Assistance / Clarification',
#  'Air Traffic Control Provided Assistance; Flight Crew Took Evasive Action; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Diverted',
#  'Flight Crew Took Evasive Action; Flight Crew Landed in Emergency Condition; Flight Crew Diverted',
#  'Aircraft Equipment Problem Dissipated; Flight Crew Overcame Equipment Problem; General Maintenance Action',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew Regained Aircraft Control; Flight Crew Executed Go Around / Missed Approach; General Flight Cancelled / Delayed',
#  'Flight Crew Diverted; Flight Crew Executed Go Around / Missed Approach; Flight Crew Took Evasive Action; Flight Crew Regained Aircraft Control',
#  'Aircraft Aircraft Damaged; Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew FLC complied w / Automation / Advisory; Flight Crew Became Reoriented',
#  'Air Traffic Control Issued New Clearance; Flight Crew Rejected Takeoff; Flight Crew Requested ATC Assistance / Clarification',
#  'Aircraft Aircraft Damaged; Flight Crew Returned To Gate; General Maintenance Action',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Separated Traffic',
#  'Air Traffic Control Provided Assistance; Flight Crew Requested ATC Assistance / Clarification; Flight Crew FLC Overrode Automation; Flight Crew Became Reoriented',
#  'Air Traffic Control Separated Traffic; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Took Evasive Action',
#  'Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert; Flight Crew Became Reoriented; Flight Crew Requested ATC Assistance / Clarification; Flight Crew

#  'Air Traffic Control Provided Assistance; Air Traffic Control Separated Traffic; Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance',
#  'Air Traffic Control Provided Assistance; Air Traffic Control Separated Traffic; Air Traffic Control Issued New Clearance; Air Traffic Control Issued Advisory / Alert',
#  'Air Traffic Control Issued New Clearance; Flight Crew Returned To Clearance; Flight Crew Requested ATC Assistance / Clarification; Flight Crew Regained Aircraft Control; General Physical Injury / Incapacitation',
#  'Air Traffic Control Issued Advisory / Alert; Air Traffic Control Issued New Clearance; Flight Crew Overcame Equipment Problem; Flight Crew Requested ATC Assistance / Clarification',
#  ...]

# %%
# Make a list of all 'Result' entries
result = list()
for entry in df['Result']:
    split = str(entry).split(sep = '; ') # include a space after ';'
    result = result + split

# Countplot:
fig = plt.figure(figsize= (13,7))

sns.countplot(x = result, order= pd.Series(result).value_counts().index) # need to transform list to pd.Series for the ordering in countplot()
plt.xticks(rotation=90)
plt.title('Result', fontsize=20);

# %% [markdown]
# This is a nice introductory plot for the entire dataset.

# %% [markdown]
# # Text mining on narratives

# %% [markdown]
# ## Selecting the example we will work with

# %%
nar1_all['Narrative'][9]
# Out:
# "During approach to TUS; leg 5 of a 6-leg day; talking to Approach Control; we were cleared direct CALLS for the ILS 11L and cleared to descend to 5;000 FT. We called the airport in sight and were cleared for the visual approach and told to contact Tower. First Officer selected direct POCIB in the FMC; and selected 4;600 FT on the MCP. When we contacted Tower; the Controller said to check altitude and stated the MVA in the area was 5;900 FT. Simultaneously we received a 'Caution Terrain; Caution Obstacle' alert from the GPWS. First Officer executed go-around maneuver. We climbed to clear the alert. Once we were clear of the hazard; we continued our descent to the runway. An s-turn to the south was needed to lose altitude. The terrain feature was in use on both navigation displays; but did not show an immediate threat in front of the airplane. The turn to POCIB was not verbalized; but I was aware of it. This turn only changed our lateral course by a couple of degrees to the right; so I did not initially think it would make a big difference; but it apparently brought us close enough laterally to terrain to trigger the alert.[We needed] verbalization of changes to FMC programming; staying on previously cleared path and altitude at night; even when cleared for a visual approach; especially in mountainous areas. Better monitoring and situational awareness on the part of the Captain/pilot not flying; not trying to salvage the approach under such conditions."

# %%
nar1_all['Narrative.1'][9]
# Out:
# "While on a descent into TUS; we had been given direct CALLS and descend to 5;000 FT. We were high on our profile due to a delayed descent. I had the speedbrakes extended and at some point in the process as we approached 5;000 FT; I extended the landing gear to slow and configure for the approach. Approach asked if we had the airport in sight and we confirmed airport in sight. Approach cleared us for the visual approach and told us to contact Tower. Once cleared for the visual; I selected POCIB in the FMC and went direct and reset the MCP altitude to 4;600 FT. The difference in heading change was less than ten degrees. We were still descending at 250 KTS with speed brake extended and gear down. When we switched to Tower; Tower said 'Check altitude; minimum vectoring in that area is 5;900 FT.' We were descending through 5;300 FT and within a few miles of POCIB. As Tower tells us this; we receive a GPWS Caution; 'Caution Obstacle Caution Terrain.' Even though it was a visual approach; it was at night so we executed the required maneuver per the FOM. We asked Tower if we could take a turn to the south to reconfigure for landing after we were clear of all terrain. The Tower approved and we landed flaps 40; exited the runway; and parked the aircraft. Captain debriefed after parking at the gate. During the event; the terrain mapping feature on the ND display never indicated terrain in front of us. It was black with terrain showing to the north. It is my opinion that had I stayed on the original clearance to CALLS at 5;000 FT or had I been on profile with a normal descent rate; we would not have received the GPWS Caution."

# %%
nar1_all['Synopsis'][9]
# Out:
# 'B737 flight crew experiences an EGPWS terrain caution just after a low altitude alert from the Tower during a night visual approach to Runway 11L at TUS. An immediate climb is initiated.'

# %% [markdown]
# ## Define the input text

# %%
txt = nar1_all['Narrative'][9]
txt
# Out:
# "During approach to TUS; leg 5 of a 6-leg day; talking to Approach Control; we were cleared direct CALLS for the ILS 11L and cleared to descend to 5;000 FT. We called the airport in sight and were cleared for the visual approach and told to contact Tower. First Officer selected direct POCIB in the FMC; and selected 4;600 FT on the MCP. When we contacted Tower; the Controller said to check altitude and stated the MVA in the area was 5;900 FT. Simultaneously we received a 'Caution Terrain; Caution Obstacle' alert from the GPWS. First Officer executed go-around maneuver. We climbed to clear the alert. Once we were clear of the hazard; we continued our descent to the runway. An s-turn to the south was needed to lose altitude. The terrain feature was in use on both navigation displays; but did not show an immediate threat in front of the airplane. The turn to POCIB was not verbalized; but I was aware of it. This turn only changed our lateral course by a couple of degrees to the right; so I did not initially think it would make a big difference; but it apparently brought us close enough laterally to terrain to trigger the alert.[We needed] verbalization of changes to FMC programming; staying on previously cleared path and altitude at night; even when cleared for a visual approach; especially in mountainous areas. Better monitoring and situational awareness on the part of the Captain/pilot not flying; not trying to salvage the approach under such conditions."

# %%
txt1 = nar1_all['Narrative.1'][9]

# %% [markdown]
# ### Deal with the numbers using Regular Expressions

# %%
def subst_RegEX(text): 
    """
    Substitute several aviation-related entries (runway identifiers, altitude indications, etc.) 
    with general labels in a given text
    """
    
    import re

    # Altitudes
    r = re.compile(r"""

                \d+;{1,1}\d+\s{1,1}FT       # >> deals with altitude indications, e.g.: '4;600 FT'

                                            # at least one number followed by exactly one ';', 
                                            # followed by at least one number.

                  """, re.VERBOSE)

    # Substitute all RegEx's found :
    text = (r.sub('AltVal', text))
    
    # Runways
    r = re.compile(r"""

                \d\d(L | R)                 # >> deals with runway identifiers e.g.: '11L'           

                                            # exactly two digits, followed by either 'L' or 'R'

                                            # The number (not less or more than 2 digits) indicates the RWY
                                            # orientation in tens of degrees. 

                                            # '11L' means : orientation of 110 deg, left RWY.
                                            # There can only be 'left' or 'right' (as far as Ioannis knows), 
                                            # since RWY are build parallel to each other.
                                            # RWYs not parallel will have a different orientation, i.e. different digits              
                  """, re.VERBOSE)

    # Substitute all RegEx's found :
    text = (r.sub('RwyID', text))
    
    # Numbers, other than altitudes
    r = re.compile(r"""

                [0-9]+                     # at least one number            

                  """, re.VERBOSE)

    # Substitute all RegEx's found :
    text = (r.sub('NumVal', text))
    
    return text

# %%
subst_RegEX(txt)
# Out:
# "During approach to TUS; leg NumVal of a NumVal-leg day; talking to Approach Control; we were cleared direct CALLS for the ILS RwyID and cleared to descend to AltVal. We called the airport in sight and were cleared for the visual approach and told to contact Tower. First Officer selected direct POCIB in the FMC; and selected AltVal on the MCP. When we contacted Tower; the Controller said to check altitude and stated the MVA in the area was AltVal. Simultaneously we received a 'Caution Terrain; Caution Obstacle' alert from the GPWS. First Officer executed go-around maneuver. We climbed to clear the alert. Once we were clear of the hazard; we continued our descent to the runway. An s-turn to the south was needed to lose altitude. The terrain feature was in use on both navigation displays; but did not show an immediate threat in front of the airplane. The turn to POCIB was not verbalized; but I was aware of it. This turn only changed our lateral course by a couple of degrees to the right; so I did not initially think it would make a big difference; but it apparently brought us close enough laterally to terrain to trigger the alert.[We needed] verbalization of changes to FMC programming; staying on previously cleared path and altitude at night; even when cleared for a visual approach; especially in mountainous areas. Better monitoring and situational awareness on the part of the Captain/pilot not flying; not trying to salvage the approach under such conditions."

# %%
subst_RegEX(txt1)
# Out:
# "While on a descent into TUS; we had been given direct CALLS and descend to AltVal. We were high on our profile due to a delayed descent. I had the speedbrakes extended and at some point in the process as we approached AltVal; I extended the landing gear to slow and configure for the approach. Approach asked if we had the airport in sight and we confirmed airport in sight. Approach cleared us for the visual approach and told us to contact Tower. Once cleared for the visual; I selected POCIB in the FMC and went direct and reset the MCP altitude to AltVal. The difference in heading change was less than ten degrees. We were still descending at NumVal KTS with speed brake extended and gear down. When we switched to Tower; Tower said 'Check altitude; minimum vectoring in that area is AltVal.' We were descending through AltVal and within a few miles of POCIB. As Tower tells us this; we receive a GPWS Caution; 'Caution Obstacle Caution Terrain.' Even though it was a visual approach; it was at night so we executed the required maneuver per the FOM. We asked Tower if we could take a turn to the south to reconfigure for landing after we were clear of all terrain. The Tower approved and we landed flaps NumVal; exited the runway; and parked the aircraft. Captain debriefed after parking at the gate. During the event; the terrain mapping feature on the ND display never indicated terrain in front of us. It was black with terrain showing to the north. It is my opinion that had I stayed on the original clearance to CALLS at AltVal or had I been on profile with a normal descent rate; we would not have received the GPWS Caution."

# %% [markdown]
# ## TOKENIZATION & STOP WORD FILTERING

# %%
def tokenize_filter(text):
    """
    Tokenizes 'text' and filters out stop-words (incl. user-defined ones)
    """
    # TOKENIZE

    ############################################
    ### This needs to be executed the 1st time:
    # import nltk
    # nltk.download('punkt')
    ############################################

    from nltk.tokenize import word_tokenize

    tokens = word_tokenize(text.lower(), language = 'english') 
    # lower-casing the text is crucial for the stop word filtering below
    #print("Tokenized words: \n\n", words)
    
    
    # STOP WORD FILTERING
    
    # Import stopwords from nltk.corpus
    from nltk.corpus import stopwords

    # Initialiser la variable des mots vides
    stop_words = set(stopwords.words('english')) 
    # we convert it to a set, qui sera plus efficient (vs. une liste) dans la recherche des stopwords. 
    # 'set' also avoids duplicates.

    # add additional stop words, if desired : 
    stop_words.update(['.', ';', '[', ']'])
    #print("\n\nThe set of stop words, including additional stop words is: \n\n", stop_words)
    
    # inner function
    def stop_words_filtering(my_list):
        """
        Delete stop words from the function input ‘my_list’.
        """
        # remove duplicate words from liste
        set_my_list = set(my_list) 
        my_list = list(set_my_list)

        for stopword in stop_words:

            if stopword in my_list:
                my_list.remove(stopword)

        return my_list

    # call the inner function
    tokenized_filtered_words = stop_words_filtering(tokens)
    
    return tokenized_filtered_words

# %%
tokenize_filter(txt)
# Out:
# ['pocib',
#  'direct',
#  'monitoring',
#  'called',
#  'turn',
#  'trying',
#  'obstacle',
#  'threat',
#  'caution',
#  'maneuver',
#  'area',
#  'lose',
#  'difference',
#  'us',
#  'contact',
#  'check',
#  'staying',
#  'degrees',
#  'selected',
#  'climbed',
#  'immediate',
#  "'",
#  'front',
#  'even',
#  'situational',
#  'airplane',
#  'navigation',
#  'especially',
#  'altitude',
#  'captain/pilot',
#  'ft',
#  'south',
#  'brought',
#  'mountainous',
#  'clear',
#  'previously',
#  'enough',
#  's-turn',
#  'lateral',
#  'alert',
#  'contacted',
#  'feature',
#  'runway',
#  'verbalization',
#  'calls',
#  'think',
#  'visual',
#  'gpws',
#  'displays',
#  'apparently',
#  'changes',
#  'better',
#  'ils',
#  'fmc',
#  'would',
#  'use',
#  'hazard',
#  'course',
#  'initially',
#  'night',
#  'laterally',
#  'changed',
#  'sight',
#  'continued',
#  'conditions',
#  'flying',
#  'close',
#  'approach',
#  '11l',
#  'told',
#  '6-leg',
#  'executed',
#  'tower',
#  'received',
#  'descent',
#  'verbalized',
#  'talking',
#  'path',
#  'control',
#  'big',
#  'programming',
#  'first',
#  'airport',
#  'salvage',
#  'show',
#  'ft.',
#  'needed',
#  '900',
#  '4',
#  'awareness',
#  'terrain',
#  'right',
#  "'caution",
#  'mcp',
#  'tus',
#  'mva',
#  'day',
#  'go-around',
#  'areas',
#  'trigger',
#  'simultaneously',
#  '600',
#  '5',
#  'make',
#  'leg',
#  'stated',
#  'said',
#  'descend',
#  'aware',
#  'couple',
#  'part',
#  'controller',
#  '000',
#  'cleared',
#  'officer']

# %%
# def stop_words_filtering(my_list):
#     """
#     Delete stop words from the function input ‘my_list’.
#     """
#     # remove duplicate words from liste
#     set_my_list = set(my_list) 
#     my_list = list(set_my_list)
    
#     for stopword in stop_words:

#         if stopword in my_list:
#             my_list.remove(stopword)
        
#     return my_list


# # call the function
# words = stop_words_filtering(words)
# words
# Out:
# ['pocib',
#  'direct',
#  'monitoring',
#  'turn',
#  'called',
#  'trying',
#  'obstacle',
#  'threat',
#  'caution',
#  'maneuver',
#  'area',
#  'lose',
#  'us',
#  'difference',
#  'contact',
#  'check',
#  'staying',
#  'degrees',
#  'selected',
#  'climbed',
#  'immediate',
#  "'",
#  'front',
#  'even',
#  'situational',
#  'airplane',
#  'navigation',
#  'especially',
#  'altitude',
#  'captain/pilot',
#  'south',
#  'brought',
#  'mountainous',
#  'clear',
#  'previously',
#  'enough',
#  's-turn',
#  'lateral',
#  'alert',
#  'contacted',
#  'feature',
#  'runway',
#  'verbalization',
#  'calls',
#  'think',
#  'visual',
#  'gpws',
#  'displays',
#  'apparently',
#  'changes',
#  'better',
#  'ils',
#  'fmc',
#  'would',
#  'use',
#  'rwyid',
#  'hazard',
#  'course',
#  'initially',
#  'night',
#  'laterally',
#  'conditions',
#  'sight',
#  'changed',
#  'continued',
#  'flying',
#  'close',
#  'approach',
#  'told',
#  'executed',
#  'tower',
#  'received',
#  'descent',
#  'verbalized',
#  'talking',
#  'path',
#  'numval',
#  'control',
#  'big',
#  'programming',
#  'first',
#  'airport',
#  'salvage',
#  'show',
#  'needed',
#  'numval-leg',
#  'awareness',
#  'terrain',
#  'altval',
#  'right',
#  "'caution",
#  'mcp',
#  'tus',
#  'mva',
#  'day',
#  'go-around',
#  'areas',
#  'trigger',
#  'simultaneously',
#  'make',
#  'leg',
#  'stated',
#  'said',
#  'descend',
#  'aware',
#  'couple',
#  'part',
#  'controller',
#  'cleared',
#  'officer']

# %% [markdown]
# ## WORDCLOUD

# %%
# from wordcloud import WordCloud

# # Instancier le calque (layer)
# wc = WordCloud(max_words= 100, stopwords= stop_words, max_font_size= 50, random_state=42, collocations = False, background_color= 'white')
# # collocation (bigrams, trigrams): two/three adjacent words, such as 'CT scan', 'machine learning', or 'social media

# # Afficher le wordcloud:
# import matplotlib.pyplot as plt 

# # Générer et afficher le nuage de mots
# plt.figure(figsize= (10,6)) # Initialisation d'une figure

# wc.generate(txt)           # "Calcul" du wordcloud

# plt.imshow(wc, interpolation="bilinear") # Affichage
# plt.title("WordCloud for 'txt'", fontsize = 20)
# plt.show()

# %%
# from wordcloud import WordCloud

# # Instancier le calque (layer)
# wc = WordCloud(max_words= 100, stopwords= stop_words, max_font_size= 50, random_state=42, collocations = False, background_color= 'white')
# # collocation (bigrams, trigrams): two/three adjacent words, such as 'CT scan', 'machine learning', or 'social media

# # Afficher le wordcloud:
# import matplotlib.pyplot as plt 

# # Générer et afficher le nuage de mots
# plt.figure(figsize= (10,6)) # Initialisation d'une figure

# wc.generate(txt1)           # "Calcul" du wordcloud

# plt.imshow(wc, interpolation="bilinear") # Affichage
# plt.title("WordCloud for 'txt1'", fontsize = 20)
# plt.show()

# %%
def plot_word_cloud(text, masque, background_color = "white") :
    """
    Afficher un nuage de mots à partir de la chaîne de caractères text sous forme du masque 'masque'.
    """
    from wordcloud import WordCloud
    from PIL import Image 
    # PIL: Python Imaging Library. Adds image processing capabilities to your Python interpreter.

    # Définir un masque
    mask_coloring = np.array(Image.open(str(masque)))

    # Définir le calque du nuage des mots
    wc = WordCloud(background_color=background_color, 
                   max_words=150, 
                   stopwords=stop_words, 
                   mask = mask_coloring, 
                   max_font_size=40, random_state=42)
    
    # Générer et afficher le nuage de mots
    plt.figure(figsize= (20,10))
    wc.generate(text)
    plt.imshow(wc, interpolation="bilinear")
    plt.xticks([])
    plt.yticks([])
    plt.title("WordCloud", fontsize = 20)
    plt.show()

# %%
# call the function defined above:
print("WordCloud for 'txt':")
plot_word_cloud(txt, "plane.png")

print("WordCloud for 'txt1':")
plot_word_cloud(txt1, "plane.png")
# Out:
# WordCloud for 'txt':
# WordCloud for 'txt1':

# %% [markdown]
# ## WORD HISTOGRAMM

# %%
def plot_word_hist(tokens):
    """
    Plot histogram of most common words. Pass 'tokens' after stop word filtering.
    """
    
    # Dans une variable nommé chaine, fusionner tous les commentaires négatifs dans une chaine de caractère
    #chaine = ''
    chaine = ' '.join(entry.lower() for entry in tokens)

    from collections import Counter
    # transforme une liste en un dictionnaire, où un élément de la liste devient une clé, associée à son nombre d'occurrences (valeur dans le dict)
    dico = Counter(chaine.split())

    # retourne une liste des 15 premiers mots les plus utilisés avec leur nombre d'occurrences:
    dico.most_common(15)

    # PLOT a histogram of words using Seaborn
    # Define input data:
    X = [dico.most_common(20)[i][0] for i in range(len(dico.most_common(15)))]
    Y = [dico.most_common(20)[i][1] for i in range(len(dico.most_common(15)))]

    import seaborn as sns
    plt.figure(figsize= (10,6))

    sns.barplot(x = X, y = Y)
    plt.xticks(rotation=90);

    plt.xlabel('Words')
    plt.ylabel('Frequency')

    plt.title('20 most common words');

# %%
# Call the function
plot_word_hist(tokenize_filter(txt))
plot_word_hist(tokenize_filter(txt1))

# %% [markdown]
# # Machine Learning on the most frequent Primary Problems

# %% [markdown]
# The most frequent Primary Problems in the data are (in decreasing order):
# - Human Factors
#
# - Procedure
#
# - Ambiguous
#
# - Aircraft
#
# - Weather
#
# Let's select only these data, leaving out 'Ambiguous' data to start with.

# %%
df_ML = df.loc[df['Primary Problem'].isin(['Human Factors', 'Procedure', 'Aircraft', 'Weather'])]

# %%
len(df_ML)
# Out:
# 16483

# %%
def tokenize_filter_make_text(text):
    tokens = tokenize_filter(text)
    chaine = ' '.join(entry.lower() for entry in tokens)
    
    return chaine

# %%
df_ML['Narrative'][5]
# Out:
# "A C560 was vectored northbound over PHX at [5000 ft] enroute to SDL. The COL4 was southbound at [4500 ft] on the East Transition over PHX. These are altitudes on routes per our SOP. Both aircraft were level. Traffic was called for both aircraft and they were told the other was level. The C560 passed over the COL4 and responded to an RA. He climbed 200 FT; saw the other aircraft; and then descended back to his assigned altitude. Separation and safety was maintained on routes and altitudes per the P50 SOP. The only way to avoid this completely would have been to climb the C560 to [6000 ft]; which would have been a 1;000 FT climb within 10-15 miles from his destination and it would require coordination. If another aircraft was at that altitude it wouldn't have been an option. There wasn't anything else I could have done to help."

# %%
X = tokenize_filter_make_text(df_ML['Narrative'][5])
X
# Out:
# "sop called col4 saw transition enroute traffic passed climbed completely assigned anything altitude c560 level maintained ft help 4500 n't safety coordination done way climb would avoid could responded 5000 told else option northbound altitudes routes east p50 aircraft within 200 per sdl phx destination 1 vectored 10-15 back miles require 6000 southbound descended 000 another ra separation"

# %%
from sklearn.model_selection import train_test_split

X = df_ML['Narrative']
y = df_ML['Primary Problem'] # target value

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import GradientBoostingClassifier

vectorizer = CountVectorizer(stop_words= stop_words)

X_train = vectorizer.fit_transform(X_train).todense() 
# .toarray() returns an numpy array. 
# .todense() returns a numpy matrix. 
# Each type comes with its set of methods...


# Selon la version de sklearn le classifier clf n'accepte pas les matrices sparses. Il faut alors utiliser la méthode toarray() pour que la matrice soit compatible.

X_test = vectorizer.transform(X_test).todense()

#  Train a classifier:
clf = GradientBoostingClassifier(n_estimators= 100, learning_rate= 1.0, max_depth= 1, random_state= 0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# Confusion matrix
pd.crosstab(y_test, y_pred, rownames=['real'], colnames=['predicted'])
# Out:
# /Users/gs/Desktop/sample_project/env/lib/python3.9/site-packages/sklearn/utils/validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(

# %%
# Classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
