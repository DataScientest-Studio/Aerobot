# %% [markdown]
# # AeroBot - Deliverable D1 - DataViz

# %% [markdown]
# ## About

# %% [markdown]
# This is the first deliverable (D1) of the project 'AeroBot' in the framework of the 'Data Scientist' training programm at [datascientest.com](https://datascientest.com/)

# %% [markdown]
# **Tutor**
#
# * Alban THUET
#
# **Authors:**
#
# * Hélène ASSIR
# * Hichem HADJI
# * [Ioannis STASINOPOULOS](https://www.linkedin.com/in/ioannis-stasinopoulos/)
#
# </br>
#
# ---
# </br>
#
# **Version History**
#
# Version | Date       | Author | Modification
# --------|----------- | ------ | --------------------------
# X.X     | XX/XX/2022 | A.B    | modif
# 1.0     | 18/05/2022 | I.S    | Document creation (copy from local .ipynb)

# %% [markdown]
# ## Loading the data

# %% [markdown]
# ### Mount & explore your Google Drive

# %%
# Mount your Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#check your present working directory 
# %pwd
# Out:
# '/content'

# %%
# move to the desired location (adapt to your folder-tree-structure):
# %cd /content/drive/MyDrive/Data_Science/Formations/DataScienceTest/projet/AeroBot/
# Out:
# /content/drive/MyDrive/Data_Science/Formations/DataScienceTest/projet/AeroBot

# %%
# !ls # list the content of the pwd

#!ls "/content/drive/MyDrive/Data_Science/Formations/DataScienceTest/projet/AeroBot/" # list contect of a speficic folder
# Out:
# ASRS_20y_data.csv  D1_DRAFT_Dataviz_Ioannis_20220527.gslides  plane.png

# %% [markdown]
# ### Copy Ioannis' file to your Google Drive

# %% [markdown]
# This section shows you how to copy the file from Ioannis's Google Drive into the pwd of your Google Drive.
#
# **Uncomment and execute the cells, if desired.**
#
# Source:
# https://towardsdatascience.com/different-ways-to-connect-google-drive-to-a-google-colab-notebook-pt-1-de03433d2f7a

# %%
# libraries for the files in google drive
from pydrive.auth import GoogleAuth
from google.colab import drive
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# auth.authenticate_user()
# gauth = GoogleAuth()
# gauth.credentials = GoogleCredentials.get_application_default()
# drive = GoogleDrive(gauth)

# file_id = '16My7pG4Ral93VIAQrCTpcMn5JTa79DGo' 
# # This is the id of the ASRS_20y_data.csv file in Ioannis' Google Drive, which he has shared with you
# # (To find the id of a file, click 'share' and 'get link' and copy the large nonsense part of the link

# # 'download' the file to your present working directory 
# download = drive.CreateFile({'id': file_id})
# download.GetContentFile('copied_file.csv')
# df  = pd.read_csv("copied_file.csv")
# df.head()

# %% [markdown]
# ## Mount Google Drive

# %% [markdown]
# ## Start working with the DataFrame

# %%
import numpy as np
import seaborn as sns

import pandas as pd
# Set pandas settings to show all data when using .head(), .columns etc.
pd.options.display.max_columns = None
pd.options.display.max_rows = None

import re # for Regular Expression handling

import matplotlib.pyplot as plt
# %matplotlib inline
# Define global plot parameters for better readability and consistency among plots
plt.rcParams['axes.labelsize'] = 23
plt.rcParams['axes.titlesize'] = 30
plt.rcParams['xtick.labelsize'] = 23
plt.rcParams['ytick.labelsize'] = 23

# BOKEH 
from bokeh.plotting import figure # Importation de la classe figure qui permet de créer un graphique bokeh.
from bokeh.io import  push_notebook, output_notebook, show
output_notebook() # permet d'afficher tous les futurs graphiques dans l'output d'une cellule jupyter. Si cette instruction n'est pas lancée, la figure s'affichera dans un nouvel onglet.
from bokeh.models import ColumnDataSource
from bokeh.transform import dodge
from bokeh.models.tools import HoverTool

# %%
df = pd.read_csv('ASRS_20y_data.csv', low_memory=False)
# See https://stackoverflow.com/questions/24251219/pandas-read-csv-low-memory-and-dtype-options

# %%
df.head(3)
# Out:
#    Unnamed: 0     ACN    Date Local Time Of Day Locale Reference  \
# 0           0  986560  201201         1801-2400       A11.TRACON
# 1           1  988077  201201         0001-0600      ENA.Airport
# 2           2  988094  201201         0601-1200      PHX.Airport
#
#   State Reference  Relative Position.Angle.Radial  \
# 0              AK                             NaN
# 1              AK                             NaN
# 2              AZ                             NaN
#
#    Relative Position.Distance.Nautical Miles Altitude.AGL.Single Value  \
# 0                                        NaN                       NaN
# 1                                        NaN                       NaN
# 2                                        NaN                       NaN
#
#    Altitude.MSL.Single Value  Latitude / Longitude (UAS) Flight Conditions  \
# 0                     8000.0                         NaN               NaN
# 1                     2000.0                         NaN               IMC
# 2                    15000.0                         NaN               VMC
#
#   Weather Elements / Visibility Work Environment Factor     Light Ceiling  \
# 0                           NaN                     NaN       NaN     NaN
# 1                           NaN                     NaN       NaN     NaN
# 2                           NaN                     NaN  Daylight     NaN
#
#   RVR.Single Value         ATC / Advisory Aircraft Operator  \
# 0              NaN             TRACON A11          Air Taxi
# 1              NaN  Center ZAN; Tower ENA          Air Taxi
# 2              NaN             Center ZAB       Air Carrier
#
#                          Make Model Name Aircraft Zone  Crew Size  \
# 0                     Super King Air 200           NaN        1.0
# 1               Caravan Undifferentiated           NaN        1.0
# 2  B737 Next Generation Undifferentiated           NaN        2.0
#
#   Operating Under FAR Part Flight Plan    Mission  Nav In Use    Flight Phase  \
# 0                 Part 135         IFR  Passenger         NaN         Descent
# 1                 Part 135         IFR        NaN         NaN  Final Approach
# 2                 Part 121         IFR  Passenger  FMS Or FMC         Descent
#
#       Route In Use     Airspace Maintenance Status.Maintenance Deferred  \
# 0          Vectors  Class E ANC                                     NaN
# 1  Visual Approach  Class E ZAN                                     NaN
# 2       STAR GEELA  Class E ZAB                                     NaN
#
#   Maintenance Status.Records Complete Maintenance Status.Released For Service  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
#
#   Maintenance Status.Required / Correct Doc On Board  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   Maintenance Status.Maintenance Type  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
#
#   Maintenance Status.Maintenance Items Involved Cabin Lighting  \
# 0                                           NaN            NaN
# 1                                           NaN            NaN
# 2                                           NaN            NaN
#
#    Number Of Seats.Number  Passengers On Board.Number  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
#
#    Crew Size Flight Attendant.Number Of Crew  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
#
#   Airspace Authorization Provider (UAS)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Operating Under Waivers / Exemptions / Authorizations (UAS)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   Waivers / Exemptions / Authorizations (UAS)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
#
#   Airworthiness Certification (UAS) Weight Category (UAS) Configuration (UAS)  \
# 0                               NaN                   NaN                 NaN
# 1                               NaN                   NaN                 NaN
# 2                               NaN                   NaN                 NaN
#
#   Flight Operated As (UAS) Flight Operated with Visual Observer (UAS)  \
# 0                      NaN                                        NaN
# 1                      NaN                                        NaN
# 2                      NaN                                        NaN
#
#   Control Mode (UAS) Flying In / Near / Over (UAS) Passenger Capable (UAS)  \
# 0                NaN                           NaN                     NaN
# 1                NaN                           NaN                     NaN
# 2                NaN                           NaN                     NaN
#
#   Type (UAS) Number of UAS Being Controlled (UAS) Aircraft Component  \
# 0        NaN                                  NaN                NaN
# 1        NaN                                  NaN                NaN
# 2        NaN                                  NaN                MCP
#
#   Manufacturer Aircraft Reference              Problem ATC / Advisory.1  \
# 0          NaN                NaN                  NaN              NaN
# 1          NaN                NaN                  NaN              NaN
# 2          NaN                  X  Improperly Operated              NaN
#
#   Aircraft Operator.1 Make Model Name.1  Aircraft Zone.1  Crew Size.1  \
# 0                 NaN               NaN              NaN          NaN
# 1                 NaN               NaN              NaN          NaN
# 2                 NaN               NaN              NaN          NaN
#
#   Operating Under FAR Part.1 Flight Plan.1 Mission.1 Nav In Use.1  \
# 0                        NaN           NaN       NaN          NaN
# 1                        NaN           NaN       NaN          NaN
# 2                        NaN           NaN       NaN          NaN
#
#   Flight Phase.1 Route In Use.1 Airspace.1  \
# 0            NaN            NaN        NaN
# 1            NaN            NaN        NaN
# 2            NaN            NaN        NaN
#
#   Maintenance Status.Maintenance Deferred.1  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
#
#    Maintenance Status.Records Complete.1  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
#
#   Maintenance Status.Released For Service.1  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
#
#   Maintenance Status.Required / Correct Doc On Board.1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   Maintenance Status.Maintenance Type.1  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Maintenance Status.Maintenance Items Involved.1 Cabin Lighting.1  \
# 0                                             NaN              NaN
# 1                                             NaN              NaN
# 2                                             NaN              NaN
#
#    Number Of Seats.Number.1  Passengers On Board.Number.1  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
#
#    Crew Size Flight Attendant.Number Of Crew.1  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
#
#    Airspace Authorization Provider (UAS).1  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
#   Operating Under Waivers / Exemptions / Authorizations (UAS).1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   Waivers / Exemptions / Authorizations (UAS).1  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
#
#    Airworthiness Certification (UAS).1 Weight Category (UAS).1  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
#
#   Configuration (UAS).1 Flight Operated As (UAS).1  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
#
#    Flight Operated with Visual Observer (UAS).1  Control Mode (UAS).1  \
# 0                                           NaN                   NaN
# 1                                           NaN                   NaN
# 2                                           NaN                   NaN
#
#   Flying In / Near / Over (UAS).1  Passenger Capable (UAS).1  Type (UAS).1  \
# 0                             NaN                        NaN           NaN
# 1                             NaN                        NaN           NaN
# 2                             NaN                        NaN           NaN
#
#   Number of UAS Being Controlled (UAS).1   Location Of Person  \
# 0                                    NaN  Facility A11.TRACON
# 1                                    NaN   Facility ZAN.ARTCC
# 2                                    NaN           Aircraft X
#
#   Location In Aircraft Reporter Organization                     Function  \
# 0                  NaN            Government          Departure; Approach
# 1                  NaN            Government                      Enroute
# 2          Flight Deck           Air Carrier  Pilot Flying; First Officer
#
#                          Qualification  \
# 0    Air Traffic Control Developmental
# 1  Air Traffic Control Fully Certified
# 2                                  NaN
#
#                                           Experience Cabin Activity  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2  Flight Crew Last 90 Days 156; Flight Crew Type...            NaN
#
#                                        Human Factors  \
# 0                              Situational Awareness
# 1                              Situational Awareness
# 2  Situational Awareness; Workload; Human-Machine...
#
#                              Communication Breakdown  \
# 0                                                NaN
# 1                                                NaN
# 2  Party1 Flight Crew; Party2 Flight Crew; Party2...
#
#   UAS Communication Breakdown  ASRS Report Number.Accession Number  \
# 0                         NaN                             986560.0
# 1                         NaN                             988077.0
# 2                         NaN                             988094.0
#
#   Location Of Person.1 Location In Aircraft.1 Reporter Organization.1  \
# 0                  NaN            Flight Deck                Air Taxi
# 1                  NaN                    NaN                     NaN
# 2           Aircraft X            Flight Deck             Air Carrier
#
#                   Function.1                        Qualification.1  \
# 0      Captain; Pilot Flying                                    NaN
# 1                        NaN                                    NaN
# 2  Captain; Pilot Not Flying  Flight Crew Air Transport Pilot (ATP)
#
#                                         Experience.1 Cabin Activity.1  \
# 0  Flight Crew Last 90 Days 46; Flight Crew Total...              NaN
# 1                                                NaN              NaN
# 2  Flight Crew Last 90 Days 141; Flight Crew Type...              NaN
#
#                                      Human Factors.1  \
# 0                                                NaN
# 1                                                NaN
# 2  Situational Awareness; Human-Machine Interface...
#
#   Communication Breakdown.1 UAS Communication Breakdown.1  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
#
#    ASRS Report Number.Accession Number.1  \
# 0                               986993.0
# 1                                    NaN
# 2                               988102.0
#
#                                              Anomaly Miss Distance  \
# 0  Deviation - Altitude Excursion From Assigned A...           NaN
# 1  ATC Issue All Types; Deviation / Discrepancy -...           NaN
# 2  Deviation - Altitude Crossing Restriction Not ...           NaN
#
#   Were Passengers Involved In Event                    Detector When Detected  \
# 0                               NaN  Person Air Traffic Control           NaN
# 1                               NaN  Person Air Traffic Control           NaN
# 2                               NaN          Person Flight Crew     In-flight
#
#                                               Result  \
# 0           Air Traffic Control Issued New Clearance
# 1                      General None Reported / Taken
# 2  Flight Crew Returned To Clearance; Flight Crew...
#
#     Contributing Factors / Situations Primary Problem  \
# 0                       Human Factors   Human Factors
# 1   Weather; Human Factors; Procedure   Human Factors
# 2  Procedure; Aircraft; Human Factors        Aircraft
#
#                                            Narrative Callback  \
# 0  A BE20 was inbound to ANC via YESKA. He was to...      NaN
# 1  A C208 departed for Kenai. Kenai Tower called ...      NaN
# 2  We were on the GEELA Arrival into PHX and were...      NaN
#
#                                          Narrative.1 Callback.1  \
# 0  I was descending to 8;000 FT proceeding direct...        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
#
#                                             Synopsis  Unnamed: 125
# 0  A11 Controller described a descent below MVA; ...           NaN
# 1  ZAN Controller issued a Visual Approach cleara...           NaN
# 2  A B737-NG on the PHX GEELA arrival was vectore...           NaN

# %%
print("The raw dataset has a total of", len(df), "entries.",
     "\n/!\ These include unmanned-aircraft-related entries; yet the latter are insignificantly low in number (see below)")
# Out:
# The raw dataset has a total of 108407 entries.
# /!\ These include unmanned-aircraft-related entries; yet the latter are insignificantly low in number (see below)

# %% [markdown]
# ### Remove UAS-related data

# %% [markdown]
# A UAS (Unmanned Aircraft Systems) includes not only the UAV (or drone), but also the person on the ground controlling the flight and the system in place that connects both of them.

# %% [markdown]
# #### Find out how many UAS-entries we have

# %%
features_UAS_all = [
###################################
### FEATURES RELATED TO DRONES  ###
###################################
 'Latitude / Longitude (UAS)',
    'Operating Under Waivers / Exemptions / Authorizations (UAS)',
  'Waivers / Exemptions / Authorizations (UAS)',
  'Airworthiness Certification (UAS)', # Only 'Standard' value
  'Weight Category (UAS)',
  'Configuration (UAS)',
  'Flight Operated As (UAS)',
  'Flight Operated with Visual Observer (UAS)', # BVLOS (Beyond Visual Line of Sight) is a term relating to the operation of UAVs (unmanned aerial vehicles) and drones at distances outside the normal visible range of the pilot.
 'Control Mode (UAS)',
 'Flying In / Near / Over (UAS)',
 'Passenger Capable (UAS)', # There are only NaNs and 'N'
 'Type (UAS)',
 'Number of UAS Being Controlled (UAS)',
 'UAS Communication Breakdown',    
 'Airspace Authorization Provider (UAS)', # only NaN's in this feature --> drop ?

    
##################################################
### Additional entries for the above variables ###
##################################################
 'Airspace Authorization Provider (UAS).1',
 'Operating Under Waivers / Exemptions / Authorizations (UAS).1',
 'Waivers / Exemptions / Authorizations (UAS).1',
 'Airworthiness Certification (UAS).1',
 'Weight Category (UAS).1',
 'Configuration (UAS).1',
 'Flight Operated As (UAS).1',
 'Flight Operated with Visual Observer (UAS).1',
 'Control Mode (UAS).1',
 'Flying In / Near / Over (UAS).1',
 'Passenger Capable (UAS).1',
 'Type (UAS).1',
 'Number of UAS Being Controlled (UAS).1',    
##################################################
]

# %%
# Search and gather the rows that contain non-nan values for any of the UAS features into dataframes

files = [] # instantiate empty list

for feat in features_UAS_all:
    
    # append pandas DataFrames to 'files' --> files becomes list of df's.
    files.append(df.loc[df[feat].isna() == False])

# concatenate df's into 1 df:
df_UAS = pd.concat(files)

# Drop the duplicates; there definitely exist many, because we searched column-by-column
df_UAS = df_UAS.drop_duplicates(keep= 'first')

# %%
print("The data contain", len(df_UAS), "UAS-related entries.")
# Out:
# The data contain 166 UAS-related entries.

# %% [markdown]
# This quantity of UAS entries seems reasonable, because these data have NaN's in many MANNED-aircraft-related features, as shown in the next line. Note that 'Make Model Name' has no NaNs.

# %%
df_UAS.isna().sum()
# Out:
# Unnamed: 0                                                         0
# ACN                                                                0
# Date                                                               0
# Local Time Of Day                                                 18
# Locale Reference                                                   1
# State Reference                                                    0
# Relative Position.Angle.Radial                                   138
# Relative Position.Distance.Nautical Miles                         79
# Altitude.AGL.Single Value                                         83
# Altitude.MSL.Single Value                                         98
# Latitude / Longitude (UAS)                                       166
# Flight Conditions                                                 20
# Weather Elements / Visibility                                     68
# Work Environment Factor                                          162
# Light                                                             55
# Ceiling                                                           78
# RVR.Single Value                                                 165
# ATC / Advisory                                                   127
# Aircraft Operator                                                  7
# Make Model Name                                                    0
# Aircraft Zone                                                    166
# Crew Size                                                         15
# Operating Under FAR Part                                          13
# Flight Plan                                                        8
# Mission                                                            7
# Nav In Use                                                       136
# Flight Phase                                                       4
# Route In Use                                                      68
# Airspace                                                          27
# Maintenance Status.Maintenance Deferred                          166
# Maintenance Status.Records Complete                              166
# Maintenance Status.Released For Service                          166
# Maintenance Status.Required / Correct Doc On Board               166
# Maintenance Status.Maintenance Type                              166
# Maintenance Status.Maintenance Items Involved                    166
# Cabin Lighting                                                   166
# Number Of Seats.Number                                           166
# Passengers On Board.Number                                       166
# Crew Size Flight Attendant.Number Of Crew                        166
# Airspace Authorization Provider (UAS)                            154
# Operating Under Waivers / Exemptions / Authorizations (UAS)      107
# Waivers / Exemptions / Authorizations (UAS)                      154
# Airworthiness Certification (UAS)                                158
# Weight Category (UAS)                                             92
# Configuration (UAS)                                               91
# Flight Operated As (UAS)                                         103
# Flight Operated with Visual Observer (UAS)                       115
# Control Mode (UAS)                                               106
# Flying In / Near / Over (UAS)                                     95
# Passenger Capable (UAS)                                          156
# Type (UAS)                                                       112
# Number of UAS Being Controlled (UAS)                              98
# Aircraft Component                                               144
# Manufacturer                                                     150
# Aircraft Reference                                               145
# Problem                                                          144
# ATC / Advisory.1                                                 164
# Aircraft Operator.1                                              161
# Make Model Name.1                                                 67
# Aircraft Zone.1                                                  166
# Crew Size.1                                                      163
# Operating Under FAR Part.1                                       164
# Flight Plan.1                                                    157
# Mission.1                                                        162
# Nav In Use.1                                                     166
# Flight Phase.1                                                   140
# Route In Use.1                                                   164
# Airspace.1                                                        81
# Maintenance Status.Maintenance Deferred.1                        166
# Maintenance Status.Records Complete.1                            166
# Maintenance Status.Released For Service.1                        166
# Maintenance Status.Required / Correct Doc On Board.1             166
# Maintenance Status.Maintenance Type.1                            166
# Maintenance Status.Maintenance Items Involved.1                  166
# Cabin Lighting.1                                                 166
# Number Of Seats.Number.1                                         166
# Passengers On Board.Number.1                                     166
# Crew Size Flight Attendant.Number Of Crew.1                      166
# Airspace Authorization Provider (UAS).1                          166
# Operating Under Waivers / Exemptions / Authorizations (UAS).1    165
# Waivers / Exemptions / Authorizations (UAS).1                    163
# Airworthiness Certification (UAS).1                              166
# Weight Category (UAS).1                                          161
# Configuration (UAS).1                                            141
# Flight Operated As (UAS).1                                       165
# Flight Operated with Visual Observer (UAS).1                     166
# Control Mode (UAS).1                                             166
# Flying In / Near / Over (UAS).1                                   81
# Passenger Capable (UAS).1                                        166
# Type (UAS).1                                                     166
# Number of UAS Being Controlled (UAS).1                           153
# Location Of Person                                                 6
# Location In Aircraft                                              86
# Reporter Organization                                             13
# Function                                                           2
# Qualification                                                     17
# Experience                                                        42
# Cabin Activity                                                   166
# Human Factors                                                     23
# Communication Breakdown                                          166
# UAS Communication Breakdown                                      159
# ASRS Report Number.Accession Number                                0
# Location Of Person.1                                             155
# Location In Aircraft.1                                           159
# Reporter Organization.1                                          155
# Function.1                                                       155
# Qualification.1                                                  154
# Experience.1                                                     159
# Cabin Activity.1                                                 166
# Human Factors.1                                                  155
# Communication Breakdown.1                                        166
# UAS Communication Breakdown.1                                    165
# ASRS Report Number.Accession Number.1                            155
# Anomaly                                                            0
# Miss Distance                                                     97
# Were Passengers Involved In Event                                160
# Detector                                                           2
# When Detected                                                      9
# Result                                                             4
# Contributing Factors / Situations                                  3
# Primary Problem                                                    5
# Narrative                                                          0
# Callback                                                         137
# Narrative.1                                                      154
# Callback.1                                                       165
# Synopsis                                                           0
# Unnamed: 125                                                     166
# dtype: int64

# %% [markdown]
# #### Drop UAS-related features and data

# %%
# remove rows
df = df.drop(df_UAS.index, axis = 0)

# %%
# Check: 
len(df) + len(df_UAS)
# Out:
# 108407

# %%
# remove UAS-columns
df = df.drop(columns= features_UAS_all)

# %% [markdown]
# ### DataViz: Plot unique() and NaN ratio

# %%
# Create an auxiliary dataframe

# Count the total No of entries, unique instances and No of NaN's of each feature
unique_cnts = []
total_entries_feat = []
nan_feat = []

for feat in df.columns:
  unique_cnts.append(len(df[str(feat)].unique()))
  total_entries_feat.append(len(df[str(feat)]))
  nan_feat.append(df[str(feat)].isna().sum())    # count No of NaN's

# Write the counts into a new df for easier handling the seaborn plot
my_df = pd.DataFrame({'feature': df.columns,
                      'unique counts': unique_cnts,
                      'total_entries_feat': total_entries_feat,
                      'nan_features':   nan_feat
                      })

# Add an entry with the max count possible, i.e. len(df)
new_entry = pd.DataFrame({'feature' : ['Total No of entries'],
                          'unique counts': [len(df)]
                          })
my_df = pd.concat([my_df, new_entry], ignore_index = True, axis = 0)

# Sort dataframe in descending order of unique counts
my_df = my_df.sort_values(by = 'unique counts', ascending = False)

# %%
# Barplot of unique features
fig = plt.figure(figsize = (20,20))
ax = sns.barplot(data = my_df, x = 'unique counts', y = 'feature')

# Color the top bar
for bar in ax.patches:
    if bar.get_y() < 0.5: # get_y() returns the bottom coordinate of the rectangle 
                          # given a vertical bar layout --> here '< 0.5' means the topmost bar
        bar.set_color('magenta')

# Plot the 15 most frequent occurences
topX = 15
plt.ylim(topX - 0.5)
plt.xlabel('Count')
plt.title(f"top{topX} features with most unique instances");

# %% [markdown]
# * It is expected that ACN, Narrative, Synopsis would have so many entries as there are data
# * Why are there slightly less 'ASRS Report Number.Accession Number'?
# * Low counts on Locale Reference either
#   * because events around a small number of airports (unlikely)
#   * because many anonymized data (the actual reason)
#
# * The variety of 'Experience' is not surprising, because it contains hours/years of experience
# * The variety in 'Anomaly' is suprisingly high, given that there are only 66 'Anomaly' labels stated in the 'CodingForm.pdf' of the ASRS database
# * 'Contributing Factors' and 'Human Factors' is also suprisingly high
#
# **This is due to the fact that these variables are combinations of a small amount of labels.**

# %% [markdown]
# Inspect unique instances and completion percentage of the data for each feature:

# %%
my_df['compl_percent'] = np.round(100 * (1 - (my_df['nan_features'] / my_df['total_entries_feat'])), 1)
my_df['unique_cnts_scaled'] = my_df['unique counts'] / 1000

# For the next plot below: sort dataframe in descending order of completion percentage
my_df = my_df.sort_values(by = 'compl_percent', ascending = False)

my_df.head()
# Out:
#             feature  unique counts  total_entries_feat  nan_features  \
# 1               ACN         108241            108241.0           0.0
# 5   State Reference             68            108241.0           0.0
# 97         Synopsis         108090            108241.0          11.0
# 93        Narrative         108223            108241.0           0.0
# 0        Unnamed: 0           4984            108241.0           0.0
#
#     compl_percent  unique_cnts_scaled
# 1           100.0             108.241
# 5           100.0               0.068
# 97          100.0             108.090
# 93          100.0             108.223
# 0           100.0               4.984

# %%
source = ColumnDataSource(my_df)

f = figure(width = 1800, height = 600, x_range = my_df['feature'])
f.xaxis.major_label_orientation = np.pi/2

abcisses1 = dodge(field_name = 'feature', value = -0.25, range = f.x_range)
abcisses2 = dodge(field_name = 'feature', value = 0, range = f.x_range)
#abcisses3 = dodge(field_name = 'x', value = 0.25, range = f.x_range)

v1 = f.vbar(source = source, x = abcisses1, top = 'unique_cnts_scaled', width = 0.2, color = 'blue', legend_label = "unique counts [thousands]")
v2 = f.vbar(source = source, x = abcisses2, top = 'compl_percent', width = 0.2, color = 'green', legend_label = "completion percentage (how many NaN's)")
#v3 = f.vbar(source = source, x = abcisses3, top = 'valeur 3', width = 0.2, color = 'blue', legend_label = "Valeur 3")

# Create HoverTool
h = HoverTool(renderers = [v1, v2],  # liste de GlyphRenderer avec lesquels on veut intéragir
    
              tooltips = [( "feature", "@feature"), 
                          ("unique counts [thousands]", "@unique_cnts_scaled"),
                          ("completeness percentage", "@compl_percent")
                          ]) # liste de couples d'informations à afficher à coté du point survolé. Les informations que nous affichons sont les coordonnées du point survolé.  
f.add_tools(h)

f.legend.location ='center'
show(f)
# Out:
#   <div class="bk-root" id="61c353bb-e305-4278-bf85-33b05dc4babb" data-root-id="1003"></div>

# %%
# Sort dataframe in descending order of *completenes percentage*
my_df = my_df.sort_values(by = 'compl_percent', ascending = False)

# %% [markdown]
# ### Heatmap of correlations

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(), annot=True, cmap='RdBu_r', center=0);

# %% [markdown]
# No significant correlations observed.

# %% [markdown]
# ### DataViz: Primary Problem

# %%
# Instantiate new figure
fig = plt.figure(figsize= (20,10))
ax = fig.add_subplot(111) # need the ax handle to set the ylabels to None

# Plot in decreasing order
sns.countplot(y = df['Primary Problem'], 
              order = df['Primary Problem'].value_counts().index, 
              orient = 'h')

# Plot settings
plt.title('Top10 primary problems')
ax.set(ylabel = None)
# Plot the 10 most frequent occurences
topX = 10
plt.ylim(topX - 0.5);

# %% [markdown]
# ### DataViz: Human Factors

# %%
# TAKES ABOUT 2min. to EXECUTE 
# Make a list of all 'Human Factor' entries
hum_facts = list()
for entry in df['Human Factors']:
    split = str(entry).split(sep = '; ') # include a space after ';'
    hum_facts = hum_facts + split

# %%
# Countplot:
fig = plt.figure(figsize= (13,7))

# # Plot in decreasing order
sns.countplot(y = hum_facts, 
              order= pd.Series(hum_facts).value_counts().index, # need to transform list to pd.Series for the ordering in countplot()
              orient = 'h') 
plt.title('Human Factors');

# %% [markdown]
# ### 'Result'

# %%
# TAKES ABOUT 3min. to EXECUTE 
# Make a list of all 'Result' entries
result = list()
for entry in df['Result']:
    split = str(entry).split(sep = '; ') # include a space after ';'
    result = result + split

# %%
# Countplot:
fig = plt.figure(figsize= (13,16))

sns.countplot(y = result, 
              order= pd.Series(result).value_counts().index,  # need to transform list to pd.Series for the ordering in countplot()
              orient = 'h')

# Plot the 20 most frequent occurences
topX = 20
plt.ylim(topX - 0.5)

plt.xticks(rotation=45)
plt.title('Top20 event results');

# %%
# Countplot:
fig = plt.figure(figsize= (13,7))

# # Plot in decreasing order
sns.countplot(y = hum_facts, 
              order= pd.Series(hum_facts).value_counts().index, # need to transform list to pd.Series for the ordering in countplot()
              orient = 'h') 
plt.title('Human Factors');

# %% [markdown]
# ### 'Anomaly'

# %%
#list(df['Anomaly'].unique())#[:30] # show only first 30 entires (unsorted)

# %% [markdown]
# #### Labels containing 'other'
#
# While there is no category `'Other Unwanted Situation'` to pick on the search engine, inside `df['Anomaly'].unique()` we find the label: `'Other Unwanted Situation'`.

# %%
print("Number of entries with 'Anomaly' == 'Other Unwanted situation':", len(df[df['Anomaly'] == 'Other Unwanted situation']), 
      "\n There are 10 more entries that contain 'Other Unwanted situation' combined with other labels (see countplot at root-label level")
# Out:
# Number of entries with 'Anomaly' == 'Other Unwanted situation': 20
#  There are 10 more entries that contain 'Other Unwanted situation' combined with other labels (see countplot at root-label level

# %% [markdown]
# **TBD: Do we drop these data?**
#
# Let's decide once we have identified the desired label for our narratives...

# %% [markdown]
# Other occurences of the word 'Other' are:
#
# ```
# Inflight Event / Encounter Other / Unknown
# Flight Deck / Cabin / Aircraft Event Other / Unknown
# Ground Event / Encounter Other / Unknown
# ```
#
# In these cases, 'Other' is present inside the label due to the concatenation (by the ASRS engine) of the root-label with its sublabels, e.g.
#
# `Flight Deck / Cabin / Aircraft Event`
#
# and
#
# `Other / Unknown`

# %% [markdown]
# #### Labels `'Critical'` and `'Less Severe'`
#
# There is a specificity for the labels `'Critical'` and `'Less Severe'`:
#
# 'Critical' may appear either as
# * a sublabel of `'Aircraft Equipment Problem'`. In this case it is found together with its root-label: `'Aircraft Equipment Problem Critical;'`
# The  `';' `at the end introduces the next label in the present database entry.
#
# * in this form: `'Conflict Ground Conflict; Critical;'`
# Here it has to be interpreted as a sublabel, since there is no root-label named simply `'Critical'`
#
# </br>
#
# Exactly the same issue happens for `'Less Severe'`
#
# </br>
# To avoid the interpretation of 'Critical' and 'Less Severe' as root-labels, we merge them with their root-label in the situations, where they are separated by a ';'.
#
# To do this, we use **regular expressions**.

# %%
# Write all the entries of 'Anomaly' into a single string using 
# a delimiter that is *not* present in the data, i.e. '$'

# This approach is MUCH FASTER than going through the dataset 
# line-by-line and replacing strings. Ioannis tried the latter;
# takes min. 10' to execute.
# Perhaps the .apply() method is an alternative...?

all_anomaly = ''
all_anomaly = '$'.join(str(entry) for entry in df['Anomaly']) # do not include a ' ' before / after the '$' !

# %%
# Inspect the result
# Print does not work, because too large
all_anomaly[:1000]
# Out:
# 'Deviation - Altitude Excursion From Assigned Altitude; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance$ATC Issue All Types; Deviation / Discrepancy - Procedural Published Material / Policy$Deviation - Altitude Crossing Restriction Not Met; Deviation / Discrepancy - Procedural Published Material / Policy; Deviation / Discrepancy - Procedural Clearance$Conflict Ground Conflict; Critical; Deviation / Discrepancy - Procedural Clearance; Ground Incursion Taxiway$Inflight Event / Encounter CFTT / CFIT; Inflight Event / Encounter VFR In IMC; Inflight Event / Encounter Weather / Turbulence$Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude$Conflict NMAC$Conflict NMAC; Deviation / Discrepancy - Procedural Published Material / Policy$Inflight Event / Encounter Other / Unknown$Inflight Event / Encounter CFTT / CFIT; Inflight Event / Encounter Unstabilized Approach$Deviation - Altitude Crossing Restrict'

# %%
r = re.findall("Conflict Ground Conflict; Critical", all_anomaly)
print("Found", len(r), "instances")
# Out:
# Found 2782 instances

# %%
# Compile Regular Expressions

# These are the expressions we are looking for
r1 = re.compile(r"Conflict Ground Conflict; Critical") 
# Do NOT search for 'Conflict Ground Conflict; Critical;',
# i.e. with a ';' at the end, because some times it is the last entry, 
# so there is no trailing ';'

# Proceed similarly for the other expressions
r2 = re.compile(r"Conflict Ground Conflict; Less Severe")

# Find and substitute
# Make sure the output of the first operation is the input of the next
all_anomaly = r1.sub('Conflict Ground Conflict Critical', all_anomaly)
all_anomaly = r2.sub('Conflict Ground Conflict Less Severe', all_anomaly)

# %%
# Write the large text back into a df column, using the '$' separator
df['AnomalyNew'] = all_anomaly.split(sep = '$')

# %%
# # Verify the result
# list(df['AnomalyNew'].unique())

# %% [markdown]
# #### Countplot for 'Anomaly without combining the sublabels

# %%
S = df['AnomalyNew']
S = S.str.split(';', expand= True).stack().reset_index(drop = True)

#Create new df with anomalies and corresponding occurence
freq_anly = pd.DataFrame(index=S)

# strip leading and trailing space
freq_anly.index = freq_anly.index.str.strip()

# %%
# Count occurences
freq_anly['No of Anomaly Occurence'] = S.value_counts()
freq_anly = freq_anly.drop_duplicates()
freq_anly = freq_anly.sort_values(by = 'No of Anomaly Occurence', axis = 0, ascending=False)
#freq_anly

# %%
freq_anly
# Out:
#                                                     No of Anomaly Occurence
# Aircraft Equipment Problem Critical                                 24831.0
# ATC Issue All Types                                                 18273.0
# Aircraft Equipment Problem Less Severe                              16516.0
# Deviation / Discrepancy - Procedural Published ...                   8325.0
# Deviation / Discrepancy - Procedural FAR                             3806.0
# Conflict Airborne Conflict                                           3400.0
# Conflict NMAC                                                        3309.0
# Deviation - Track / Heading All Types                                3273.0
# Deviation / Discrepancy - Procedural Clearance                       2533.0
# Airspace Violation All Types                                         2414.0
# Deviation - Altitude Excursion From Assigned Al...                   1979.0
# Conflict Ground Conflict Critical                                    1882.0
# Conflict Ground Conflict Less Severe                                 1519.0
# Deviation - Altitude Overshoot                                       1452.0
# Deviation - Altitude Crossing Restriction Not Met                    1255.0
# Deviation - Speed All Types                                          1229.0
# Ground Event / Encounter Loss Of Aircraft Control                     831.0
# Flight Deck / Cabin / Aircraft Event Smoke / Fi...                    690.0
# Inflight Event / Encounter Weather / Turbulence                       654.0
# Inflight Event / Encounter Wake Vortex Encounter                      515.0
# Flight Deck / Cabin / Aircraft Event Illness / ...                    498.0
# Ground Event / Encounter Other / Unknown                              487.0
# Deviation / Discrepancy - Procedural Hazardous ...                    480.0
# Deviation / Discrepancy - Procedural Other / Un...                    478.0
# No Specific Anomaly Occurred All Types                                458.0
# nan                                                                   450.0
# Inflight Event / Encounter CFTT / CFIT                                439.0
# Deviation / Discrepancy - Procedural Maintenance                      375.0
# Inflight Event / Encounter Other / Unknown                            349.0
# Flight Deck / Cabin / Aircraft Event Other / Un...                    309.0
# Inflight Event / Encounter Loss Of Aircraft Con...                    280.0
# Ground Event / Encounter Ground Strike - Aircraft                     267.0
# Deviation - Altitude Undershoot                                       213.0
# Deviation / Discrepancy - Procedural Weight And...                    191.0
# Inflight Event / Encounter Unstabilized Approach                      146.0
# Inflight Event / Encounter Bird / Animal                              124.0
# Deviation / Discrepancy - Procedural Landing Wi...                    120.0
# Other Fatigue                                                         113.0
# Inflight Event / Encounter Fuel Issue                                 109.0
# Flight Deck / Cabin / Aircraft Event Passenger ...                    108.0
# Ground Event / Encounter Vehicle                                       98.0
# Ground Incursion Runway                                                92.0
# Deviation / Discrepancy - Procedural MEL / CDL                         85.0
# Ground Excursion Taxiway                                               78.0
# Deviation / Discrepancy - Procedural Security                          74.0
# Inflight Event / Encounter VFR In IMC                                  58.0
# Ground Event / Encounter Gear Up Landing                               56.0
# Ground Event / Encounter Person / Animal / Bird                        43.0
# Ground Event / Encounter Aircraft                                      39.0
# Ground Incursion Taxiway                                               36.0
# Inflight Event / Encounter Object                                      32.0
# Other Unwanted Situation                                               30.0
# Flight Deck / Cabin / Aircraft Event Passenger ...                     24.0
# Other Low Fuel State                                                   21.0
# Other Unwanted situation                                               20.0
# No Specific Anomaly Occurred Unwanted Situation                        18.0
# Other FSS Ops                                                          17.0
# Other Staffing                                                         16.0
# Other Min Fuel                                                         15.0
# Ground Event / Encounter Weather / Turbulence                          14.0
# Other Fac Staffing                                                     13.0
# Ground Excursion Ramp                                                  12.0
# Other Facility Staffing                                                11.0
# Other fatigue                                                          10.0
# Other ATC Handling                                                      9.0
# Other Freq Failure                                                      8.0
# Other Training                                                          7.0
# Other Flt Crew Illness                                                  6.0
# Ground Event / Encounter Jet Blast                                      5.0
# Other laser                                                             4.0
# Other Jet Blast                                                         3.0
# Other LASER                                                             2.0
# Other Laser Strike                                                      1.0
# Ground Incursion Ramp                                                   NaN

# %%
fig = plt.figure(figsize = (20,10)) 
sns.barplot(y = freq_anly.index, x = freq_anly['No of Anomaly Occurence'])
# Plot the 15 most frequent occurences
plt.ylim(14.5);

# %% [markdown]
# There is a major issue with this graph: It is at sublabel level, e.g. plots 'Conflict NMAC' and 'Conflict Ground Conflict Critical' as separate lines.
#
# Thus, we lack the overview of the main anomaly labels, a.k.a. 'root-labels'.
# We deal with this in the next section.

# %% [markdown]
# #### Gathering the labels with respect to their root-labels

# %% [markdown]
# All labels belonging to the same root-label should be merged together, to accurately count the number of occurences at root-label level.
#
# Especially in the case of root-labels e.g. `Deviation / Discrepancy `, which has several sublabels ('Clearance', 'FAR', 'Hazardous Material Violation' ... [total of 11 labels]), that are otherwise masked in the noise of their individual sublabel counts.
#
# The root-label with most sublabels is 'Ground Event / Encounter': 14 sublabels are listed in the database, of which 'Loss of VLOS (UAS)' applies to UAS entries, which we have dropped --> effectively 13 sublabels in our dataset.

# %%
# # HAVE NOT YET USED THIS CELL
# # List of the primary anomaly issues (root-labels)
# # Copied from the ASRS Search Wizard
# prim_anomalies = [
#                   'Aircraft Equipment Problem',
#                   'Airspace Violation',
#                   'ATC Issue',
#                   'Conflict'
#                   'Deviation - Altitude',
#                   'Deviation / Discrepancy - Procedural',
#                   'Deviation - Speed',
#                   'Deviation - Track / Heading',
#                   'Flight Deck / Cabin / Aircraft Event',
#                   'Ground Event / Encounter',
#                   'Ground Excursion',
#                   'Ground Incursion',
#                   'Inflight Event / Encounter',
#                   'No Specific Anomaly Occurred'
#                  ]

# %% [markdown]
# We will use RegEx's.
#
# We have tried the implementation using loops, but it is too slow.
#
# RegEx's are faster and more flexible, because we do not need to know the exact name of the labels; their syntactic structure is sufficient.

# %%
# Write all the entries of 'Anomaly' into a single string using 
# a delimiter which is not present in the data, i.e. '$'

# This approach is MUCH FASTER than going through the dataset 
# line-by-line and replacing strings. Ioannis tried this approach;
# takes min. 10' to execute.

all_anomaly = ''
all_anomaly = '$'.join(str(entry) for entry in df['AnomalyNew']) # do not include a ' ' before / after the '$' !

# %%
# Compile Regular Expressions

############ DELETE THIS  #################
#r = re.findall("Ground Event / Encounter[a-zA-Z0-9_\s\/\(\)\-]+;", all_anomaly) # THIS WORKS, KEEP IT !
#r = re.compile(r"Ground Event / Encounter[a-zA-Z0-9_\s\/\(\)\-]+;")
#r = re.compile(r"Ground\sEvent\s/\sEncounter[a-zA-Z0-9_\s\/\(\)\-]+;") 
#r = re.compile(r"Ground\sEvent\s/\sEncounter[a-zA-Z0-9_\-\s\/\(\)\-]+;")
############################################

# RegEx for 'Ground Event / Encounter' and its sublabels:
# we name our regex 'r10', to keep the same order of root-labels as on the ASRS wizard
r10 = re.compile(r"""
                  Ground\sEvent\s/\sEncounter  # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                           
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r10.findall(all_anomaly)
len(findings)
# Out:
# 9342

# %%
# Examine the unique list of findings and compare with ASRS search wizard
set(findings)
# Out:
# {'Ground Event / Encounter Aircraft',
#  'Ground Event / Encounter FOD',
#  'Ground Event / Encounter Fuel Issue',
#  'Ground Event / Encounter Gear Up Landing',
#  'Ground Event / Encounter Ground Equipment Issue',
#  'Ground Event / Encounter Ground Strike - Aircraft',
#  'Ground Event / Encounter Jet Blast',
#  'Ground Event / Encounter Loss Of Aircraft Control',
#  'Ground Event / Encounter Object',
#  'Ground Event / Encounter Other / Unknown',
#  'Ground Event / Encounter Person / Animal / Bird',
#  'Ground Event / Encounter Vehicle',
#  'Ground Event / Encounter Weather / Turbulence'}

# %%
len(set(findings)) # should be 13
# Out:
# 13

# %%
# Find and substitute
repl_result = re.subn(r10, 'Ground Event / Encounter', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# 9342 instances have been replaced

# %%
# # Check the result
#all_anomaly[:1000]

# %% [markdown]
# ##### 'Aircraft Equipment Problem'

# %%
# Compile Regular Expressions

# RegEx for 'Aircraft Equipment Problem' and its sublabels:
r1 = re.compile(r"""
                  Aircraft\sEquipment\sProblem  # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r1.findall(all_anomaly)
len(findings)
# Out:
# 42338

# %%
# Examine the unique list of findings and compare with ASRS search wizard
set(findings)
# Out:
# {'Aircraft Equipment Problem Critical',
#  'Aircraft Equipment Problem Less Severe'}

# %%
len(set(findings)) # should be 2
# Out:
# 2

# %%
# Find and substitute
repl_result = re.subn(r1, 'Aircraft Equipment Problem', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# 42338 instances have been replaced

# %% [markdown]
# ###### Tree representation

# %%
pip install ete3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ete3
#   Downloading ete3-3.1.2.tar.gz (4.7 MB)
#      |████████████████████████████████| 4.7 MB 4.4 MB/s
# Building wheels for collected packages: ete3
#   Building wheel for ete3 (setup.py) ... done
#   Created wheel for ete3: filename=ete3-3.1.2-py3-none-any.whl size=2273013 sha256=5950309c9bc7cff31239c5904b75be8845ddb983af1872312c5ccc02082dad77
#   Stored in directory: /root/.cache/pip/wheels/17/fd/e2/6ac384d8c2484789304657dde01b96d7ab83f4f1dd96d266df
# Successfully built ete3
# Installing collected packages: ete3
# Successfully installed ete3-3.1.2

# %%
# http://etetoolkit.org/docs/latest/tutorial/tutorial_trees.html
# pip install ete3
from ete3 import Tree

tree_branches = ""
for finding in set(findings):
 # tree_branches = finding + ', ' + tree_branches
  #tree_branches = ''.join(finding)
  tree_branches = ', '.join(finding for finding in set(findings)) # do not include a ' ' before / after the '$' !

tree_branches
# Out:
# 'Aircraft Equipment Problem Critical, Aircraft Equipment Problem Less Severe'

# %%
unrooted_tree = Tree( "(" + tree_branches + ");" )
print(unrooted_tree)
# Out:
#    /-Aircraft Equipment Problem Critical
# --|
#    \-Aircraft Equipment Problem Less Severe

# %%
rooted_tree = Tree( "(A,B,C,D);" )
print(rooted_tree)
# Out:
#    /-A
#   |
#   |--B
# --|
#   |--C
#   |
#    \-D

# %%
rooted_tree = Tree( "((A,B),(C,D, (F)));" )
print(rooted_tree)
# Out:
#       /-A
#    /-|
#   |   \-B
# --|
#   |   /-C
#   |  |
#    \-|--D
#      |
#       \- /-F

# %% [markdown]
# ##### 'Airspace Violation'

# %%
# Compile Regular Expressions

# RegEx for 'Airspace Violation' and its sublabels:
r2 = re.compile(r"""
                  Airspace\sViolation          # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r2.findall(all_anomaly)
len(findings)
# Out:
# 4403

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings))

print("Number of findings:", len(set(findings)), "(should be 1)")

# Find and substitute
repl_result = re.subn(r2, 'Airspace Violation', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'Airspace Violation All Types'}
# Number of findings: 1 (should be 1)
# 4403 instances have been replaced

# %% [markdown]
# ##### /!\ 'ATC Issue'

# %%
# Compile Regular Expressions

# RegEx for 'ATC Issue' and its sublabels:
r3 = re.compile(r"""
                  ATC\sIssue                   # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r3.findall(all_anomaly)
len(findings)
# Out:
# 18276

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings))

print("Number of findings:", len(set(findings)), "(should be 1)")

# Find and substitute
repl_result = re.subn(r3, 'ATC Issue', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'ATC Issued Improper Clrnc', 'ATC Issued GAR', 'ATC Issued Abort', 'ATC Issue All Types'}
# Number of findings: 4 (should be 1)
# 18276 instances have been replaced

# %% [markdown]
# According to the search engine wizard, there should be only 1 sublabel of 'ATC Issue': 'All Types'.
#
# **However, our RegEx finds 4 sublabels!**
#
# These are also not mentioned in the CodingForm.pdf from the ASRS database!
#
# This is yet another demonstration of the power of RegEx's that help us discover unexpected instances.

# %% [markdown]
# ##### /!\ 'Conflict'

# %%
# Compile Regular Expressions

# RegEx for 'Conflict' and its sublabels:
r4 = re.compile(r"""
                  Conflict                     # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r4.findall(all_anomaly)
len(findings)
# Out:
# 19486

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings), "\n")

print("Number of findings:", len(set(findings)), "(should be 4)\n")

# Find and substitute
repl_result = re.subn(r4, 'Conflict', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'Conflicting R/A', 'Conflict RE Arr Effective Date', 'Conflicting Proc', 'Conflict/ Acft Confign', 'Conflict NMAC', 'Conflict ARR/Dep Spacing', 'Conflict with Boat', 'Conflict Ground Conflict Less Severe', 'Conflict Ground Conflict Critical', 'Conflict Alerts', 'Conflict Alert On False Target', 'Conflict Alert System Not Audible', 'Conflict ATC Procs', 'Conflict Airborne Conflict', 'Conflict Alert', 'Conflicting Tfc', 'Conflicting Taxi Instructions', 'Conflict Alert Anomaly', 'Conflict Activity', 'Conflicting Tower Information', 'Confliction'}
#
# Number of findings: 21 (should be 4)
#
# 19486 instances have been replaced

# %%
# There is indeed a 'Conflict with Boat' entry in the original data !
my_str = str(list(df['Anomaly'].unique()))
print(my_str.find('Conflict with Boat'))
# Out:
# 1857058

# %% [markdown]
# ###### Tree representation

# %%
from ete3 import Tree
# http://etetoolkit.org/docs/latest/tutorial/tutorial_trees.html

tree_branches = ""
for finding in set(findings):
 # tree_branches = finding + ', ' + tree_branches
  #tree_branches = ''.join(finding)
  tree_branches = ', '.join(finding for finding in set(findings)) # do not include a ' ' before / after the '$' !

tree_branches
# Out:
# 'Conflicting R/A, Conflict RE Arr Effective Date, Conflicting Proc, Conflict/ Acft Confign, Conflict NMAC, Conflict ARR/Dep Spacing, Conflict with Boat, Conflict Ground Conflict Less Severe, Conflict Ground Conflict Critical, Conflict Alerts, Conflict Alert On False Target, Conflict Alert System Not Audible, Conflict ATC Procs, Conflict Airborne Conflict, Conflict Alert, Conflicting Tfc, Conflicting Taxi Instructions, Conflict Alert Anomaly, Conflict Activity, Conflicting Tower Information, Confliction'

# %%
unrooted_tree = Tree( "(" + tree_branches + ");" )
print(unrooted_tree)
# Out:
#    /-Conflicting R/A
#   |
#   |--Conflict RE Arr Effective Date
#   |
#   |--Conflicting Proc
#   |
#   |--Conflict/ Acft Confign
#   |
#   |--Conflict NMAC
#   |
#   |--Conflict ARR/Dep Spacing
#   |
#   |--Conflict with Boat
#   |
#   |--Conflict Ground Conflict Less Severe
#   |
#   |--Conflict Ground Conflict Critical
#   |
#   |--Conflict Alerts
#   |
# --|--Conflict Alert On False Target
#   |
#   |--Conflict Alert System Not Audible
#   |
#   |--Conflict ATC Procs
#   |
#   |--Conflict Airborne Conflict
#   |
#   |--Conflict Alert
#   |
#   |--Conflicting Tfc
#   |
#   |--Conflicting Taxi Instructions
#   |
#   |--Conflict Alert Anomaly
#   |
#   |--Conflict Activity
#   |
#   |--Conflicting Tower Information
#   |
#    \-Confliction

# %% [markdown]
# ##### 'Deviation / Altitude'

# %%
# Compile Regular Expressions

# RegEx for 'Deviation - Altitude' and its sublabels:
r5 = re.compile(r"""
                  Deviation\s\-\sAltitude       # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r5.findall(all_anomaly)
len(findings)
# Out:
# 11430

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings), "\n")

print("Number of findings:", len(set(findings)), "(should be 4)\n")

# Find and substitute
repl_result = re.subn(r5, 'Deviation - Altitude', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'Deviation - Altitude Excursion From Assigned Altitude', 'Deviation - Altitude Overshoot', 'Deviation - Altitude Crossing Restriction Not Met', 'Deviation - Altitude Undershoot'}
#
# Number of findings: 4 (should be 4)
#
# 11430 instances have been replaced

# %% [markdown]
# ##### /!\ 'Deviation / Discrepancy - Procedural'

# %%
# Compile Regular Expressions

# RegEx for 'Deviation / Discrepancy - Procedural' and its sublabels:
r6 = re.compile(r"""
                  Deviation\s/\sDiscrepancy\s\-\sProcedural       # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r6.findall(all_anomaly)
len(findings)
# Out:
# 104323

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings), "\n")

print("Number of findings:", len(set(findings)), "(should be 11)\n")

# Find and substitute
repl_result = re.subn(r6, 'Deviation / Discrepancy - Procedural', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'Deviation / Discrepancy - Procedural Hazardous Material Violation', 'Deviation / Discrepancy - Procedural FAR', 'Deviation / Discrepancy - Procedural MEL / CDL', 'Deviation / Discrepancy - Procedural Security', 'Deviation / Discrepancy - Procedural Published Material / Policy', 'Deviation / Discrepancy - Procedural Landing Without Clearance', 'Deviation / Discrepancy - Procedural Unauthorized Flight Operations (UAS)', 'Deviation / Discrepancy - Procedural Weight And Balance', 'Deviation / Discrepancy - Procedural Clearance', 'Deviation / Discrepancy - Procedural Other / Unknown', 'Deviation / Discrepancy - Procedural Maintenance'}
#
# Number of findings: 11 (should be 11)
#
# 104323 instances have been replaced

# %% [markdown]
# Strange that we found
#
# `'Deviation / Discrepancy - Procedural Unauthorized Flight Operations (UAS)'`
#
# **>>Examine this later in more detail.<<**

# %%
#val = df[df['Anomaly'].str.contains('Deviation / Discrepancy - Procedural Unauthorized Flight Operations (UAS)')]

# %%
#val.head()

# %% [markdown]
# ##### 'Deviation - Procedural'

# %%
# Compile Regular Expressions

# RegEx for 'Deviation - Speed' and its sublabels:
r7 = re.compile(r"""
                  Deviation\s\-\sSpeed       # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r7.findall(all_anomaly)
len(findings)
# Out:
# 2977

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings), "\n")

print("Number of findings:", len(set(findings)), "(should be 1)\n")

# Find and substitute
repl_result = re.subn(r7, 'Deviation - Speed', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'Deviation - Speed All Types'}
#
# Number of findings: 1 (should be 1)
#
# 2977 instances have been replaced

# %% [markdown]
# ##### 'Deviation - Track / Heading'

# %%
# Compile Regular Expressions

# RegEx for 'Deviation - Track / Heading' and its sublabels:
r8 = re.compile(r"""
                  Deviation\s\-\sTrack\s/\sHeading       # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r8.findall(all_anomaly)
len(findings)
# Out:
# 9153

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings), "\n")

print("Number of findings:", len(set(findings)), "(should be 1)\n")

# Find and substitute
repl_result = re.subn(r8, 'Deviation - Track / Heading', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'Deviation - Track / Heading All Types'}
#
# Number of findings: 1 (should be 1)
#
# 9153 instances have been replaced

# %% [markdown]
# ##### 'Flight Deck / Cabin / Aircraft Event'

# %%
# Compile Regular Expressions

# RegEx for 'Flight Deck / Cabin / Aircraft Event' and its sublabels:
r9 = re.compile(r"""
                  Flight\sDeck\s/\sCabin\s/\sAircraft\sEvent       # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r9.findall(all_anomaly)
len(findings)
# Out:
# 8809

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings), "\n")

print("Number of findings:", len(set(findings)), "(should be 5)\n")

# Find and substitute
repl_result = re.subn(r9, 'Flight Deck / Cabin / Aircraft Event', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'Flight Deck / Cabin / Aircraft Event Passenger Misconduct', 'Flight Deck / Cabin / Aircraft Event Smoke / Fire / Fumes / Odor', 'Flight Deck / Cabin / Aircraft Event Passenger Electronic Device', 'Flight Deck / Cabin / Aircraft Event Other / Unknown', 'Flight Deck / Cabin / Aircraft Event Illness / Injury'}
#
# Number of findings: 5 (should be 5)
#
# 8809 instances have been replaced

# %% [markdown]
# ##### 'Ground Excursion'

# %%
# Compile Regular Expressions

# RegEx for 'Ground Excursion' and its sublabels:
r11 = re.compile(r"""
                  Ground\sExcursion            # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r11.findall(all_anomaly)
len(findings)
# Out:
# 2472

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings), "\n")

print("Number of findings:", len(set(findings)), "(should be 3)\n")

# Find and substitute
repl_result = re.subn(r11, 'Ground Excursion', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'Ground Excursion Runway', 'Ground Excursion Taxiway', 'Ground Excursion Ramp'}
#
# Number of findings: 3 (should be 3)
#
# 2472 instances have been replaced

# %% [markdown]
# ##### 'Ground Incursion'

# %%
# Compile Regular Expressions

# RegEx for 'Ground Incursion' and its sublabels:
r12 = re.compile(r"""
                  Ground\sIncursion            # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r12.findall(all_anomaly)
len(findings)
# Out:
# 5882

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings), "\n")

print("Number of findings:", len(set(findings)), "(should be 3)\n")

# Find and substitute
repl_result = re.subn(r12, 'Ground Incursion', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'Ground Incursion Runway', 'Ground Incursion Taxiway', 'Ground Incursion Ramp'}
#
# Number of findings: 3 (should be 3)
#
# 5882 instances have been replaced

# %% [markdown]
# ##### 'Inflight Event / Encounter'

# %%
# Compile Regular Expressions

# RegEx for 'Inflight Event / Encounter' and its sublabels:
r13 = re.compile(r"""
                  Inflight\sEvent\s/\sEncounter  # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r13.findall(all_anomaly)
len(findings)
# Out:
# 24408

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings), "\n")

print("Number of findings:", len(set(findings)), "(should be 13 - [1 related to UAS])\n")

# Find and substitute
repl_result = re.subn(r13, 'Inflight Event / Encounter', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'Inflight Event / Encounter Laser', 'Inflight Event / Encounter VFR In IMC', 'Inflight Event / Encounter Weather / Turbulence', 'Inflight Event / Encounter Bird / Animal', 'Inflight Event / Encounter Fuel Issue', 'Inflight Event / Encounter Object', 'Inflight Event / Encounter Unstabilized Approach', 'Inflight Event / Encounter CFTT / CFIT', 'Inflight Event / Encounter Loss Of Aircraft Control', 'Inflight Event / Encounter Other / Unknown', 'Inflight Event / Encounter Wake Vortex Encounter', 'Inflight Event / Encounter Aircraft'}
#
# Number of findings: 12 (should be 13 - [1 related to UAS])
#
# 24408 instances have been replaced

# %% [markdown]
# ##### 'No Specific Anomaly Occurred'

# %%
# Compile Regular Expressions

# RegEx for 'No Specific Anomaly Occurred' and its sublabels:
r14 = re.compile(r"""
                  No\sSpecific\sAnomaly\sOccurred  # use \s instead of ' ', because verbose ignores the latter! 
                  
                  [a-zA-Z0-9_                  # define custom list of characters that should be found at least once 
                                               # corresponds to \w and we extend it with more characters below
                  
                  \-                           # hyphen
                  
                  \s                           # whitespace
                  
                  \/                           # forward slash
                  
                  \(\)]                        # left or right bracket; if detected it means you have not dropped all UAS entries
                                               # keep the ']' at the end; otherwise less matches are found
                   
                  +                            # '+' means 'find at least 1 occurence'
                                
               """, 
               re.VERBOSE)                     # VERBOSE allows us to write the RegEx in the above, expanded way --> more readable

findings = r14.findall(all_anomaly)
len(findings)
# Out:
# 560

# %%
# Examine the unique list of findings and compare with ASRS search wizard
print(set(findings), "\n")

print("Number of findings:", len(set(findings)), "(should be 2)\n")

# Find and substitute
repl_result = re.subn(r14, 'No Specific Anomaly Occurred', all_anomaly)
# The re.subn() method returns the new version of the target string after the replacements 
# The second element is the number of replacements it has made

print(repl_result[1], "instances have been replaced")

all_anomaly = repl_result[0]
# Out:
# {'No Specific Anomaly Occurred Unwanted Situation', 'No Specific Anomaly Occurred All Types'}
#
# Number of findings: 2 (should be 2)
#
# 560 instances have been replaced

# %% [markdown]
# #### DataViz: Countplot at root-label level

# %%
# Write the large text back into a df column, using the '$' separator
df['AnomalyNew1'] = all_anomaly.split(sep = '$')

S = df['AnomalyNew1']
S = S.str.split(';', expand= True).stack().reset_index(drop = True)

# %%
#Create new df with anomalies and corresponding occurence
freq_anly = pd.DataFrame(index=S)

# strip leading and trailing space
freq_anly.index = freq_anly.index.str.strip()

# Count occurences
freq_anly['No of Anomaly Occurence'] = S.value_counts()
freq_anly = freq_anly.drop_duplicates()
freq_anly = freq_anly.sort_values(by = 'No of Anomaly Occurence', axis = 0, ascending=False)

freq_anly[:20] # first 20 lines
# Out:
#                                       No of Anomaly Occurence
# Aircraft Equipment Problem                            41347.0
# ATC Issue                                             18273.0
# Deviation / Discrepancy - Procedural                  16467.0
# Conflict                                              10110.0
# Deviation - Altitude                                   4899.0
# Deviation - Track / Heading                            3273.0
# Inflight Event / Encounter                             2709.0
# Airspace Violation                                     2414.0
# Ground Event / Encounter                               2043.0
# Flight Deck / Cabin / Aircraft Event                   1629.0
# Deviation - Speed                                      1229.0
# No Specific Anomaly Occurred                            476.0
# nan                                                     450.0
# Ground Excursion                                        303.0
# Ground Incursion                                        128.0
# Other Fatigue                                           113.0
# Other Unwanted Situation                                 30.0
# Other Low Fuel State                                     21.0
# Other Unwanted situation                                 20.0
# Other FSS Ops                                            17.0

# %%
fig = plt.figure(figsize = (20,10)) 
sns.barplot(y = freq_anly.index, x = freq_anly['No of Anomaly Occurence'])
# Plot the 10 most frequent occurences
topX = 10
plt.ylim(topX - 0.5)
plt.xlabel('Count')
plt.title(f"The top{topX} most frequent root labels for 'Anomaly' ");

# %% [markdown]
# IDEAS:
# * we can group the rest of the 'Other' root-labels together, to motivate that we drop them (if we do drop them)
# * transform into BOKEH figure, when you hover the mouse over the bars, it shows you the type of sublabels that are included. This helps understanding the content of the root-label

# %%
df['AnomalyNew1'][5]
# Out:
# 'Conflict; Deviation - Altitude'

# %%
df['AnomalyNew'][5]
# Out:
# 'Conflict Airborne Conflict; Deviation - Altitude Excursion From Assigned Altitude'

# %% [markdown]
# ### Narratives

# %% [markdown]
# #### Select Narratives

# %%
# define a DataFrame of the entries that contain 2 narratives, i.e. Narrative.1 is not empty
nar1_all = df[df['Narrative.1'].isna() == False]

# %%
print("Out of a total of", len(df), "entries of events,", "there are", len(nar1_all), "entries that include a 2nd narrative.")
# Out:
# Out of a total of 108241 entries of events, there are 14825 entries that include a 2nd narrative.

# %%
print('Main Narrative: \n')
nar = nar1_all['Narrative'][9]
nar
# Out:
# Main Narrative:
# "During approach to TUS; leg 5 of a 6-leg day; talking to Approach Control; we were cleared direct CALLS for the ILS 11L and cleared to descend to 5;000 FT. We called the airport in sight and were cleared for the visual approach and told to contact Tower. First Officer selected direct POCIB in the FMC; and selected 4;600 FT on the MCP. When we contacted Tower; the Controller said to check altitude and stated the MVA in the area was 5;900 FT. Simultaneously we received a 'Caution Terrain; Caution Obstacle' alert from the GPWS. First Officer executed go-around maneuver. We climbed to clear the alert. Once we were clear of the hazard; we continued our descent to the runway. An s-turn to the south was needed to lose altitude. The terrain feature was in use on both navigation displays; but did not show an immediate threat in front of the airplane. The turn to POCIB was not verbalized; but I was aware of it. This turn only changed our lateral course by a couple of degrees to the right; so I did not initially think it would make a big difference; but it apparently brought us close enough laterally to terrain to trigger the alert.[We needed] verbalization of changes to FMC programming; staying on previously cleared path and altitude at night; even when cleared for a visual approach; especially in mountainous areas. Better monitoring and situational awareness on the part of the Captain/pilot not flying; not trying to salvage the approach under such conditions."

# %%
print('Second Narrative: \n')
nar1 = nar1_all['Narrative.1'][9]
nar1
# Out:
# Second Narrative:
# "While on a descent into TUS; we had been given direct CALLS and descend to 5;000 FT. We were high on our profile due to a delayed descent. I had the speedbrakes extended and at some point in the process as we approached 5;000 FT; I extended the landing gear to slow and configure for the approach. Approach asked if we had the airport in sight and we confirmed airport in sight. Approach cleared us for the visual approach and told us to contact Tower. Once cleared for the visual; I selected POCIB in the FMC and went direct and reset the MCP altitude to 4;600 FT. The difference in heading change was less than ten degrees. We were still descending at 250 KTS with speed brake extended and gear down. When we switched to Tower; Tower said 'Check altitude; minimum vectoring in that area is 5;900 FT.' We were descending through 5;300 FT and within a few miles of POCIB. As Tower tells us this; we receive a GPWS Caution; 'Caution Obstacle Caution Terrain.' Even though it was a visual approach; it was at night so we executed the required maneuver per the FOM. We asked Tower if we could take a turn to the south to reconfigure for landing after we were clear of all terrain. The Tower approved and we landed flaps 40; exited the runway; and parked the aircraft. Captain debriefed after parking at the gate. During the event; the terrain mapping feature on the ND display never indicated terrain in front of us. It was black with terrain showing to the north. It is my opinion that had I stayed on the original clearance to CALLS at 5;000 FT or had I been on profile with a normal descent rate; we would not have received the GPWS Caution."

# %% [markdown]
# #### DataViz: Wordcloud

# %%
def plot_word_cloud(text, title, stop_words, mask, background_color = "white") :
    """
    Plot a wordcloud of the input variable 'text' using the mask 'mask' and with 'title' as title .
    """
    from wordcloud import WordCloud
    from PIL import Image 
    # PIL: Python Imaging Library. Adds image processing capabilities to your Python interpreter.

    # Define a mask
    mask_coloring = np.array(Image.open(str(mask)))

    # Define the word cloud layer
    wc = WordCloud(background_color=background_color, 
                   max_words=150, 
                   stopwords=stop_words, 
                   mask = mask_coloring,
                   colormap='ocean', # cool # winter # ocean
                   # see list: https://matplotlib.org/stable/tutorials/colors/colormaps.html
                   max_font_size=40, random_state=42)
    
    # Generate and plot the wordcloud
    #plt.figure(figsize= (10,5)) # comment it out if you use subplots
    wc.generate(text)
    plt.imshow(wc, interpolation="bilinear")
    plt.xticks([])
    plt.yticks([])
    plt.title(f"{title}", fontsize = 15)
    #plt.show() # comment it out if you use subplots

# %%
# Define stop word list
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english')) 
# we convert it to a set, more efficient (vs. a liste) for the stopword-filtering later 
# 'set' also avoids duplicates

# add additional stop words: 
stop_words.update(['.', ';', '[', ']'])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# call the function defined above:
fig = plt.figure(figsize = (20, 20))

plt.subplot(121)
plot_word_cloud(nar, 'Main Narrative', stop_words, "plane.png")

plt.subplot(122)
plot_word_cloud(nar1, '2nd Narrative', stop_words, "plane.png")

# %% [markdown]
# #### DataViz: Worcloud of All naratives

# %%
# Write all narratives of the dataset into a single string 
all_nar = ''
all_nar = ' '.join(str(entry) for entry in df['Narrative'])
len(all_nar)
# Out:
# 160209560

# %%
fig = plt.figure(figsize = (18, 18))

plot_word_cloud(all_nar, 'All narratives', stop_words, "plane.png")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-752cb8791155> in <module>()
#       1 fig = plt.figure(figsize = (18, 18))
#       2
# ----> 3 plot_word_cloud(all_nar, 'All narratives', stop_words, "plane.png")
#
# <ipython-input-32-6e913f1e46b8> in plot_word_cloud(text, title, stop_words, mask, background_color)
#      21     # Generate and plot the wordcloud
#      22     #plt.figure(figsize= (10,5)) # comment it out if you use subplots
# ---> 23     wc.generate(text)
#      24     plt.imshow(wc, interpolation="bilinear")
#      25     plt.xticks([])
#
# /usr/local/lib/python3.7/dist-packages/wordcloud/wordcloud.py in generate(self, text)
#     603         self
#     604         """
# --> 605         return self.generate_from_text(text)
#     606
#     607     def _check_generated(self):
#
# /usr/local/lib/python3.7/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# /usr/local/lib/python3.7/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     516             # recompute bottom right
#     517             # the order of the cumsum's is important for speed ?!
# --> 518             occupancy.update(img_array, x, y)
#     519             last_freq = freq
#     520
#
# /usr/local/lib/python3.7/dist-packages/wordcloud/wordcloud.py in update(self, img_array, pos_x, pos_y)
#      48     def update(self, img_array, pos_x, pos_y):
#      49         partial_integral = np.cumsum(np.cumsum(img_array[pos_x:, pos_y:],
# ---> 50                                                axis=1), axis=0)
#      51         # paste recomputed part into old image
#      52         # if x or y is zero it is a bit annoying
#
# <__array_function__ internals> in cumsum(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in cumsum(a, axis, dtype, out)
#    2530
#    2531     """
# -> 2532     return _wrapfunc(a, 'cumsum', axis=axis, dtype=dtype, out=out)
#    2533
#    2534
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %% [markdown]
# #### Narrative length distribution

# %% [markdown]
# ##### All main narratives

# %%
# Create new column in df
df['narr_len'] = pd.Series([len(entry) for entry in df['Narrative']])

# %%
# Plot
sns.displot(df['narr_len'], bins = 30, kde = True)
plt.xlabel('# of characters')
plt.title('Narrative length distribution');

# %% [markdown]
# ##### Only entries with 2 narratives

# %%
# Create new column in 'nar1_all' DataFrame
nar1_all['narr_len'] = pd.Series([len(entry) for entry in nar1_all['Narrative']])
nar1_all['narr1_len'] = pd.Series([len(entry) for entry in nar1_all['Narrative.1']])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Plot
sns.displot([nar1_all['narr_len'], nar1_all['narr1_len']],
            bins = 40, kde = True)
plt.xlabel('# of characters')
plt.title('Narrative length');

# %% [markdown]
# The peak in narr1_len is suspicious. Examine the situation:

# %%
# Plot (zoom)
sns.displot([nar1_all['narr_len'], nar1_all['narr1_len']],
            bins = 40, kde = True)
plt.xlabel('# of characters')
plt.title('Narrative length')
plt.xlim([0, 600]);

# %% [markdown]
# The peak is for narrative.1 with len < 300 characters.

# %%
nar1_all['narr1_len'].unique()
# Out:
# array([1689.,  614.,   77., ..., 1085., 2652.,   nan])

# %%
len(nar1_all[nar1_all['narr1_len'] < 300])
# Out:
# 1295

# %%
# Examine the short 'Narrative.1' entries
my_list = [entry for entry in nar1_all[nar1_all['narr1_len'] < 300 ]['Narrative.1']]

# %%
my_list[:10]
# Out:
# ['Using both of our experience and available resources we determined it to be a safe option to depart. We may have been able to get a better understanding of the storm had we been in more contact with Dispatch who may have seen more. Or if we had other radar depictions to view in addition to the aircraft radar we might have seen there was another option whether it be delay the departure or take another course.',
#  '[Narrative 2 had no additional information.]',
#  "Multiple speed assignments and incomplete clearances increased our arrival workload to the point that we accomplished our Descent Checklist late and almost forgot to turn the seatbelt sign on prior to landing. While still cruising at FL250; ATC had assigned 280 knots. Later on the arrival; we were told to comply with the speeds on the arrival. We had not yet been cleared to 'Descend 'via' the GEELA 6;' so we asked if we were cleared to descend 'via' the arrival; and then; for the first time; we were in fact cleared to descend 'via' the GEELA 6 Runway 7R transition. This was a blatant case of over control and it creates an environment prone to errors. ABQ Center and PHX Approach are over controlling airplanes on all the arrivals into PHX; and it is frustrating. We are trying to be good citizens and comply with the Controller instructions; but it is clear that they are not seeing this from a flight crew's perspective. The issuance of speeds while VNAVing on an arrival has the potential to cause missed altitude restrictions. Clearances off of the arrival without a new altitude is wrong. Once cleared for the arrival; they need to let us fly it - period.",
#  'No substantive additional information was included in the secondary narrative.',
#  'A PC-12 called south of the US/Mexico border inbound to OLS. The pilot called several times; eventually crossing the border; but could not hear me and stated he would start descending for the airport. The aircraft was at 12;000 feet and the reported ceilings were at 6;000 feet. The aircraft entered a restricted area (R2303B) at 12;000 feet and started to descend. About 12 miles northeast of the airport; the pilot could hear me and I gave him an altitude to climb to; since he was now below the MVA; and issued vectors back to the destination airport. We have had numerous communications issues with aircraft inbound from Mexico landing at OLS. We need a radio transceiver at the OLS airport. We have no RADAR coverage below 8;000 feet within 10 miles of the airport; the radio problem makes this very dangerous.',
#  "For this incident; I was the non-flying pilot; I never saw the conflicting aircraft (so my statements are based on what the Captain told me); and our TCAS was non-operational (deferred under MEL guidance). The weather at Tucson was VFR. We were turning base to final to Runway 11L and cleared the visual. ATC never gave us a heads up that there was traffic in our area. The Captain suddenly piped up and ask if I saw that (referring to the passing of a high winged Cessna estimated to be between 300 and 400 feet off our left wingtip and co-altitude). ATC then instructed us to contact Tower and they cleared us to land. We ask Tower if they knew of the other aircraft and they replied that approach control was in contact with them and that the Cessna stated that we were in sight. We landed uneventfully. While taxing in Tower said that their 'bells and whistles' had sounded.This incident might have been avoided; if ATC had informed us of possible conflicting traffic; if we were not offered the visual but flew the full ILS approach with other traffic in the area; if ATC had kept us under IFR longer or directed the Cessna to turn away from us; if the Cessna pilot maneuvered on his own to provide more clearance from us; or if our TCAS had been operational.",
#  "At cruise we detected an electrical burning smell. We suspected the avionics cooling fan. We wanted to act quickly before the situation got worse so we immediately contacted Maintenance Control and Dispatch to confirm with them that pulling the Circuit Breaker (CB) was the correct course of action. After pulling the CB the smell went away quickly. Our decision making was hindered by the lack of information presented in the systems manual on the number of fans in operation in the avionics bay and the related CB's. After pulling the CB we looked in the MEL for the avionics fan and it does not even have a Dispatch Maintenance Procedure (DMP). The systems manual seems to indicate we have 4 fans but the CB panel and MEL seem to indicate 5 fans. Please follow up with me and let me know if the fan indeed was on its way to a bad end.",
#  "Falcon Field has two runways 22R and 22L. I was doing full stop landing to the ramp. Approximately 4 NM; Tower said 'aircraft on base you are number two; Runway 22R cleared to land' and 'verify you are full stop' I did the readback and I tried to see traffic on base. There was just one traffic on Runway 22L base; and no one on 22R base or final. So I followed the traffic on 22L base and I landed safely. I think there were three reasons for this mishap:1-At Falcon Field for full stop landings we generally use 22L.2-There was just one traffic to runway 22L. 3-There was 10 KTS wind and I focused on landing.So I got confused and I landed on the wrong Runway 22L. I know this is my responsibility and this should not have happened. I learned from this mistake and it will not happen again.",
#  '[Report narrative contained no additional information]',
#  "CZEG (Edmonton Center) called me on the R-side prior to having a D-side with a non-radar point out on Aircraft X in the block 240B270 and advised he would be doing a couple turns in hold about 20 miles east of JAGIT.  I approved it.  I had [no] traffic and the altitudes where well above my MIAs.  A while later my D-side points out the code 2000 at FL240 in that vicinity and I tagged up the call sign.  Moments later while I was sequencing aircraft for ANC my D-side points out that Aircraft X was descending; about that time it started to MSAW as well.  My D-side immediately called CZEG to inquire; and established that nobody was in contact with him because of his altitude [low].  So we got permission to use CZEG's frequency to relay through another aircraft a low altitude alert and to climb immediately.  Aircraft X climbed and I had the other aircraft call again to assign 240; and my D-side advised CZEG of this.  A few minutes later CZEG advised they were in contact with the pilot again as he fell out of our radar coverage and the pilot admitted his descent. The appropriate coordination had been accomplished; so it was a pilot deviation; no changes recommended."]

# %%
my_list1 = [entry for entry in nar1_all['Narrative.1'] 
            if ('Narrative' in entry or 'narrative' in entry)
            ]
len(my_list1)
# Out:
# 3437

# %%
my_list1[:100]
# Out:
# ['[Narrative #2 had no additional information.]',
#  '[Narrative 2 had no additional information.]',
#  'No substantive additional information was included in the secondary narrative.',
#  '[Narrative 2 contains no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information]',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contains no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contains no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  "First officer and I were departing PANC for ZZZ. First time in or out of PANC for either of us. We discussed the departure procedure; ANCHO8 during our departure briefing. The emphasis item that we did not FULLY brief was that a turn is made to the south off of runway 7L once passing 2000' or at D4.0 TED; WHICHEVER COMES FIRST. These last three words; which are not emphasized; are where we erred. So; we flew the proper ground track and the FO made the right turn at the 4.0 point off of TED. Once in the turn we received the verbal low altitude alert warning from the controller to turn right and climb immediately. We were well established in the turn when this occurred and there were NO terrain warnings or EGPWS alerts from inside the aircraft.Multiple factors were involved here.  Departure on the last day out of an unfamiliar airport with mountains off the departure end; obscured by smoke at about 4 miles visibility. Also; in my opinion; a poorly worded departure procedure and NO GUIDANCE on the company 10-7C page. Two items need to be clarified for this departure and others at PANC that have the same initial procedure off of the 7's. First ... It needs to be emphasized that the initial turn is made when EITHER you have reached D4.0 OR 2000' WHICHEVER COMES FIRST! There are not too many places that I have flown where this type of procedure is in effect. It can be easily done; but it needs to be much clearer to the crews. In addition; in the INITIAL CLIMB narrative on the 10-3 departure procedure it states; 'Advise ATC prior to departure if unable to be established on heading 199 by D4.0 TED EAST of TED VOR.' This is a difficult assessment to make for most crews.",
#  '[Report narrative contained no additional information]',
#  '[Report narrative contains no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Narrative #2 had no additional information.]',
#  '[No substantive additional information was included in the secondary narrative.]',
#  '[Narrative #2 had no additional information.]',
#  '[Narrative 2 had no additional information]',
#  '[No substantive additional information was included in the secondary narrative.]',
#  '[Narrative #2 contained no additional information.]',
#  '[Narrative 2 contained no additional information.]',
#  '[Narrative 2 provided no additional information]',
#  '[Narrative #2 contained no additional information.]',
#  '[Narrative #2 contained no additional information.]',
#  '[No additional information contained in Narrative #2.]',
#  '[No additional information provided in narrative 2.]',
#  '[Narrative 2 had no additional information.]',
#  '[Narrative 2 contained no additional information.]',
#  '[Narrative 2 contained no additional information.]',
#  '[Narrative 2 contained no additional information.]',
#  '[Narrative 2 contained no additional information.]',
#  '[Narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Narrative #2 contains no additional information.]',
#  '[Narrative #2 contained no additional information.]',
#  '[Report narrative contained no additional information]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative had no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information].',
#  'The secondary narrative contained no additional information.',
#  '[Report narrative contained no additional information].',
#  '[Report Narrative Contained no Additional Information].',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report Narrative Contained No Additional Information].',
#  '[Report Narrative Contained No Additional Information.]',
#  '[Report narrative had no additional information].',
#  '[Report narrative contained no additional information].',
#  '[Report Narrative Contained No Additional Information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report Narrative Contained No Additional Information.]',
#  '[Report narrative contained no additional information.]',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information].',
#  '[Report narrative contained no additional information.]']

# %% [markdown]
# * The 'common denominator' of these entries is the string 'additional information', or 'Additional Information'.
# * Some have '[]', others not
# * Some have 'no', others not
# * the word 'narrative' or 'Narrative' is sometimes preceeds, sometimes follows 'additional information'

# %%
empty_narr1 = [entry for entry in nar1_all['Narrative.1'] 
            if ('additional information' in entry or 'Additional Information' in entry)]

# %%
print("Out of a total of", len(nar1_all), "non-NaN 'Narrative.1' entries, there are\n", len(empty_narr1), "effectively empty 'Narrative.1' entries, such as '[Report Narrative Contained No Additional Information.]'")
# Out:
# Out of a total of 14825 non-NaN 'Narrative.1' entries, there are
#  3494 effectively empty 'Narrative.1' entries, such as '[Report Narrative Contained No Additional Information.]'
